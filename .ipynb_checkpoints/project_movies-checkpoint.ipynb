# %%
import pandas as pd
import numpy as np
import seaborn as sns
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import math
import datetime as dt

# %% [markdown]
# # Import data

# %% [markdown]
# 1. plot_summaries.txt
#
# Plot summaries of 42,306 movies extracted from the November 2, 2012 dump of English-language Wikipedia.  Each line contains the Wikipedia movie ID (which indexes into movie.metadata.tsv) followed by the summary.

# %%
#with open('data/MovieSummaries/plot_summaries.txt', encoding='utf8') as f:
#    lines = f.read()
#    print(lines)
    

################################ Balth: J'ai des problèmes avec les lignes en dessus...

colnames = ['Wikipedia_movie_ID', 'Summary'] 

df = pd.read_csv('data/MovieSummaries/plot_summaries.txt', names = colnames, header = None, sep="\t", on_bad_lines='warn')
df
# Out:
#        Wikipedia_movie_ID                                            Summary
# 0                23890098  Shlykov, a hard-working taxi driver and Lyosha...
# 1                31186339  The nation of Panem consists of a wealthy Capi...
# 2                20663735  Poovalli Induchoodan  is sentenced for six yea...
# 3                 2231378  The Lemon Drop Kid , a New York City swindler,...
# 4                  595909  Seventh-day Adventist Church pastor Michael Ch...
# ...                   ...                                                ...
# 42298            34808485  The story is about Reema , a young Muslim scho...
# 42299             1096473  In 1928 Hollywood, director Leo Andreyev  look...
# 42300            35102018  American Luthier focuses on Randy Parsons’ tra...
# 42301             8628195  Abdur Rehman Khan , a middle-aged dry fruit se...
# 42302             6040782  1940 - Operation Dynamo has just taken place. ...
#
# [42303 rows x 2 columns]

# %% [markdown]
# 2. corenlp_plot_summaries.tar.gz [628 M, separate download]
#
# The plot summaries from above, run through the Stanford CoreNLP pipeline (tagging, parsing, NER and coref). Each filename begins with the Wikipedia movie ID (which indexes into movie.metadata.tsv).

# %%
# Reading the data inside the xml.gz file to a variable under the name data
import gzip
path_corenlp = 'data/corenlp_plot_summaries/'
fname = '330.xml.gz'
with gzip.open(path_corenlp+fname, 'rb') as f:
    data = f.read()
    
# Passing the stored data inside the beautifulsoup parser 
bs_data = BeautifulSoup(data, "xml") 

# Finding all instances of tag   
b_unique = bs_data.find_all("lemma") 
print(b_unique)
# Out:
# [<lemma>in</lemma>, <lemma>order</lemma>, <lemma>to</lemma>, <lemma>prepare</lemma>, <lemma>the</lemma>, <lemma>role</lemma>, <lemma>of</lemma>, <lemma>a</lemma>, <lemma>important</lemma>, <lemma>old</lemma>, <lemma>actress</lemma>, <lemma>,</lemma>, <lemma>a</lemma>, <lemma>theater</lemma>, <lemma>student</lemma>, <lemma>interview</lemma>, <lemma>three</lemma>, <lemma>actress</lemma>, <lemma>who</lemma>, <lemma>be</lemma>, <lemma>she</lemma>, <lemma>pupil</lemma>, <lemma>:</lemma>, <lemma>a</lemma>, <lemma>international</lemma>, <lemma>diva</lemma>, <lemma>,</lemma>, <lemma>a</lemma>, <lemma>television</lemma>, <lemma>star</lemma>, <lemma>and</lemma>, <lemma>a</lemma>, <lemma>dub</lemma>, <lemma>director</lemma>, <lemma>.</lemma>]

# %% [markdown]
# 3. movie.metadata.tsv.gz [3.4 M]
#
#
# Metadata for 81,741 movies, extracted from the Noverber 4, 2012 dump of Freebase.  Tab-separated; columns:
#
# 1. Wikipedia movie ID
# 2. Freebase movie ID
# 3. Movie name
# 4. Movie release date
# 5. Movie box office revenue
# 6. Movie runtime
# 7. Movie languages (Freebase ID:name tuples)
# 8. Movie countries (Freebase ID:name tuples)
# 9. Movie genres (Freebase ID:name tuples)

# %%
colnames = ['Wikipedia_movie_ID', 'Freebase_movie_ID', 'Movie_name', 'Movie_release_date', 'Movie_box office_revenue', 'Movie_runtime', 'Movie_languages', 'Movie_countries' , 'Movie_genres'] 


movie_md_raw = pd.read_csv('data/MovieSummaries/movie.metadata.tsv', sep='\t',names = colnames, header=None)
movie_md = movie_md_raw.copy()
movie_md.rename(columns = {'Movie_box office_revenue':'Movie_boxoffice_revenue'}, inplace = True)
movie_md.sample(5)
# Out:
#        Wikipedia_movie_ID Freebase_movie_ID                  Movie_name  \
# 6866             12288251        /m/02vz1fg           Birth of a Notion
# 42170             8582821        /m/0278tzk                  Al Corazón
# 14393            32416906        /m/0gysdrt                  Finding Me
# 53984             4765882         /m/0cm4_m      Unaccustomed As We Are
# 17211            20630769        /m/051vnnf  Trail of the Lonesome Pink
#
#       Movie_release_date  Movie_boxoffice_revenue  Movie_runtime  \
# 6866          1947-04-12                      NaN            7.0
# 42170         1996-03-22                      NaN           92.0
# 14393         2009-03-03                      NaN          115.0
# 53984         1929-05-04                      NaN           18.0
# 17211         1974-06-27                      NaN            NaN
#
#                           Movie_languages  \
# 6866   {"/m/02h40lc": "English Language"}
# 42170    {"/m/06nm1": "Spanish Language"}
# 14393  {"/m/02h40lc": "English Language"}
# 53984  {"/m/02h40lc": "English Language"}
# 17211                                  {}
#
#                                  Movie_countries  \
# 6866   {"/m/09c7w0": "United States of America"}
# 42170                   {"/m/0jgd": "Argentina"}
# 14393                                         {}
# 53984  {"/m/09c7w0": "United States of America"}
# 17211                                         {}
#
#                                             Movie_genres
# 6866   {"/m/02hmvc": "Short Film", "/m/0hcr": "Animat...
# 42170  {"/m/04t36": "Musical", "/m/0jtdp": "Documenta...
# 14393                            {"/m/07s9rl0": "Drama"}
# 53984  {"/m/02hmvc": "Short Film", "/m/01z4y": "Comed...
# 17211  {"/m/02hmvc": "Short Film", "/m/05p553": "Come...

# %% [markdown]
# **General description of data**

# %%
movie_md.info()
sns.heatmap(movie_md.isnull(), cmap=['w','b'])
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81741 entries, 0 to 81740
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Wikipedia_movie_ID       81741 non-null  int64
#  1   Freebase_movie_ID        81741 non-null  object
#  2   Movie_name               81741 non-null  object
#  3   Movie_release_date       74839 non-null  object
#  4   Movie_boxoffice_revenue  8401 non-null   float64
#  5   Movie_runtime            61291 non-null  float64
#  6   Movie_languages          81741 non-null  object
#  7   Movie_countries          81741 non-null  object
#  8   Movie_genres             81741 non-null  object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 5.6+ MB

# %% [markdown]
# **Create relational tables for languages, countries and genres**

# %%
def string2list(string):
    '''
    Converts string to dictionnary to list
    in order to be able to use pandas.DataFrame.explode()
    '''
    import ast
    
    dic = ast.literal_eval(string)
    new_list  = list(dic.values())
    return new_list


movie_languages = movie_md.copy()
movie_languages.Movie_languages = movie_languages.Movie_languages.apply(lambda x: string2list(x))
movie_languages = movie_languages.explode('Movie_languages', ignore_index = True)
movie_languages = movie_languages.drop(columns=['Freebase_movie_ID', 'Movie_name','Movie_release_date'\
                                                ,'Movie_boxoffice_revenue','Movie_runtime','Movie_countries'\
                                                ,'Movie_genres'])
movie_languages['Movie_languages']= movie_languages['Movie_languages'].astype(str) 

movie_countries = movie_md.copy()
movie_countries['Movie_countries'] = movie_countries['Movie_countries'].apply(lambda x: string2list(x))
movie_countries = movie_countries.explode('Movie_countries', ignore_index = True)
movie_countries = movie_countries.drop(columns=['Freebase_movie_ID', 'Movie_name','Movie_release_date'\
                                                ,'Movie_boxoffice_revenue','Movie_runtime','Movie_languages'\
                                                ,'Movie_genres'])

movie_genres = movie_md.copy()
movie_genres['Movie_genres'] = movie_genres['Movie_genres'].apply(lambda x: string2list(x))
movie_genres = movie_genres.explode('Movie_genres', ignore_index = True)
movie_genres = movie_genres.drop(columns=['Freebase_movie_ID', 'Movie_name','Movie_release_date'\
                                                ,'Movie_boxoffice_revenue','Movie_runtime','Movie_languages'\
                                                ,'Movie_countries'])
movie_genres
# Out:
#         Wikipedia_movie_ID     Movie_genres
# 0                   975900         Thriller
# 1                   975900  Science Fiction
# 2                   975900           Horror
# 3                   975900        Adventure
# 4                   975900     Supernatural
# ...                    ...              ...
# 245618              913762            Drama
# 245619            12476867         Thriller
# 245620            12476867           Horror
# 245621            12476867          Slasher
# 245622            12476867             Teen
#
# [245623 rows x 2 columns]

# %% [markdown]
# **Clean + distribution of Movie_release_date**

# %%
#movie_md[movie_md.Movie_release_date.isna()]#all missing Movie_release_date are nan

#convert dates to datetimes. Dates with only year are set as the first of January of that year. Date that are out of bounds
#are set as NaT.
movie_md.Movie_release_date = pd.to_datetime(movie_md.Movie_release_date, errors = 'coerce', yearfirst = True)

plt.figure(figsize=[11, 5])
plt.suptitle('Movie release dates')

# Plot 1
plt.subplot(1, 2, 1)
sns.histplot(data=movie_md, x='Movie_release_date')
plt.title('Movie release dates histogram')

# Plot 2
plt.subplot(1, 2, 2)
sns.boxplot(data=movie_md.Movie_release_date.dt.year)
plt.title('Movie release dates boxplot')
plt.show()

movie_md.Movie_release_date.describe(datetime_is_numeric = True)
#movie_md.loc[movie_md.Movie_release_date.dt.year == 1888].Movie_name
# Out:
# count                            74838
# mean     1977-10-12 11:46:07.610037696
# min                1888-01-01 00:00:00
# 25%                1956-01-01 00:00:00
# 50%                1985-05-18 12:00:00
# 75%                2004-01-01 00:00:00
# max                2016-06-08 00:00:00
# Name: Movie_release_date, dtype: object

# %% [markdown]
# There doesn't seem to be any major issues with the movie release dates. Although the earliest movie from the dataset is from 1888 (which raised suspicion) and lasts only 3 seconds, after some research, it is in fact a real 'film'.

# %% [markdown]
# **Clean + distribution of Movie_boxoffice_revenue**

# %%
#movie_md[movie_md.Movie_boxoffice_revenue.isna()]#all missing Movie_release_date are nan

plt.figure(figsize=[11, 5])
plt.suptitle('Movie boxoffice revenue')

# Plot 1
plt.subplot(1, 2, 1)
sns.histplot(data=movie_md, x='Movie_boxoffice_revenue',log_scale = True)
plt.title('Movie boxoffice revenue histogram')

# Plot 2
plt.subplot(1, 2, 2)
sns.boxplot(data=movie_md.Movie_boxoffice_revenue)
plt.yscale('log')
plt.title('Movie boxoffice revenue boxplot')
plt.show()

stats = movie_md.Movie_boxoffice_revenue.describe()
print(f'Max revenue: {stats}')
movie_md.loc[movie_md.Movie_boxoffice_revenue == stats[7]]
# Out:
# Max revenue: count    8.401000e+03
# mean     4.799363e+07
# std      1.121753e+08
# min      1.000000e+04
# 25%      2.083193e+06
# 50%      1.063969e+07
# 75%      4.071696e+07
# max      2.782275e+09
# Name: Movie_boxoffice_revenue, dtype: float64
#        Wikipedia_movie_ID Freebase_movie_ID Movie_name Movie_release_date  \
# 23702             4273140         /m/0bth54     Avatar         2009-12-10
#
#        Movie_boxoffice_revenue  Movie_runtime  \
# 23702             2.782275e+09          178.0
#
#                                          Movie_languages  \
# 23702  {"/m/02h40lc": "English Language", "/m/06nm1":...
#
#                                          Movie_countries  \
# 23702  {"/m/09c7w0": "United States of America", "/m/...
#
#                                             Movie_genres
# 23702  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...

# %% [markdown]
# **Clean + distribution of Movie_runtime**

# %%
#movie_md[movie_md.Movie_runtime.isna()]#all missing Movie_release_date are nan

movie_md.loc[movie_md.Movie_runtime == np.max(movie_md.Movie_runtime), 'Movie_runtime'] = np.nan #wrong max 
movie_md.loc[movie_md.Movie_runtime == np.min(movie_md.Movie_runtime), 'Movie_runtime'] = np.nan #wrong min

plt.figure(figsize=[11, 5])
plt.suptitle('Movie runtime')

# Plot 1
plt.subplot(1, 2, 1)
sns.histplot(data=movie_md, x='Movie_runtime')
plt.yscale('log')
plt.xscale('log')
plt.title('Movie runtime histogram')

# Plot 2
plt.subplot(1, 2, 2)
sns.violinplot(data=movie_md.Movie_runtime)
plt.yscale('log')
plt.title('Movie runtime boxplot')
plt.show()

movie_md.Movie_runtime.describe()

stats = movie_md.Movie_runtime.describe()
stats
# Out:
# count    61287.000000
# mean        93.981244
# std         70.681536
# min          0.050000
# 25%         81.000000
# 50%         93.000000
# 75%        106.000000
# max       9360.000000
# Name: Movie_runtime, dtype: float64

# %% [markdown]
# **Clean + distributions of movie_languages**

# %%
unique = pd.DataFrame(movie_languages.Movie_languages.unique())
#From the line above, problematic language value: \ud801\udc16\ud801\udc32\ud801\udc49\ud801\udc4b\ud801\udc4c\ud801\udc32
#unique.loc[unique == 'English Language']
#unique[unique[0] == '\ud801\udc16\ud801\udc32\ud801\udc49\ud801\udc4b\ud801\udc4c\ud801\udc32']
#'utf-8' codec can't encode characters in position 97-108: surrogates not allowed
#oui = unique == '\ud801\udc16\ud801\udc32\ud801\udc49\ud801\udc4b\ud801\udc4c\ud801\udc32'

#non = oui[0].tolist()
#non.index(True)
#unique.iloc[82]

# %%
plt.figure()
g = sns.histplot(data=movie_languages, x='Movie_languages')
g.set(xticklabels=[])
g.set_title('Histogram of movie languages')
g.set_ylabel('Number of movies')
plt.yscale('log')
plt.show()

number_movie_languages_sorted = movie_languages.groupby(by = 'Movie_languages').count().sort_values(
                                                            by = 'Wikipedia_movie_ID', ascending = False)
number_movie_languages_sorted = number_movie_languages_sorted.rename(columns = {'Wikipedia_movie_ID': 'Number_movies'})
tot_movies_languages = number_movie_languages_sorted.sum()
number_movie_languages_sorted['Ratio'] = number_movie_languages_sorted*100/tot_movies_languages
number_movie_languages_sorted['Cumsum'] = number_movie_languages_sorted['Ratio'].cumsum()

number_movie_languages_sorted
# Out:
#                        Number_movies      Ratio      Cumsum
# Movie_languages
# English Language               40891  42.965368   42.965368
# nan                            13866  14.569411   57.534779
# Hindi Language                  3744   3.933930   61.468709
# Spanish Language                3673   3.859328   65.328038
# French Language                 3422   3.595595   68.923633
# ...                              ...        ...         ...
# Picard Language                    1   0.001051   99.995797
# Sunda Language                     1   0.001051   99.996848
# Sumerian                           1   0.001051   99.997899
# Southwestern Mandarin              1   0.001051   99.998949
# Maasai Language                    1   0.001051  100.000000
#
# [208 rows x 3 columns]

# %% [markdown]
# **Clean + distributions of movie_countries**

# %%
movie_countries.Movie_countries.unique()

plt.figure()
g = sns.histplot(data=movie_countries, x='Movie_countries')
g.set(xticklabels=[])
g.set_title('Histogram of movie countries')
g.set_ylabel('Number of movies')
plt.yscale('log')
plt.show()

number_movie_countries_sorted = movie_countries.groupby(by = 'Movie_countries').count().sort_values(
                                                            by = 'Wikipedia_movie_ID', ascending = False)
number_movie_countries_sorted = number_movie_countries_sorted.rename(columns = {'Wikipedia_movie_ID': 'Number_movies'})
tot_movies_countries = number_movie_countries_sorted.sum()

number_movie_countries_sorted['Ratio'] = number_movie_countries_sorted*100/tot_movies_countries
number_movie_countries_sorted['Cumsum'] = number_movie_countries_sorted['Ratio'].cumsum()

number_movie_countries_sorted
# Out:
#                           Number_movies      Ratio      Cumsum
# Movie_countries
# United States of America          34408  39.806106   39.806106
# India                              8411   9.730561   49.536667
# United Kingdom                     7868   9.102373   58.639040
# France                             4395   5.084510   63.723551
# Italy                              3163   3.659228   67.382779
# ...                                 ...        ...         ...
# Ukranian SSR                          1   0.001157   99.995372
# Iraqi Kurdistan                       1   0.001157   99.996529
# Macau                                 1   0.001157   99.997686
# Palestinian Territories               1   0.001157   99.998843
# Turkmenistan                          1   0.001157  100.000000
#
# [147 rows x 3 columns]

# %% [markdown]
# **Clean + distributions of movie_genres**

# %%
movie_genres.Movie_genres.unique()

#replace Biopic [feature] by Biopic
movie_genres.loc[movie_genres.Movie_genres == 'Biopic [feature]','Movie_genres'] = 'Biopic'


plt.figure()
g = sns.histplot(data=movie_genres, x='Movie_genres')
g.set(xticklabels=[])
plt.yscale('log')
g.set_title('Histogram of movie genres')
g.set_ylabel('Number of movies')
plt.show()


number_movie_genres_sorted = movie_genres.groupby(by = 'Movie_genres').count().sort_values(
                                                            by = 'Wikipedia_movie_ID', ascending = False)
number_movie_genres_sorted = number_movie_genres_sorted.rename(columns = {'Wikipedia_movie_ID': 'Number_movies'})
tot_movies_genres = number_movie_genres_sorted.sum()

number_movie_genres_sorted['Ratio'] = number_movie_genres_sorted*100/tot_movies_genres
number_movie_genres_sorted['Cumsum'] = number_movie_genres_sorted['Ratio'].cumsum()
number_movie_genres_sorted
# Out:
#                   Number_movies      Ratio      Cumsum
# Movie_genres
# Drama                     34007  13.975728   13.975728
# Comedy                    16349   6.718887   20.694615
# Romance Film              10234   4.205828   24.900443
# Black-and-white            9094   3.737327   28.637770
# Action                     8798   3.615681   32.253451
# ...                         ...        ...         ...
# Comdedy                       1   0.000411   99.998356
# New Queer Cinema              1   0.000411   99.998767
# Linguistics                   1   0.000411   99.999178
# Statutory rape                1   0.000411   99.999589
# C-Movie                       1   0.000411  100.000000
#
# [363 rows x 3 columns]

# %% [markdown]
# # 4. character.metadata.tsv.gz [14 M]
#
# Metadata for 450,669 characters aligned to the movies above, extracted from the Noverber 4, 2012 dump of Freebase.  Tab-separated; columns:
#
# 1. Wikipedia movie ID
# 2. Freebase movie ID
# 3. Movie release date
# 4. Character name
# 5. Actor date of birth
# 6. Actor gender
# 7. Actor height (in meters)
# 8. Actor ethnicity (Freebase ID)
# 9. Actor name
# 10. Actor age at movie release
# 11. Freebase character/actor map ID
# 12. Freebase character ID
# 13. Freebase actor ID

# %%
colnames=['Wikipedia_movie_ID', 'Freebase_movie_ID', 'Movie_release_date', 'Character_name','Actor_date_of_birth', 'Actor_gender', 'Actor_height', 'Actor_ethnicity', 'Actor_name', 'Actor_age_at_movie_release', 'Freebase_character/actor_map_ID', 'Freebase_character_ID', 'Freebase_actor_ID'] 

character_md = pd.read_csv('data/MovieSummaries/character.metadata.tsv', sep='\t',names = colnames, header=None)
character_md.head(5)
# Out:
#    Wikipedia_movie_ID Freebase_movie_ID Movie_release_date  \
# 0              975900         /m/03vyhn         2001-08-24
# 1              975900         /m/03vyhn         2001-08-24
# 2              975900         /m/03vyhn         2001-08-24
# 3              975900         /m/03vyhn         2001-08-24
# 4              975900         /m/03vyhn         2001-08-24
#
#                Character_name Actor_date_of_birth Actor_gender  Actor_height  \
# 0                    Akooshay          1958-08-26            F         1.620
# 1  Lieutenant Melanie Ballard          1974-08-15            F         1.780
# 2         Desolation Williams          1969-06-15            M         1.727
# 3          Sgt Jericho Butler          1967-09-12            M         1.750
# 4             Bashira Kincaid          1977-09-25            F         1.650
#
#   Actor_ethnicity          Actor_name  Actor_age_at_movie_release  \
# 0             NaN      Wanda De Jesus                        42.0
# 1      /m/044038p  Natasha Henstridge                        27.0
# 2         /m/0x67            Ice Cube                        32.0
# 3             NaN       Jason Statham                        33.0
# 4             NaN         Clea DuVall                        23.0
#
#   Freebase_character/actor_map_ID Freebase_character_ID Freebase_actor_ID
# 0                      /m/0bgchxw            /m/0bgcj3x        /m/03wcfv7
# 1                       /m/0jys3m            /m/0bgchn4         /m/0346l4
# 2                       /m/0jys3g            /m/0bgchn_        /m/01vw26l
# 3                      /m/02vchl6            /m/0bgchnq         /m/034hyc
# 4                      /m/02vbb3r            /m/0bgchp9         /m/01y9xg

# %% [markdown]
# tvtropes.clusters.txt
#
# 72 character types drawn from tvtropes.com, along with 501 instances of those types.  The ID field indexes into the Freebase character/actor map ID in character.metadata.tsv.

# %%
with open('data/MovieSummaries/tvtropes.clusters.txt', encoding='utf8') as f:
    lines = f.read()
    #print(lines)
    
print(lines)
# Out:
# absent_minded_professor	{"char": "Professor Philip Brainard", "movie": "Flubber", "id": "/m/0jy9q0", "actor": "Robin Williams"}
# absent_minded_professor	{"char": "Professor Keenbean", "movie": "Richie Rich", "id": "/m/02vchl3", "actor": "Michael McShane"}
# absent_minded_professor	{"char": "Dr. Reinhardt Lane", "movie": "The Shadow", "id": "/m/0k6fkc", "actor": "Ian McKellen"}
# absent_minded_professor	{"char": "Dr. Harold Medford", "movie": "Them!", "id": "/m/0k6_br", "actor": "Edmund Gwenn"}
# absent_minded_professor	{"char": "Daniel Jackson", "movie": "Stargate", "id": "/m/0k3rhh", "actor": "James Spader"}
# adventurer_archaeologist	{"char": "Indiana Jones", "movie": "Indiana Jones and the Kingdom of the Crystal Skull", "id": "/m/0jzx78", "actor": "Harrison Ford"}
# adventurer_archaeologist	{"char": "Indiana Jones", "movie": "Indiana Jones and the Raiders of the Lost Ark", "id": "/m/0k294p", "actor": "Harrison Ford"}
# adventurer_archaeologist	{"char": "Indiana Jones", "movie": "Indiana Jones and the Temple of Doom", "id": "/m/0jzx9b", "actor": "Harrison Ford"}
# adventurer_archaeologist	{"char": "Evelyn Carnahan-O'Connell", "movie": "The Mummy", "id": "/m/0k5yzc", "actor": "Rachel Weisz"}
# arrogant_kungfu_guy	{"char": "Han", "movie": "Enter the Dragon", "id": "/m/02vd8hn", "actor": "Shih Kien"}
# arrogant_kungfu_guy	{"char": "Johnny Lawrence", "movie": "The Karate Kid", "id": "/m/0k5jyf", "actor": "William Zabka"}
# arrogant_kungfu_guy	{"char": "Jen Yu", "movie": "Crouching Tiger, Hidden Dragon", "id": "/m/0jwv09", "actor": "Zhang Ziyi"}
# arrogant_kungfu_guy	{"char": "Pai Mei", "movie": "Kill Bill Volume 2", "id": "/m/0gz3h92", "actor": "Chia Hui Liu"}
# arrogant_kungfu_guy	{"char": "Apollo Creed", "movie": "Rocky", "id": "/m/0k2n0d", "actor": "Carl Weathers"}
# arrogant_kungfu_guy	{"char": "Clubber Lang", "movie": "Rocky III", "id": "/m/0k2n56", "actor": "Mr. T"}
# arrogant_kungfu_guy	{"char": "Storm Shadow", "movie": "G.I. Joe: The Rise of Cobra", "id": "/m/052dfd5", "actor": "Lee Byung-Hun"}
# arrogant_kungfu_guy	{"char": "Kurgan", "movie": "Highlander", "id": "/m/02214xq", "actor": "Clancy Brown"}
# arrogant_kungfu_guy	{"char": "Anakin Skywalker", "movie": "Star Wars Episode III: Revenge of the Sith", "id": "/m/02sg5ry", "actor": "Hayden Christensen"}
# big_man_on_campus	{"char": "Guy Perkins", "movie": "Never Been Kissed", "id": "/m/02vbkvz", "actor": "Jeremy Jordan"}
# big_man_on_campus	{"char": "John Tucker", "movie": "John Tucker Must Die", "id": "/m/0j_6gm", "actor": "Jesse Metcalfe"}
# big_man_on_campus	{"char": "Woody Deane", "movie": "It's a Boy Girl Thing", "id": "/m/02vc983", "actor": "Kevin Zegers"}
# big_man_on_campus	{"char": "Van Wilder", "movie": "National Lampoon's Van Wilder", "id": "/m/0k14rv", "actor": "Ryan Reynolds"}
# big_man_on_campus	{"char": "Paul Metzler", "movie": "Election", "id": "/m/02vdf9d", "actor": "Chris Klein"}
# big_man_on_campus	{"char": "Troy Bolton", "movie": "High School Musical", "id": "/m/0jzdys", "actor": "Zac Efron"}
# big_man_on_campus	{"char": "Mike Dexter", "movie": "Can't Hardly Wait", "id": "/m/03jsnmf", "actor": "Peter Facinelli"}
# bounty_hunter	{"char": "Man with No Name", "movie": "For a Few Dollars More", "id": "/m/0jybsq", "actor": "Clint Eastwood"}
# bounty_hunter	{"char": "Josey Wales", "movie": "The Outlaw Josey Wales", "id": "/m/0k61jr", "actor": "Clint Eastwood"}
# bounty_hunter	{"char": "Jellon Lamb", "movie": "The Proposition", "id": "/m/06wh7_d", "actor": "John Hurt"}
# bounty_hunter	{"char": "Beck", "movie": "The Rundown", "id": "/m/0k6bqx", "actor": "The Rock"}
# bounty_hunter	{"char": "Rick Deckard", "movie": "Blade Runner", "id": "/m/0jvhbm", "actor": "Harrison Ford"}
# bounty_hunter	{"char": "Leonard Smalls", "movie": "Raising Arizona", "id": "/m/02vbtgt", "actor": "Randall \"Tex\" Cobb"}
# bounty_hunter	{"char": "Jack Walsh", "movie": "Midnight Run", "id": "/m/0k0n9r", "actor": "Robert De Niro"}
# bounty_hunter	{"char": "Milo Boyd", "movie": "The Bounty Hunter", "id": "/m/0772tb3", "actor": "Gerard Butler"}
# bounty_hunter	{"char": "Toombs", "movie": "The Chronicles of Riddick", "id": "/m/0k4qdz", "actor": "Nick Chinlund"}
# bounty_hunter	{"char": "Nick Randall", "movie": "Wanted: Dead or Alive", "id": "/m/03jsm0f", "actor": "Rutger Hauer"}
# brainless_beauty	{"char": "Gemma Honeycutt", "movie": "Fool's Gold", "id": "/m/04dddz5", "actor": "Alexis Dziena"}
# brainless_beauty	{"char": "Matt Mateo", "movie": "The Opposite of Sex", "id": "/m/02tbdw7", "actor": "Ivan Sergei"}
# brainless_beauty	{"char": "Paul Metzler", "movie": "Election", "id": "/m/02vdf9d", "actor": "Chris Klein"}
# brainless_beauty	{"char": "Shelley Darlingson", "movie": "The House Bunny", "id": "/m/04dgw4t", "actor": "Anna Faris"}
# brainless_beauty	{"char": "Brace Channing", "movie": "My Favorite Martian", "id": "/m/03lvf22", "actor": "Elizabeth Hurley"}
# brainless_beauty	{"char": "Mia", "movie": "Stan Helsing", "id": "/m/0gc3g1p", "actor": "Desi Lydic"}
# brainless_beauty	{"char": "Marcia Brady", "movie": "The Brady Bunch Movie", "id": "/m/0k4k_5", "actor": "Christine Taylor"}
# brainless_beauty	{"char": "Chris", "movie": "Roxanne", "id": "/m/0k2q15", "actor": "Rick Rossovich"}
# brainless_beauty	{"char": "Buffy Summers", "movie": "Buffy the Vampire Slayer", "id": "/m/0jvy0r", "actor": "Kristy Swanson"}
# brainless_beauty	{"char": "Brad", "movie": "Extract", "id": "/m/0b3trzf", "actor": "Dustin Milligan"}
# brainless_beauty	{"char": "Jack Bartlett", "movie": "Sugar & Spice", "id": "/m/0cg2m9s", "actor": "James Marsden"}
# brainless_beauty	{"char": "Maggie Feller", "movie": "In Her Shoes", "id": "/m/0jzvtp", "actor": "Cameron Diaz"}
# broken_bird	{"char": "Chelsea Deardon", "movie": "Legal Eagles", "id": "/m/0j_wlm", "actor": "Daryl Hannah"}
# broken_bird	{"char": "Mad Hatter", "movie": "Alice in Wonderland", "id": "/m/04q4dng", "actor": "Johnny Depp"}
# broken_bird	{"char": "Nicole Oakley", "movie": "Crazy/Beautiful", "id": "/m/0jwrqb", "actor": "Kirsten Dunst"}
# broken_bird	{"char": "Annie Newton", "movie": "The Invisible", "id": "/m/02tbbww", "actor": "Margarita Levieva"}
# broken_bird	{"char": "Nina Sayers", "movie": "Black Swan", "id": "/m/0cccx3m", "actor": "Natalie Portman"}
# bromantic_foil	{"char": "Randal Graves", "movie": "Clerks.", "id": "/m/0jwj18", "actor": "Jeff Anderson"}
# bromantic_foil	{"char": "Randal Graves", "movie": "Clerks II", "id": "/m/09vvrb_", "actor": "Jeff Anderson"}
# bromantic_foil	{"char": "Brodie Bruce", "movie": "Mallrats", "id": "/m/07ldy8x", "actor": "Jason Lee"}
# bromantic_foil	{"char": "Banky Edwards", "movie": "Chasing Amy", "id": "/m/05ckj7h", "actor": "Jason Lee"}
# bromantic_foil	{"char": "Ed", "movie": "Shaun of the Dead", "id": "/m/0k35nb", "actor": "Nick Frost"}
# bruiser_with_a_soft_center	{"char": "Hellboy", "movie": "Hellboy: Blood and Iron", "id": "/m/0jzb66", "actor": "Ron Perlman"}
# bruiser_with_a_soft_center	{"char": "Tron", "movie": "Tron", "id": "/m/0hcfdd1", "actor": "Bruce Boxleitner"}
# bruiser_with_a_soft_center	{"char": "James Bond", "movie": "Casino Royale", "id": "/m/02hw79s", "actor": "Daniel Craig"}
# bully	{"char": "Biff Tannen", "movie": "Back to the Future", "id": "/m/0jty60", "actor": "Thomas F. Wilson"}
# bully	{"char": "Scut Farkus", "movie": "A Christmas Story", "id": "/m/0jsprx", "actor": "Zack Ward"}
# bully	{"char": "Vanessa", "movie": "The Grudge 2", "id": "/m/0k592n", "actor": "Teresa Palmer"}
# byronic_hero	{"char": "Jake LaMotta", "movie": "Raging Bull", "id": "/m/0k28_g", "actor": "Robert De Niro"}
# byronic_hero	{"char": "James Bond", "movie": "Casino Royale", "id": "/m/02hw79s", "actor": "Daniel Craig"}
# byronic_hero	{"char": "Travis Bickle", "movie": "Taxi Driver", "id": "/m/0k43s9", "actor": "Robert De Niro"}
# byronic_hero	{"char": "Anakin Skywalker", "movie": "Star Wars Episode III: Revenge of the Sith", "id": "/m/02sg5ry", "actor": "Hayden Christensen"}
# byronic_hero	{"char": "Martin Q. Blank", "movie": "Grosse Pointe Blank", "id": "/m/0jz0wk", "actor": "John Cusack"}
# byronic_hero	{"char": "Brand Hauser", "movie": "War Inc.", "id": "/m/02vczvr", "actor": "John Cusack"}
# byronic_hero	{"char": "Cobb", "movie": "Inception", "id": "/m/0667g_f", "actor": "Leonardo DiCaprio"}
# byronic_hero	{"char": "Achilles", "movie": "Troy", "id": "/m/0k7ckp", "actor": "Brad Pitt"}
# byronic_hero	{"char": "Britt Reid", "movie": "The Green Hornet", "id": "/m/0h5m_9x", "actor": "Seth Rogen"}
# byronic_hero	{"char": "Donnie Darko", "movie": "Donnie Darko", "id": "/m/0jxftx", "actor": "Jake Gyllenhaal"}
# byronic_hero	{"char": "Captain Jack Sparrow", "movie": "Pirates of the Caribbean: Dead Man's Chest", "id": "/m/0k1xxm", "actor": "Johnny Depp"}
# byronic_hero	{"char": "John Wilmot, 2nd Earl of Rochester", "movie": "The Libertine", "id": "/m/0k5ptk", "actor": "Johnny Depp"}
# byronic_hero	{"char": "Robert Angier", "movie": "The Prestige", "id": "/m/0k65k8", "actor": "Hugh Jackman"}
# byronic_hero	{"char": "Tony Stark", "movie": "Iron Man", "id": "/m/0j1__hv", "actor": "Robert Downey Jr."}
# byronic_hero	{"char": "Loki", "movie": "Thor", "id": "/m/0855mjk", "actor": "Tom Hiddleston"}
# byronic_hero	{"char": "Lenny Nero", "movie": "Strange Days", "id": "/m/0k3tt_", "actor": "Ralph Fiennes"}
# byronic_hero	{"char": "Bill 'The Butcher' Cutting", "movie": "Gangs of New York", "id": "/m/0jynbm", "actor": "Daniel Day-Lewis"}
# casanova	{"char": "Giacomo Casanova", "movie": "Casanova", "id": "/m/0jw4mw", "actor": "Heath Ledger"}
# casanova	{"char": "Telly", "movie": "Kids", "id": "/m/0j_flm", "actor": "Leo Fitzpatrick"}
# casanova	{"char": "Tony Stark", "movie": "Iron Man", "id": "/m/0j1__hv", "actor": "Robert Downey Jr."}
# casanova	{"char": "Dorian Gray", "movie": "The League of Extraordinary Gentlemen", "id": "/m/0dkcy1f", "actor": "Stuart Townsend"}
# casanova	{"char": "John Wilmot, 2nd Earl of Rochester", "movie": "The Libertine", "id": "/m/0k5ptk", "actor": "Johnny Depp"}
# casanova	{"char": "Timothy", "movie": "The Long Kiss Goodnight", "id": "/m/02vch3p", "actor": "Craig Bierko"}
# casanova	{"char": "Johnny Wickham", "movie": "Bride and Prejudice", "id": "/m/0cf_wtd", "actor": "Daniel Gillies"}
# chanteuse	{"char": "Jessica Rabbit", "movie": "Who Framed Roger Rabbit", "id": "/m/02wszk9", "actor": "Kathleen Turner"}
# chanteuse	{"char": "Tina Carlyle", "movie": "The Mask", "id": "/m/0k5wls", "actor": "Cameron Diaz"}
# chanteuse	{"char": "Susie Diamond", "movie": "The Fabulous Baker Boys", "id": "/m/0k50tl", "actor": "Michelle Pfeiffer"}
# chanteuse	{"char": "Sugar Kane Kowalczyk", "movie": "Some Like It Hot", "id": "/m/0k3j8v", "actor": "Marilyn Monroe"}
# chanteuse	{"char": "Dorothy Vallens", "movie": "Blue Velvet", "id": "/m/0jvlc4", "actor": "Isabella Rossellini"}
# chanteuse	{"char": "Ellen Aim", "movie": "Streets of Fire", "id": "/m/0k3w12", "actor": "Diane Lane"}
# charmer	{"char": "James Bond", "movie": "Casino Royale", "id": "/m/02hw79s", "actor": "Daniel Craig"}
# charmer	{"char": "Han Solo", "movie": "Star Wars Episode IV: A New Hope", "id": "/m/0k3r1_", "actor": "Harrison Ford"}
# charmer	{"char": "Captain Jack Sparrow", "movie": "Pirates of the Caribbean: Dead Man's Chest", "id": "/m/0k1xxm", "actor": "Johnny Depp"}
# charmer	{"char": "Frank Abagnale Jr.", "movie": "Catch Me If You Can", "id": "/m/0jw5pq", "actor": "Leonardo DiCaprio"}
# charmer	{"char": "Harold Hill", "movie": "The Music Man", "id": "/m/04hv61w", "actor": "Matthew Broderick"}
# charmer	{"char": "Flynn Rider", "movie": "Tangled", "id": "/m/07sl05m", "actor": "Zachary Levi"}
# charmer	{"char": "Hannibal Lecter", "movie": "The Silence of the Lambs", "id": "/m/0k6g86", "actor": "Anthony Hopkins"}
# child_prodigy	{"char": "Anakin Skywalker", "movie": "Star Wars Episode I: The Phantom Menace", "id": "/m/02sg5rn", "actor": "Jake Lloyd"}
# child_prodigy	{"char": "Chris Knight", "movie": "Real Genius", "id": "/m/0k2ckt", "actor": "Val Kilmer"}
# classy_cat_burglar	{"char": "Danielle Foussard", "movie": "To Catch a Thief", "id": "/m/02vbgd1", "actor": "Brigitte Auber"}
# consummate_professional	{"char": "Frank Martin", "movie": "The Transporter", "id": "/m/0k6r5t", "actor": "Jason Statham"}
# consummate_professional	{"char": "Agent Smith", "movie": "The Matrix", "id": "/m/0k5wz1", "actor": "Hugo Weaving"}
# consummate_professional	{"char": "The Professor", "movie": "The Bourne Identity", "id": "/m/0k4kdl", "actor": "Clive Owen"}
# consummate_professional	{"char": "Sam 'Ace' Rothstein", "movie": "Casino", "id": "/m/0jw4vx", "actor": "Robert De Niro"}
# corrupt_corporate_executive	{"char": "Dick Jones", "movie": "RoboCop", "id": "/m/0k2m8v", "actor": "Ronny Cox"}
# corrupt_corporate_executive	{"char": "Cutler Beckett", "movie": "Pirates of the Caribbean: Dead Man's Chest", "id": "/m/0k1xyw", "actor": "Tom Hollander"}
# corrupt_corporate_executive	{"char": "Cutler Beckett", "movie": "Pirates of the Caribbean: At World's End", "id": "/m/0k1xwx", "actor": "Tom Hollander"}
# corrupt_corporate_executive	{"char": "Max Zorin", "movie": "A View to a Kill", "id": "/m/02xl2ny", "actor": "Christopher Walken"}
# corrupt_corporate_executive	{"char": "Carter Burke", "movie": "Aliens", "id": "/m/0jt8n6", "actor": "Paul Reiser"}
# corrupt_corporate_executive	{"char": "Noah Cross", "movie": "Chinatown", "id": "/m/0jwcjw", "actor": "John Huston"}
# corrupt_corporate_executive	{"char": "Doctor Doom", "movie": "Fantastic Four", "id": "/m/0jy24c", "actor": "Julian McMahon"}
# corrupt_corporate_executive	{"char": "Kingpin", "movie": "Daredevil", "id": "/m/0jwz5q", "actor": "Michael Clarke Duncan"}
# corrupt_corporate_executive	{"char": "Judge Doom", "movie": "Who Framed Roger Rabbit", "id": "/m/0k81j_", "actor": "Christopher Lloyd"}
# corrupt_corporate_executive	{"char": "Conal Cochran", "movie": "Halloween III: Season of the Witch", "id": "/m/0jz33w", "actor": "Dan O'Herlihy"}
# corrupt_corporate_executive	{"char": "Mayor Augustus Maywho", "movie": "How the Grinch Stole Christmas!", "id": "/m/0jzmfp", "actor": "Jeffrey Tambor"}
# corrupt_corporate_executive	{"char": "Henry F. Potter", "movie": "It's a Wonderful Life", "id": "/m/0j_11c", "actor": "Lionel Barrymore"}
# corrupt_corporate_executive	{"char": "Royalton", "movie": "Speed Racer", "id": "/m/03jqz37", "actor": "Roger Allam"}
# corrupt_corporate_executive	{"char": "B.Z.", "movie": "Santa Claus: The Movie", "id": "/m/0k2w67", "actor": "John Lithgow"}
# corrupt_corporate_executive	{"char": "Les Grossman", "movie": "Tropic Thunder", "id": "/m/0gyjwgg", "actor": "Tom Cruise"}
# corrupt_corporate_executive	{"char": "James McCullen - 1641", "movie": "G.I. Joe: The Rise of Cobra", "id": "/m/0h5q191", "actor": "David Murray"}
# corrupt_corporate_executive	{"char": "Ed Dillinger", "movie": "Tron", "id": "/m/0k7cbx", "actor": "David Warner"}
# corrupt_corporate_executive	{"char": "Ian Hawke", "movie": "Alvin and the Chipmunks", "id": "/m/03kyztz", "actor": "David Cross"}
# corrupt_corporate_executive	{"char": "Jack Bennett", "movie": "Edge of Darkness", "id": "/m/08cwjsb", "actor": "Danny Huston"}
# corrupt_corporate_executive	{"char": "Charles Travis", "movie": "Congo", "id": "/m/02vclwl", "actor": "Bruce Campbell"}
# corrupt_corporate_executive	{"char": "Gary Winston", "movie": "Antitrust", "id": "/m/02vbk_v", "actor": "Tim Robbins"}
# corrupt_corporate_executive	{"char": "Dietrich Banning", "movie": "The Tuxedo", "id": "/m/0cgn58l", "actor": "Ritchie Coster"}
# corrupt_corporate_executive	{"char": "Ratchet", "movie": "Robots", "id": "/m/0k2mmy", "actor": "Greg Kinnear"}
# coward	{"char": "Beni Gabor", "movie": "The Mummy", "id": "/m/03jskk3", "actor": "Kevin J. O'Connor"}
# coward	{"char": "Lt. Roget / Singing man", "movie": "Paths of Glory", "id": "/m/0cc_884", "actor": "Wayne Morris"}
# coward	{"char": "Captain Jack Sparrow", "movie": "Pirates of the Caribbean: Dead Man's Chest", "id": "/m/0k1xxm", "actor": "Johnny Depp"}
# coward	{"char": "Carter Burke", "movie": "Aliens", "id": "/m/0jt8n6", "actor": "Paul Reiser"}
# coward	{"char": "Ike Clanton", "movie": "Tombstone", "id": "/m/0cg418l", "actor": "Stephen Lang"}
# coward	{"char": "Cpl. Timothy P. Upham", "movie": "Saving Private Ryan", "id": "/m/040qvsz", "actor": "Jeremy Davies"}
# crazy_jealous_guy	{"char": "Jake LaMotta", "movie": "Raging Bull", "id": "/m/0k28_g", "actor": "Robert De Niro"}
# crazy_jealous_guy	{"char": "Sir Alfred De Carter", "movie": "Unfaithfully Yours", "id": "/m/02vct43", "actor": "Rex Harrison"}
# crazy_jealous_guy	{"char": "Heathcliff", "movie": "Wuthering Heights", "id": "/m/0k86mc", "actor": "Laurence Olivier"}
# crazy_jealous_guy	{"char": "Alisdair Stewart", "movie": "The Piano", "id": "/m/0k63tb", "actor": "Sam Neill"}
# crazy_jealous_guy	{"char": "Dr. Stephen Fleming", "movie": "Damage", "id": "/m/0jwy3x", "actor": "Jeremy Irons"}
# crazy_jealous_guy	{"char": "Otto", "movie": "A Fish Called Wanda", "id": "/m/0jsqxv", "actor": "Kevin Kline"}
# crazy_jealous_guy	{"char": "Frank N. Furter", "movie": "The Rocky Horror Picture Show", "id": "/m/0k69_1", "actor": "Tim Curry"}
# crazy_jealous_guy	{"char": "David McCall", "movie": "Fear", "id": "/m/0jy3_h", "actor": "Mark Wahlberg"}
# crazy_jealous_guy	{"char": "Bud White", "movie": "L.A. Confidential", "id": "/m/0j_n0t", "actor": "Russell Crowe"}
# crazy_jealous_guy	{"char": "Tony Montana", "movie": "Scarface", "id": "/m/02_8_nx", "actor": "Al Pacino"}
# crazy_jealous_guy	{"char": "Martin Burney", "movie": "Sleeping with the Enemy", "id": "/m/0k3ddh", "actor": "Patrick Bergin"}
# crazy_jealous_guy	{"char": "Sam 'Ace' Rothstein", "movie": "Casino", "id": "/m/0jw4vx", "actor": "Robert De Niro"}
# crazy_jealous_guy	{"char": "Tommy DeVito", "movie": "Goodfellas", "id": "/m/0jyytb", "actor": "Joe Pesci"}
# crazy_jealous_guy	{"char": "John Lotter", "movie": "Boys Don't Cry", "id": "/m/0jvqzw", "actor": "Peter Sarsgaard"}
# crazy_jealous_guy	{"char": "Jake McKenna", "movie": "U Turn", "id": "/m/0k7gxk", "actor": "Nick Nolte"}
# crazy_jealous_guy	{"char": "Duke of Monroth", "movie": "Moulin Rouge!", "id": "/m/0k0vyn", "actor": "Richard Roxburgh"}
# crazy_jealous_guy	{"char": "Bill", "movie": "Kill Bill Volume 1", "id": "/m/0j_fvv", "actor": "David Carradine"}
# crazy_jealous_guy	{"char": "Bobby Tennison", "movie": "No One Would Tell", "id": "/m/0g9k2p6", "actor": "Fred Savage"}
# crazy_jealous_guy	{"char": "Johnny Farrell", "movie": "Gilda", "id": "/m/0jysmq", "actor": "Glenn Ford"}
# crazy_jealous_guy	{"char": "Takeo", "movie": "The Grudge", "id": "/m/0hgc9dq", "actor": "Takashi Matsuyama"}
# crazy_jealous_guy	{"char": "Guy", "movie": "Swimming with Sharks", "id": "/m/021_h9h", "actor": "Frank Whaley"}
# crazy_jealous_guy	{"char": "Blue", "movie": "Sucker Punch", "id": "/m/0850_tx", "actor": "Oscar Isaac"}
# crazy_jealous_guy	{"char": "Tony Wendice", "movie": "Dial M for Murder", "id": "/m/0jx7qr", "actor": "Ray Milland"}
# crazy_jealous_guy	{"char": "Steven Taylor", "movie": "A Perfect Murder", "id": "/m/0jsw40", "actor": "Michael Douglas"}
# crazy_jealous_guy	{"char": "Geoffrey Clifton", "movie": "The English Patient", "id": "/m/0k4_tz", "actor": "Colin Firth"}
# crazy_survivalist	{"char": "Harlan Ogilvy", "movie": "War of the Worlds", "id": "/m/0k7w6s", "actor": "Tim Robbins"}
# crazy_survivalist	{"char": "Eli", "movie": "The Book of Eli", "id": "/m/05nv915", "actor": "Denzel Washington"}
# crazy_survivalist	{"char": "Marvin Boggs", "movie": "Red", "id": "/m/0b7n5zy", "actor": "John Malkovich"}
# cultured_badass	{"char": "James Bond", "movie": "Casino Royale", "id": "/m/02hw79s", "actor": "Daniel Craig"}
# cultured_badass	{"char": "Dorian Gray", "movie": "The League of Extraordinary Gentlemen", "id": "/m/0dkcy1f", "actor": "Stuart Townsend"}
# cultured_badass	{"char": "Everett Hitch", "movie": "Appaloosa", "id": "/m/04601vx", "actor": "Viggo Mortensen"}
# cultured_badass	{"char": "Leopold", "movie": "Kate & Leopold", "id": "/m/02tb9_v", "actor": "Hugh Jackman"}
# cultured_badass	{"char": "Hannibal Lecter", "movie": "The Silence of the Lambs", "id": "/m/0k6g86", "actor": "Anthony Hopkins"}
# cultured_badass	{"char": "Ghost Dog", "movie": "Ghost Dog: The Way of the Samurai", "id": "/m/0jyr6h", "actor": "Forest Whitaker"}
# cultured_badass	{"char": "Dupont", "movie": "Equilibrium", "id": "/m/0jxwqx", "actor": "Angus Macfadyen"}
# cultured_badass	{"char": "Arthur Burns", "movie": "The Proposition", "id": "/m/0k66rt", "actor": "Danny Huston"}
# dean_bitterman	{"char": "Richard Vernon", "movie": "The Breakfast Club", "id": "/m/0k4l6b", "actor": "Paul Gleason"}
# dean_bitterman	{"char": "Ed Rooney", "movie": "Ferris Bueller's Day Off", "id": "/m/0jy52w", "actor": "Jeffrey Jones"}
# dean_bitterman	{"char": "Mr. Nolan", "movie": "Dead Poets Society", "id": "/m/0jx21w", "actor": "Norman Lloyd"}
# dean_bitterman	{"char": "Dean Richmond", "movie": "The Nutty Professor", "id": "/m/0k60j5", "actor": "Larry Miller"}
# dirty_cop	{"char": "Alonzo", "movie": "Training Day", "id": "/m/0k79b3", "actor": "Denzel Washington"}
# dirty_cop	{"char": "Dennis Peck", "movie": "Internal Affairs", "id": "/m/0jzyzv", "actor": "Richard Gere"}
# dirty_cop	{"char": "Colin Sullivan", "movie": "The Departed", "id": "/m/0k4xjq", "actor": "Matt Damon"}
# dirty_cop	{"char": "Police Captain Hank Quinlan", "movie": "Touch of Evil", "id": "/m/0k78gf", "actor": "Orson Welles"}
# dirty_cop	{"char": "Rooster", "movie": "Righteous Kill", "id": "/m/02vcq3r", "actor": "Al Pacino"}
# dirty_cop	{"char": "Abel Turner", "movie": "Lakeview Terrace", "id": "/m/02tb650", "actor": "Samuel L. Jackson"}
# dirty_cop	{"char": "The Lieutenant", "movie": "Bad Lieutenant", "id": "/m/0jtz28", "actor": "Harvey Keitel"}
# ditz	{"char": "Cher Horowitz", "movie": "Clueless", "id": "/m/0jwjsy", "actor": "Alicia Silverstone"}
# ditz	{"char": "Mr. Bean", "movie": "Mr. Bean's Holiday", "id": "/m/0jygqg", "actor": "Rowan Atkinson"}
# ditz	{"char": "Arthur Bach", "movie": "Arthur", "id": "/m/0ghdkxh", "actor": "Russell Brand"}
# ditz	{"char": "Nick", "movie": "30 Minutes or Less", "id": "/m/0gvd8dq", "actor": "Jesse Eisenberg"}
# ditz	{"char": "Henry Roth", "movie": "50 First Dates", "id": "/m/0jsll5", "actor": "Adam Sandler"}
# ditz	{"char": "Michael Newman", "movie": "Click", "id": "/m/0jwj2t", "actor": "Adam Sandler"}
# ditz	{"char": "Chuck Levine", "movie": "I Now Pronounce You Chuck and Larry", "id": "/m/02vbl__", "actor": "Adam Sandler"}
# doormat	{"char": "George McFly", "movie": "Back to the Future", "id": "/m/0jty5w", "actor": "Crispin Glover"}
# doormat	{"char": "Harry Dunne", "movie": "Dumb & Dumber", "id": "/m/0jxmxp", "actor": "Jeff Daniels"}
# doormat	{"char": "Belle", "movie": "Beauty and the Beast: The Enchanted Christmas", "id": "/m/0fprkm7", "actor": "Paige O'Hara"}
# doormat	{"char": "Stu Price", "movie": "The Hangover", "id": "/m/05srhg_", "actor": "Ed Helms"}
# drill_sargeant_nasty	{"char": "Gny. Sgt. Hartman", "movie": "Full Metal Jacket", "id": "/m/0jykjt", "actor": "R. Lee Ermey"}
# drill_sargeant_nasty	{"char": "Master Chief John James Urgayle", "movie": "G.I. Jane", "id": "/m/0jylf1", "actor": "Viggo Mortensen"}
# drill_sargeant_nasty	{"char": "Sgt. Hulka", "movie": "Stripes", "id": "/m/022108v", "actor": "Warren Oates"}
# drill_sargeant_nasty	{"char": "Sergeant Thomas Highway", "movie": "Heartbreak Ridge", "id": "/m/0jz8d6", "actor": "Clint Eastwood"}
# drill_sargeant_nasty	{"char": "Staff Sergeant Robert Barnes", "movie": "Platoon", "id": "/m/0k1yyt", "actor": "Tom Berenger"}
# drill_sargeant_nasty	{"char": "Maj. John Reisman", "movie": "The Dirty Dozen: The Next Mission", "id": "/m/0b78ft6", "actor": "Lee Marvin"}
# dumb_blonde	{"char": "Kitty Packard", "movie": "Dinner at Eight", "id": "/m/0jx9zj", "actor": "Jean Harlow"}
# dumb_blonde	{"char": "Cindy Campbell", "movie": "Scary Movie 4", "id": "/m/0k2y_7", "actor": "Anna Faris"}
# dumb_blonde	{"char": "Cindy Campbell", "movie": "Scary Movie 3", "id": "/m/0k2z05", "actor": "Anna Faris"}
# dumb_blonde	{"char": "Brandi", "movie": "Observe and Report", "id": "/m/059sp8v", "actor": "Anna Faris"}
# dumb_blonde	{"char": "Pola Debevoise", "movie": "How to Marry a Millionaire", "id": "/m/0jzmyb", "actor": "Marilyn Monroe"}
# dumb_blonde	{"char": "Romy White", "movie": "Romy and Michele's High School Reunion", "id": "/m/0k2p5c", "actor": "Mira Sorvino"}
# dumb_blonde	{"char": "Michele Weinberger", "movie": "Romy and Michele's High School Reunion", "id": "/m/0k2p5j", "actor": "Lisa Kudrow"}
# dumb_blonde	{"char": "Suzanne Stone Maretto", "movie": "To Die For", "id": "/m/0k75t3", "actor": "Nicole Kidman"}
# dumb_blonde	{"char": "Rocky Horror - A Creation", "movie": "The Rocky Horror Picture Show", "id": "/m/02tb6wq", "actor": "Peter Hinwood"}
# dumb_blonde	{"char": "Mia", "movie": "Stan Helsing", "id": "/m/0gc3g1p", "actor": "Desi Lydic"}
# dumb_blonde	{"char": "Lina Lamont", "movie": "Singin' in the Rain", "id": "/m/0k3b2r", "actor": "Jean Hagen"}
# dumb_muscle	{"char": "Lennie Pike", "movie": "It's a Mad, Mad, Mad, Mad World", "id": "/m/01z0cck", "actor": "Jonathan Winters"}
# dumb_muscle	{"char": "Mongo", "movie": "Blazing Saddles", "id": "/m/04w0vjn", "actor": "Alex Karras"}
# dumb_muscle	{"char": "Fezzik", "movie": "The Princess Bride", "id": "/m/0k65zh", "actor": "Andr\u00e9 the Giant"}
# dumb_muscle	{"char": "Karl Childers", "movie": "Sling Blade", "id": "/m/0k3dtt", "actor": "Billy Bob Thornton"}
# eccentric_mentor	{"char": "Aughra", "movie": "The Dark Crystal", "id": "/m/02vbpft", "actor": "Billie Whitelaw"}
# eccentric_mentor	{"char": "Mr. Kesuke Miyagi", "movie": "The Karate Kid", "id": "/m/0k5jxz", "actor": "Pat Morita"}
# eccentric_mentor	{"char": "Yoda", "movie": "Star Wars Episode V: The Empire Strikes Back", "id": "/m/02sg6hm", "actor": "Frank Oz"}
# eccentric_mentor	{"char": "Gandalf", "movie": "The Lord of the Rings: The Fellowship of the Ring", "id": "/m/0k5s9d", "actor": "Ian McKellen"}
# eccentric_mentor	{"char": "Fin Raziel", "movie": "Willow", "id": "/m/0k837x", "actor": "Patricia Hayes"}
# egomaniac_hunter	{"char": "Clayton", "movie": "Tarzan", "id": "/m/0k42s4", "actor": "Brian Blessed"}
# egomaniac_hunter	{"char": "Gaston", "movie": "Beauty and the Beast", "id": "/m/0jv4jc", "actor": "Richard White"}
# egomaniac_hunter	{"char": "Charles Muntz", "movie": "Up", "id": "/m/045_c9z", "actor": "Christopher Plummer"}
# egomaniac_hunter	{"char": "John Wilson", "movie": "White Hunter, Black Heart", "id": "/m/0k818w", "actor": "Clint Eastwood"}
# egomaniac_hunter	{"char": "Victor Quartermaine", "movie": "Wallace & Gromit: The Curse of the Were-Rabbit", "id": "/m/0k7vr9", "actor": "Ralph Fiennes"}
# egomaniac_hunter	{"char": "The Predator", "movie": "Predator 2", "id": "/m/03lpp78", "actor": "Kevin Peter Hall"}
# egomaniac_hunter	{"char": "The Predator", "movie": "Predator", "id": "/m/0h34xg2", "actor": "Peter Cullen"}
# evil_prince	{"char": "Prince Yu", "movie": "Curse of the Golden Flower", "id": "/m/0gbxx9x", "actor": "Junjie Qin"}
# evil_prince	{"char": "Crown Prince Leopold", "movie": "The Illusionist", "id": "/m/0k5f_q", "actor": "Rufus Sewell"}
# evil_prince	{"char": "Commodus", "movie": "Gladiator", "id": "/m/0jytd4", "actor": "Joaquin Phoenix"}
# evil_prince	{"char": "Lord Nelson Rathbone", "movie": "Shanghai Knights", "id": "/m/02vd4f4", "actor": "Aidan Gillen"}
# evil_prince	{"char": "Prince Nuada", "movie": "Hellboy 2: The Golden Army", "id": "/m/04m9lhl", "actor": "Luke Goss"}
# evil_prince	{"char": "Nizam", "movie": "Prince of Persia: The Sands of Time", "id": "/m/04m5488", "actor": "Ben Kingsley"}
# evil_prince	{"char": "Prince Otwani", "movie": "Sheena", "id": "/m/0k36bq", "actor": "Trevor Thomas"}
# evil_prince	{"char": "Prince Humperdinck", "movie": "The Princess Bride", "id": "/m/0k65z0", "actor": "Chris Sarandon"}
# fastest_gun_in_the_west	{"char": "Jim", "movie": "Blazing Saddles", "id": "/m/0jvhqr", "actor": "Gene Wilder"}
# fastest_gun_in_the_west	{"char": "Bret Maverick", "movie": "Maverick", "id": "/m/0k0hyr", "actor": "Mel Gibson"}
# fastest_gun_in_the_west	{"char": "Ned Nederlander", "movie": "\u00a1Three Amigos!", "id": "/m/0jshd9", "actor": "Martin Short"}
# fastest_gun_in_the_west	{"char": "Harmonica", "movie": "Once Upon a Time in the West", "id": "/m/0k1j46", "actor": "Charles Bronson"}
# fastest_gun_in_the_west	{"char": "Sheriff Woody", "movie": "Toy Story", "id": "/m/0k78tv", "actor": "Tom Hanks"}
# fastest_gun_in_the_west	{"char": "Ben Wade", "movie": "3:10 to Yuma", "id": "/m/03hqy08", "actor": "Russell Crowe"}
# fastest_gun_in_the_west	{"char": "RoboCop", "movie": "RoboCop", "id": "/m/0h5q82q", "actor": "Peter Weller"}
# father_to_his_men	{"char": "Capt. Mikhail Polenin", "movie": "K-19: The Widowmaker", "id": "/m/0j_9gv", "actor": "Liam Neeson"}
# father_to_his_men	{"char": "Capt. Nathan Cutting Brittles", "movie": "She Wore a Yellow Ribbon", "id": "/m/0k35w2", "actor": "John Wayne"}
# father_to_his_men	{"char": "Maximus Decimus Meridius", "movie": "Gladiator", "id": "/m/0jytc_", "actor": "Russell Crowe"}
# father_to_his_men	{"char": "Jack Aubrey", "movie": "Master and Commander: The Far Side of the World", "id": "/m/0k0h66", "actor": "Russell Crowe"}
# father_to_his_men	{"char": "Captain Benjamin L. Willard", "movie": "Apocalypse Now", "id": "/m/0jtp2f", "actor": "Martin Sheen"}
# father_to_his_men	{"char": "Captain of the 'Weser'", "movie": "Das Boot", "id": "/m/0j47kxy", "actor": "G\u00fcnter Lamprecht"}
# father_to_his_men	{"char": "Captain Nemo", "movie": "The League of Extraordinary Gentlemen", "id": "/m/0k5nrw", "actor": "Naseeruddin Shah"}
# father_to_his_men	{"char": "Capt. James 'Bugger' Staros", "movie": "The Thin Red Line", "id": "/m/0k6nwg", "actor": "Elias Koteas"}
# father_to_his_men	{"char": "Gen. Robert E. Lee", "movie": "Gettysburg", "id": "/m/0jyqwm", "actor": "Martin Sheen"}
# father_to_his_men	{"char": "General Kuribayashi", "movie": "Letters from Iwo Jima", "id": "/m/03jtctp", "actor": "Ken Watanabe"}
# father_to_his_men	{"char": "Lt. Commander Ron Hunter", "movie": "Crimson Tide", "id": "/m/0jwsnp", "actor": "Denzel Washington"}
# father_to_his_men	{"char": "Christopher Pike", "movie": "Star Trek", "id": "/m/03ld2yg", "actor": "Bruce Greenwood"}
# father_to_his_men	{"char": "Zordon", "movie": "Mighty Morphin' Power Rangers: The Movie", "id": "/m/0k0nmw", "actor": "Nicholas Bell"}
# father_to_his_men	{"char": "Wolfstan", "movie": "Black Death", "id": "/m/0cg03cg", "actor": "John Lynch"}
# father_to_his_men	{"char": "Major Henry West", "movie": "28 Days Later", "id": "/m/0jskmk", "actor": "Christopher Eccleston"}
# final_girl	{"char": "Nancy Thompson", "movie": "A Nightmare on Elm Street", "id": "/m/0jsvgr", "actor": "Heather Langenkamp"}
# final_girl	{"char": "Sidney Prescott", "movie": "Scream", "id": "/m/0k2_bc", "actor": "Neve Campbell"}
# final_girl	{"char": "Ellen Ripley", "movie": "Alien", "id": "/m/0jt7sz", "actor": "Sigourney Weaver"}
# final_girl	{"char": "Sarah Connor", "movie": "The Terminator", "id": "/m/0k6m_h", "actor": "Linda Hamilton"}
# final_girl	{"char": "Laurie Strode", "movie": "Halloween", "id": "/m/0jz2x0", "actor": "Jamie Lee Curtis"}
# final_girl	{"char": "Whitney Miller", "movie": "Friday the 13th", "id": "/m/04ls8ty", "actor": "Amanda Righetti"}
# gadgeteer_genius	{"char": "Tony Stark", "movie": "Iron Man", "id": "/m/0j1__hv", "actor": "Robert Downey Jr."}
# gadgeteer_genius	{"char": "Dr. Loveless", "movie": "Wild Wild West", "id": "/m/0k82tm", "actor": "Kenneth Branagh"}
# gadgeteer_genius	{"char": "Artemus Gordon", "movie": "Wild Wild West", "id": "/m/0k82tg", "actor": "Kevin Kline"}
# gadgeteer_genius	{"char": "Lewis", "movie": "Meet the Robinsons", "id": "/m/0k0kn_", "actor": "Tom Selleck"}
# gadgeteer_genius	{"char": "Anakin Skywalker", "movie": "Star Wars Episode I: The Phantom Menace", "id": "/m/02sg5rn", "actor": "Jake Lloyd"}
# gadgeteer_genius	{"char": "Ling Ling Fat", "movie": "Forbidden City Cop", "id": "/m/02vb6nv", "actor": "Stephen Chow"}
# gadgeteer_genius	{"char": "Lucius Fox", "movie": "The Dark Knight", "id": "/m/045yrqg", "actor": "Morgan Freeman"}
# gentleman_thief	{"char": "John Robie", "movie": "To Catch a Thief", "id": "/m/0k75r_", "actor": "Cary Grant"}
# gentleman_thief	{"char": "Sir Charles Lytton", "movie": "The Pink Panther", "id": "/m/0k63yr", "actor": "David Niven"}
# gentleman_thief	{"char": "Neil McCauley", "movie": "Heat", "id": "/m/0jz8sq", "actor": "Robert De Niro"}
# gentleman_thief	{"char": "Rodney Skinner", "movie": "The League of Extraordinary Gentlemen", "id": "/m/0k5ns5", "actor": "Tony Curran"}
# gentleman_thief	{"char": "Cobb", "movie": "Inception", "id": "/m/0667g_f", "actor": "Leonardo DiCaprio"}
# gentleman_thief	{"char": "Nick Wells", "movie": "The Score", "id": "/m/0k6d1f", "actor": "Robert De Niro"}
# granola_person	{"char": "Beth", "movie": "John Tucker Must Die", "id": "/m/0j_6h2", "actor": "Sophia Bush"}
# granola_person	{"char": "Jasper Palmer", "movie": "Children of Men", "id": "/m/0jwbh7", "actor": "Michael Caine"}
# granola_person	{"char": "Max Dennison", "movie": "Hocus Pocus", "id": "/m/02vd92w", "actor": "Omri Katz"}
# granola_person	{"char": "Lotte Schwartz", "movie": "Being John Malkovich", "id": "/m/0jv6mp", "actor": "Cameron Diaz"}
# granola_person	{"char": "Ana Pascal", "movie": "Stranger Than Fiction", "id": "/m/0k3t_x", "actor": "Maggie Gyllenhaal"}
# granola_person	{"char": "Ashley", "movie": "Orange County", "id": "/m/0k1m4g", "actor": "Schuyler Fisk"}
# granola_person	{"char": "Sheldon Mopes", "movie": "Death to Smoochy", "id": "/m/0jx3b8", "actor": "Edward Norton"}
# granola_person	{"char": "Bill Django", "movie": "The Men Who Stare at Goats", "id": "/m/06679y8", "actor": "Jeff Bridges"}
# grumpy_old_man	{"char": "Max Goldman", "movie": "Grumpy Old Men", "id": "/m/02vcwz0", "actor": "Walter Matthau"}
# grumpy_old_man	{"char": "Walt Kowalski", "movie": "Gran Torino", "id": "/m/059t435", "actor": "Clint Eastwood"}
# grumpy_old_man	{"char": "Carl Fredricksen", "movie": "Up", "id": "/m/045_cb3", "actor": "Ed Asner"}
# grumpy_old_man	{"char": "Howard Beale", "movie": "Network", "id": "/m/0k168v", "actor": "Peter Finch"}
# grumpy_old_man	{"char": "Judge Elihu Smails", "movie": "Caddyshack", "id": "/m/04w0v_v", "actor": "Ted Knight"}
# hardboiled_detective	{"char": "Sam Spade", "movie": "The Maltese Falcon", "id": "/m/04dmkpj", "actor": "Humphrey Bogart"}
# hardboiled_detective	{"char": "Philip Marlowe", "movie": "The Big Sleep", "id": "/m/0k4gwm", "actor": "Humphrey Bogart"}
# hardboiled_detective	{"char": "Dist. Atty. Martin Ferguson", "movie": "The Enforcer", "id": "/m/0k4_sm", "actor": "Humphrey Bogart"}
# hardboiled_detective	{"char": "Capt. 'Rip' Murdock", "movie": "Dead Reckoning", "id": "/m/0jx253", "actor": "Humphrey Bogart"}
# hardboiled_detective	{"char": "Jeff Bailey", "movie": "Out of the Past", "id": "/m/0k1nzj", "actor": "Robert Mitchum"}
# hardboiled_detective	{"char": "J. J. Gittes", "movie": "Chinatown", "id": "/m/0jwcjk", "actor": "Jack Nicholson"}
# hardboiled_detective	{"char": "Eddie Valiant", "movie": "Who Framed Roger Rabbit", "id": "/m/0k81jp", "actor": "Bob Hoskins"}
# hardboiled_detective	{"char": "Rick Deckard", "movie": "Blade Runner", "id": "/m/0jvhbm", "actor": "Harrison Ford"}
# heartbroken_badass	{"char": "Mina Harker", "movie": "The League of Extraordinary Gentlemen", "id": "/m/0k5ns0", "actor": "Peta Wilson"}
# heartbroken_badass	{"char": "James Bond", "movie": "Quantum of Solace", "id": "/m/03hqwg_", "actor": "Daniel Craig"}
# heartbroken_badass	{"char": "Max Rockatansky", "movie": "Mad Max", "id": "/m/0k09b2", "actor": "Mel Gibson"}
# heartbroken_badass	{"char": "Josey Wales", "movie": "The Outlaw Josey Wales", "id": "/m/0k61jr", "actor": "Clint Eastwood"}
# heartbroken_badass	{"char": "Tallahassee", "movie": "Zombieland", "id": "/m/05skv28", "actor": "Woody Harrelson"}
# heartbroken_badass	{"char": "Bruce Wayne", "movie": "The Dark Knight Rises", "id": "/m/0n4g1dv", "actor": "Christian Bale"}
# heartbroken_badass	{"char": "Bill", "movie": "Kill Bill Volume 1", "id": "/m/0j_fvv", "actor": "David Carradine"}
# henpecked_husband	{"char": "Norbit", "movie": "Norbit", "id": "/m/01z0rf5", "actor": "Eddie Murphy"}
# henpecked_husband	{"char": "Bobby Davis", "movie": "Wild Hogs", "id": "/m/0256cyz", "actor": "Martin Lawrence"}
# henpecked_husband	{"char": "Dr. Ernest Menville", "movie": "Death Becomes Her", "id": "/m/0jx2_4", "actor": "Bruce Willis"}
# henpecked_husband	{"char": "Dr. Howard Bannister", "movie": "What's Up, Doc?", "id": "/m/0k7_cy", "actor": "Ryan O'Neal"}
# henpecked_husband	{"char": "Ned Schneebly", "movie": "School of Rock", "id": "/m/0k2zjr", "actor": "Mike White"}
# hitman_with_a_heart	{"char": "Julian Noble", "movie": "The Matador", "id": "/m/0k5wt7", "actor": "Pierce Brosnan"}
# hitman_with_a_heart	{"char": "Ghost Dog", "movie": "Ghost Dog: The Way of the Samurai", "id": "/m/0jyr6h", "actor": "Forest Whitaker"}
# hitman_with_a_heart	{"char": "Jimmy 'The Tulip' Tudeski", "movie": "The Whole Nine Yards", "id": "/m/0k6x0x", "actor": "Bruce Willis"}
# hitman_with_a_heart	{"char": "Mr. Goodkat", "movie": "Lucky Number Slevin", "id": "/m/0k087f", "actor": "Bruce Willis"}
# hitman_with_a_heart	{"char": "John Lee", "movie": "The Replacement Killers", "id": "/m/0k68kd", "actor": "Chow Yun-Fat"}
# hitman_with_a_heart	{"char": "Il Duce", "movie": "The Boondock Saints", "id": "/m/0k4k6j", "actor": "Billy Connolly"}
# hitman_with_a_heart	{"char": "Jason Bourne", "movie": "The Bourne Identity", "id": "/m/0k4kcz", "actor": "Matt Damon"}
# hitman_with_a_heart	{"char": "Frank Falenczyk", "movie": "You Kill Me", "id": "/m/02vb7cx", "actor": "Ben Kingsley"}
# hitman_with_a_heart	{"char": "Wesley Gibson", "movie": "Wanted", "id": "/m/02vb_l5", "actor": "James McAvoy"}
# hitman_with_a_heart	{"char": "Vincent", "movie": "Collateral", "id": "/m/0jwkz6", "actor": "Tom Cruise"}
# jerk_jock	{"char": "Austin", "movie": "Not Another Teen Movie", "id": "/m/0k1cs5", "actor": "Eric Christian Olsen"}
# jerk_jock	{"char": "Johnny Lawrence", "movie": "The Karate Kid", "id": "/m/0k5jyf", "actor": "William Zabka"}
# jerk_jock	{"char": "Gaston", "movie": "Beauty and the Beast", "id": "/m/0jv4jc", "actor": "Richard White"}
# jerk_jock	{"char": "Jim", "movie": "Edward Scissorhands", "id": "/m/0jxqwd", "actor": "Anthony Michael Hall"}
# jerk_jock	{"char": "Biff Tannen", "movie": "Back to the Future", "id": "/m/0jty60", "actor": "Thomas F. Wilson"}
# jerk_jock	{"char": "Kurt Kelly", "movie": "Heathers", "id": "/m/0h5slxp", "actor": "Lance Fenton"}
# jerk_jock	{"char": "Bo", "movie": "Cursed", "id": "/m/0jwwhw", "actor": "Milo Ventimiglia"}
# jerk_jock	{"char": "Mike Dexter", "movie": "Can't Hardly Wait", "id": "/m/03jsnmf", "actor": "Peter Facinelli"}
# jerk_jock	{"char": "Garth", "movie": "Alpha and Omega", "id": "/m/0d2jcym", "actor": "Chris Carmack"}
# junkie_prophet	{"char": "Agatha", "movie": "Minority Report", "id": "/m/0k0pgt", "actor": "Samantha Morton"}
# junkie_prophet	{"char": "Cassie Holmes", "movie": "Push", "id": "/m/040kc5w", "actor": "Dakota Fanning"}
# klutz	{"char": "Mia Thermopolis", "movie": "The Princess Diaries", "id": "/m/02vbfh2", "actor": "Anne Hathaway"}
# klutz	{"char": "Seymour Krelborn", "movie": "Little Shop of Horrors", "id": "/m/0k020r", "actor": "Rick Moranis"}
# loser_protagonist	{"char": "Paul Blart", "movie": "Paul Blart: Mall Cop", "id": "/m/059sm0m", "actor": "Kevin James"}
# loser_protagonist	{"char": "Sidney Young", "movie": "How to Lose Friends & Alienate People", "id": "/m/040l_q8", "actor": "Simon Pegg"}
# loser_protagonist	{"char": "Dennis", "movie": "Run, Fat Boy, Run", "id": "/m/03lvx8n", "actor": "Simon Pegg"}
# loser_protagonist	{"char": "Mark Bellison", "movie": "The Invention of Lying", "id": "/m/062xh9l", "actor": "Ricky Gervais"}
# loser_protagonist	{"char": "Dewey Finn", "movie": "School of Rock", "id": "/m/0k2zjf", "actor": "Jack Black"}
# loser_protagonist	{"char": "Rob Gordon", "movie": "High Fidelity", "id": "/m/02vb_jp", "actor": "John Cusack"}
# loveable_rogue	{"char": "Han Solo", "movie": "Star Wars Episode IV: A New Hope", "id": "/m/0k3r1_", "actor": "Harrison Ford"}
# loveable_rogue	{"char": "Captain Jack Sparrow", "movie": "Pirates of the Caribbean: Dead Man's Chest", "id": "/m/0k1xxm", "actor": "Johnny Depp"}
# loveable_rogue	{"char": "Peter Blood", "movie": "Captain Blood", "id": "/m/02vb_m3", "actor": "Errol Flynn"}
# loveable_rogue	{"char": "Capt. Louis Renault", "movie": "Casablanca", "id": "/m/05286qg", "actor": "Claude Rains"}
# loveable_rogue	{"char": "Abu", "movie": "The Thief of Bagdad", "id": "/m/0k6nkk", "actor": "Sabu Dastagir"}
# loveable_rogue	{"char": "Eames", "movie": "Inception", "id": "/m/07lkzl3", "actor": "Tom Hardy"}
# loveable_rogue	{"char": "Rodney Skinner", "movie": "The League of Extraordinary Gentlemen", "id": "/m/0k5ns5", "actor": "Tony Curran"}
# loveable_rogue	{"char": "Harold Hill", "movie": "The Music Man", "id": "/m/04hv61w", "actor": "Matthew Broderick"}
# loveable_rogue	{"char": "Wolverine", "movie": "X-Men", "id": "/m/0k86q4", "actor": "Hugh Jackman"}
# master_swordsman	{"char": "Qui-Gon Jinn", "movie": "Star Wars Episode I: The Phantom Menace", "id": "/m/0k3qyf", "actor": "Liam Neeson"}
# master_swordsman	{"char": "Obi-Wan Kenobi", "movie": "Star Wars Episode I: The Phantom Menace", "id": "/m/0k3qy3", "actor": "Ewan McGregor"}
# master_swordsman	{"char": "Darth Vader", "movie": "Star Wars Episode V: The Empire Strikes Back", "id": "/m/02nwtmm", "actor": "James Earl Jones"}
# master_swordsman	{"char": "Inigo Montoya", "movie": "The Princess Bride", "id": "/m/0k65z5", "actor": "Mandy Patinkin"}
# master_swordsman	{"char": "Bill", "movie": "Kill Bill Volume 1", "id": "/m/0j_fvv", "actor": "David Carradine"}
# master_swordsman	{"char": "Archibald Cunningham", "movie": "Rob Roy", "id": "/m/0k2ltj", "actor": "Tim Roth"}
# master_swordsman	{"char": "Madmartigan", "movie": "Willow", "id": "/m/0k8378", "actor": "Val Kilmer"}
# master_swordsman	{"char": "Nameless", "movie": "Hero", "id": "/m/0jzcr5", "actor": "Jet Li"}
# master_swordsman	{"char": "Broken Sword", "movie": "Hero", "id": "/m/0jzcrb", "actor": "Tony Leung Chiu Wai"}
# master_swordsman	{"char": "Aragorn", "movie": "The Lord of the Rings: The Return of the King", "id": "/m/0k5scp", "actor": "Viggo Mortensen"}
# master_swordsman	{"char": "Blade", "movie": "Blade", "id": "/m/0jvh78", "actor": "Wesley Snipes"}
# master_swordsman	{"char": "He-Man", "movie": "Masters of the Universe", "id": "/m/0k0h9d", "actor": "Dolph Lundgren"}
# morally_bankrupt_banker	{"char": "Mr. Perkins", "movie": "Despicable Me", "id": "/m/06zzgw6", "actor": "Will Arnett"}
# morally_bankrupt_banker	{"char": "Patrick Bateman", "movie": "American Psycho", "id": "/m/0jtfcj", "actor": "Christian Bale"}
# morally_bankrupt_banker	{"char": "Henry F. Potter", "movie": "It's a Wonderful Life", "id": "/m/0j_11c", "actor": "Lionel Barrymore"}
# officer_and_a_gentleman	{"char": "Norrington", "movie": "Pirates of the Caribbean: Dead Man's Chest", "id": "/m/0k1xyd", "actor": "Jack Davenport"}
# officer_and_a_gentleman	{"char": "Col. Robert Gould Shaw", "movie": "Glory", "id": "/m/0jyts_", "actor": "Matthew Broderick"}
# officer_and_a_gentleman	{"char": "Jack Aubrey", "movie": "Master and Commander: The Far Side of the World", "id": "/m/0k0h66", "actor": "Russell Crowe"}
# officer_and_a_gentleman	{"char": "Captain Nicholls", "movie": "War Horse", "id": "/m/0gkcn1g", "actor": "Tom Hiddleston"}
# ophelia	{"char": "Elisabeth Burrows", "movie": "Don't Say a Word", "id": "/m/0jxfnl", "actor": "Brittany Murphy"}
# ophelia	{"char": "Crazy Cora", "movie": "Quigley Down Under", "id": "/m/02tb5g1", "actor": "Laura San Giacomo"}
# ophelia	{"char": "Justine", "movie": "Melancholia", "id": "/m/0gkj0cn", "actor": "Kirsten Dunst"}
# ophelia	{"char": "Gina Montana", "movie": "Scarface", "id": "/m/0k2ysf", "actor": "Mary Elizabeth Mastrantonio"}
# ophelia	{"char": "Jane Olsen", "movie": "The Cabinet of Dr. Caligari", "id": "/m/08cqh60", "actor": "Lil Dagover"}
# playful_hacker	{"char": "Kevin Flynn", "movie": "Tron", "id": "/m/0k7cbl", "actor": "Jeff Bridges"}
# playful_hacker	{"char": "Sam Flynn", "movie": "Tron: Legacy", "id": "/m/062y97x", "actor": "Garrett Hedlund"}
# playful_hacker	{"char": "Riley Poole", "movie": "National Treasure", "id": "/m/0k14vc", "actor": "Justin Bartha"}
# playful_hacker	{"char": "David Lightman", "movie": "WarGames", "id": "/m/0k7w8p", "actor": "Matthew Broderick"}
# playful_hacker	{"char": "Mr. Universe", "movie": "Serenity", "id": "/m/0k31lb", "actor": "David Krumholtz"}
# prima_donna	{"char": "Lina Lamont", "movie": "Singin' in the Rain", "id": "/m/0k3b2r", "actor": "Jean Hagen"}
# prima_donna	{"char": "Sharpay Evans", "movie": "High School Musical", "id": "/m/0jzdz2", "actor": "Ashley Tisdale"}
# prima_donna	{"char": "Sharpay Evans", "movie": "High School Musical 2", "id": "/m/02vc3dx", "actor": "Ashley Tisdale"}
# prima_donna	{"char": "Sharpay Evans", "movie": "High School Musical 3: Senior Year", "id": "/m/03lyytc", "actor": "Ashley Tisdale"}
# prima_donna	{"char": "Margo Channing", "movie": "All About Eve", "id": "/m/0jt8y2", "actor": "Bette Davis"}
# prima_donna	{"char": "Norma Desmond", "movie": "Sunset Boulevard", "id": "/m/0k3ybb", "actor": "Gloria Swanson"}
# psycho_for_hire	{"char": "Gaear Grimsrud", "movie": "Fargo", "id": "/m/0jy2x0", "actor": "Peter Stormare"}
# psycho_for_hire	{"char": "Harlen Maguire", "movie": "Road to Perdition", "id": "/m/0k2ljt", "actor": "Jude Law"}
# psycho_for_hire	{"char": "Mr. Blonde", "movie": "Reservoir Dogs", "id": "/m/0k2ggy", "actor": "Michael Madsen"}
# psycho_for_hire	{"char": "Red Grant", "movie": "From Russia with Love", "id": "/m/04p7pxj", "actor": "Robert Shaw"}
# psycho_for_hire	{"char": "Anton Chigurh", "movie": "No Country for Old Men", "id": "/m/03lgvz6", "actor": "Javier Bardem"}
# psycho_for_hire	{"char": "Jackson Rippner", "movie": "Red Eye", "id": "/m/0k2dm9", "actor": "Cillian Murphy"}
# psycho_for_hire	{"char": "Staff Sergeant Robert Barnes", "movie": "Platoon", "id": "/m/0k1yyt", "actor": "Tom Berenger"}
# psycho_for_hire	{"char": "George Higgins", "movie": "8mm", "id": "/m/03jsz47", "actor": "Chris Bauer"}
# psycho_for_hire	{"char": "Major Arnold Toht", "movie": "Indiana Jones and the Raiders of the Lost Ark", "id": "/m/02nwzyz", "actor": "Ronald Lacey"}
# psycho_for_hire	{"char": "Mortimer Brewster", "movie": "Arsenic and Old Lace", "id": "/m/0jtr3s", "actor": "Cary Grant"}
# psycho_for_hire	{"char": "Col. Paul Tanner", "movie": "My Fellow Americans", "id": "/m/04q604c", "actor": "Everett McGill"}
# psycho_for_hire	{"char": "Bullet Tooth Tony", "movie": "Snatch", "id": "/m/0k3gbw", "actor": "Vinnie Jones"}
# psycho_for_hire	{"char": "Waingro", "movie": "Heat", "id": "/m/03jrl1d", "actor": "Kevin Gage"}
# psycho_for_hire	{"char": "Jack Wilson", "movie": "Shane", "id": "/m/0k34x6", "actor": "Jack Palance"}
# psycho_for_hire	{"char": "Isaacs", "movie": "Hanna", "id": "/m/0gh94vc", "actor": "Tom Hollander"}
# psycho_for_hire	{"char": "Frank", "movie": "Once Upon a Time in the West", "id": "/m/0k1j4j", "actor": "Henry Fonda"}
# pupil_turned_to_evil	{"char": "Count Dooku", "movie": "Star Wars Episode II: Attack of the Clones", "id": "/m/0k3q_8", "actor": "Christopher Lee"}
# pupil_turned_to_evil	{"char": "Aaron Hallam", "movie": "The Hunted", "id": "/m/03ls4jv", "actor": "Benicio del Toro"}
# retired_outlaw	{"char": "William Munny", "movie": "Unforgiven", "id": "/m/0k7l31", "actor": "Clint Eastwood"}
# retired_outlaw	{"char": "Ned Logan", "movie": "Unforgiven", "id": "/m/04xg29q", "actor": "Morgan Freeman"}
# retired_outlaw	{"char": "Butch Cassidy", "movie": "Butch Cassidy and the Sundance Kid", "id": "/m/04ky2tz", "actor": "Paul Newman"}
# retired_outlaw	{"char": "The Sundance Kid", "movie": "Butch Cassidy and the Sundance Kid", "id": "/m/0jvzx9", "actor": "Robert Redford"}
# retired_outlaw	{"char": "Patrick Floyd 'Pat' Garrett", "movie": "Young Guns II", "id": "/m/03jsysn", "actor": "William Petersen"}
# retired_outlaw	{"char": "Roy O'Bannon", "movie": "Shanghai Noon", "id": "/m/0k34yw", "actor": "Owen Wilson"}
# revenge	{"char": "Inigo Montoya", "movie": "The Princess Bride", "id": "/m/0k65z5", "actor": "Mandy Patinkin"}
# revenge	{"char": "Khan Noonien Singh", "movie": "Star Trek II: The Wrath of Khan", "id": "/m/02h8fyx", "actor": "Ricardo Montalb\u00e1n"}
# revenge	{"char": "Col. Douglas Mortimer", "movie": "For a Few Dollars More", "id": "/m/0jybsw", "actor": "Lee Van Cleef"}
# revenge	{"char": "Leonard", "movie": "Memento", "id": "/m/0k0l33", "actor": "Guy Pearce"}
# revenge	{"char": "Harmonica", "movie": "Once Upon a Time in the West", "id": "/m/0k1j46", "actor": "Charles Bronson"}
# revenge	{"char": "Conan the Barbarian", "movie": "Conan the Destroyer", "id": "/m/0jwmfk", "actor": "Arnold Schwarzenegger"}
# romantic_runnerup	{"char": "Lon Hammond Jr.", "movie": "The Notebook", "id": "/m/04lsjwd", "actor": "James Marsden"}
# romantic_runnerup	{"char": "Prince Edward", "movie": "Enchanted", "id": "/m/0jxvm9", "actor": "James Marsden"}
# romantic_runnerup	{"char": "James Norrington", "movie": "Pirates of the Caribbean: At World's End", "id": "/m/0k1xw3", "actor": "Jack Davenport"}
# romantic_runnerup	{"char": "Julian Mercer", "movie": "Something's Gotta Give", "id": "/m/0k3jn6", "actor": "Keanu Reeves"}
# romantic_runnerup	{"char": "Michael Grates", "movie": "Reality Bites", "id": "/m/0k2ct2", "actor": "Ben Stiller"}
# romantic_runnerup	{"char": "Proteus", "movie": "Sinbad: Legend of the Seven Seas", "id": "/m/02vc177", "actor": "Joseph Fiennes"}
# self_made_man	{"char": "George Kittredge", "movie": "The Philadelphia Story", "id": "/m/0h6f8kc", "actor": "John Howard"}
# self_made_man	{"char": "Roger Callaway", "movie": "It Takes Two", "id": "/m/0j_0s0", "actor": "Steve Guttenberg"}
# self_made_man	{"char": "Daniel \"Rudy\" Ruettiger", "movie": "Rudy", "id": "/m/02tb8j3", "actor": "Sean Astin"}
# slacker	{"char": "Brodie Bruce", "movie": "Mallrats", "id": "/m/07ldy8x", "actor": "Jason Lee"}
# slacker	{"char": "Dale Denton", "movie": "Pineapple Express", "id": "/m/02t9zmj", "actor": "Seth Rogen"}
# slacker	{"char": "Ben Stone", "movie": "Knocked Up", "id": "/m/0j_ks0", "actor": "Seth Rogen"}
# slacker	{"char": "Shaun", "movie": "Shaun of the Dead", "id": "/m/0k35n0", "actor": "Simon Pegg"}
# slacker	{"char": "Kumar Patel", "movie": "Harold & Kumar Go to White Castle", "id": "/m/0jz5zx", "actor": "Kal Penn"}
# slacker	{"char": "Kumar Patel", "movie": "Harold & Kumar Escape from Guantanamo Bay", "id": "/m/02vdfc2", "actor": "Kal Penn"}
# slacker	{"char": "Romy White", "movie": "Romy and Michele's High School Reunion", "id": "/m/0k2p5c", "actor": "Mira Sorvino"}
# slacker	{"char": "Michele Weinberger", "movie": "Romy and Michele's High School Reunion", "id": "/m/0k2p5j", "actor": "Lisa Kudrow"}
# slacker	{"char": "John Winger", "movie": "Stripes", "id": "/m/0k3w4y", "actor": "Bill Murray"}
# slacker	{"char": "Dewey Finn", "movie": "School of Rock", "id": "/m/0k2zjf", "actor": "Jack Black"}
# slacker	{"char": "Aram Finklestein", "movie": "The Rebound", "id": "/m/064yxrp", "actor": "Justin Bartha"}
# stoner	{"char": "Jay", "movie": "Dogma", "id": "/m/0jxdkm", "actor": "Jason Mewes"}
# stoner	{"char": "Bill S. Preston, Esq.", "movie": "Bill & Ted's Excellent Adventure", "id": "/m/0jvcqm", "actor": "Alex Winter"}
# stoner	{"char": "Ted \"Theodore\" Logan", "movie": "Bill & Ted's Excellent Adventure", "id": "/m/0jvcqg", "actor": "Keanu Reeves"}
# stoner	{"char": "Jeff Spicoli", "movie": "Fast Times at Ridgemont High", "id": "/m/0jy30b", "actor": "Sean Penn"}
# stoner	{"char": "Luke Shapiro", "movie": "The Wackness", "id": "/m/040lm10", "actor": "Josh Peck"}
# stoner	{"char": "Kumar Patel", "movie": "Harold & Kumar Go to White Castle", "id": "/m/0jz5zx", "actor": "Kal Penn"}
# stoner	{"char": "Harold Lee", "movie": "Harold & Kumar Go to White Castle", "id": "/m/0jz5zr", "actor": "John Cho"}
# stoner	{"char": "Dale Denton", "movie": "Pineapple Express", "id": "/m/02t9zmj", "actor": "Seth Rogen"}
# stoner	{"char": "Red", "movie": "Pineapple Express", "id": "/m/04zk2_k", "actor": "Danny McBride"}
# stoner	{"char": "Saul Silver", "movie": "Pineapple Express", "id": "/m/02vb3yc", "actor": "James Franco"}
# stoner	{"char": "Thadeous", "movie": "Your Highness", "id": "/m/07zm_ym", "actor": "Danny McBride"}
# stoner	{"char": "Fabious", "movie": "Your Highness", "id": "/m/07zm_zv", "actor": "James Franco"}
# stoner	{"char": "Marty Mikalski", "movie": "The Cabin in the Woods", "id": "/m/083z84s", "actor": "Fran Kranz"}
# storyteller	{"char": "Dilios", "movie": "300", "id": "/m/0jsg_x", "actor": "David Wenham"}
# storyteller	{"char": "Ed Bloom - Young", "movie": "Big Fish", "id": "/m/0jvbkh", "actor": "Ewan McGregor"}
# storyteller	{"char": "Garth McCann", "movie": "Secondhand Lions", "id": "/m/0k309k", "actor": "Michael Caine"}
# storyteller	{"char": "Wendy Darling", "movie": "Peter Pan", "id": "/m/0k1vn1", "actor": "Rachel Hurd-Wood"}
# stupid_crooks	{"char": "Sol", "movie": "Snatch", "id": "/m/03jtd2p", "actor": "Lennie James"}
# stupid_crooks	{"char": "Vinny", "movie": "Snatch", "id": "/m/03lsltz", "actor": "Robbie Gee"}
# stupid_crooks	{"char": "Tyrone", "movie": "Snatch", "id": "/m/09hy0ym", "actor": "Ade"}
# stupid_crooks	{"char": "Jerry Lundegaard", "movie": "Fargo", "id": "/m/0jy2wd", "actor": "William H. Macy"}
# stupid_crooks	{"char": "Vincent Vega", "movie": "Pulp Fiction", "id": "/m/01xlj4l", "actor": "John Travolta"}
# surfer_dude	{"char": "Ted \"Theodore\" Logan", "movie": "Bill & Ted's Excellent Adventure", "id": "/m/0jvcqg", "actor": "Keanu Reeves"}
# surfer_dude	{"char": "Bill S. Preston, Esq.", "movie": "Bill & Ted's Excellent Adventure", "id": "/m/0jvcqm", "actor": "Alex Winter"}
# surfer_dude	{"char": "Jeff Spicoli", "movie": "Fast Times at Ridgemont High", "id": "/m/0jy30b", "actor": "Sean Penn"}
# surfer_dude	{"char": "Chicken Joe", "movie": "Surf's Up", "id": "/m/02_wz7y", "actor": "Jon Heder"}
# surfer_dude	{"char": "Geek", "movie": "Surf's Up", "id": "/m/02_wz9s", "actor": "Jeff Bridges"}
# surfer_dude	{"char": "Stoney Brown", "movie": "Encino Man", "id": "/m/0jxvpr", "actor": "Pauly Shore"}
# surfer_dude	{"char": "Crawl", "movie": "Son in Law", "id": "/m/02tb5qh", "actor": "Pauly Shore"}
# surfer_dude	{"char": "Bud Macintosh", "movie": "Bio-Dome", "id": "/m/02vcwzp", "actor": "Pauly Shore"}
# surfer_dude	{"char": "Lance B. Johnson", "movie": "Apocalypse Now", "id": "/m/02vd4sl", "actor": "Sam Bottoms"}
# the_chief	{"char": "Dreyfus", "movie": "The Pink Panther", "id": "/m/0k63xm", "actor": "Kevin Kline"}
# the_chief	{"char": "Lt. Andrew Bogomil", "movie": "Beverly Hills Cop", "id": "/m/045xnnw", "actor": "Ronny Cox"}
# the_chief	{"char": "The Chief", "movie": "Dirty Harry", "id": "/m/0cg54hp", "actor": "John Larch"}
# the_editor	{"char": "Ben Bradlee", "movie": "All the President's Men", "id": "/m/0jt9_0", "actor": "Jason Robards"}
# the_editor	{"char": "Walter Burns", "movie": "His Girl Friday", "id": "/m/0jzg14", "actor": "Cary Grant"}
# tranquil_fury	{"char": "Eric Draven", "movie": "The Crow", "id": "/m/0k4td6", "actor": "Brandon Lee"}
# tranquil_fury	{"char": "John Preston", "movie": "Equilibrium", "id": "/m/0jxwq8", "actor": "Christian Bale"}
# tranquil_fury	{"char": "Ethan Hunt", "movie": "Mission: Impossible", "id": "/m/0k0qpl", "actor": "Tom Cruise"}
# tranquil_fury	{"char": "Inigo Montoya", "movie": "The Princess Bride", "id": "/m/0k65z5", "actor": "Mandy Patinkin"}
# tranquil_fury	{"char": "David Sumner", "movie": "Straw Dogs", "id": "/m/0k3v65", "actor": "Dustin Hoffman"}
# tranquil_fury	{"char": "Max Cady", "movie": "Cape Fear", "id": "/m/0jw22y", "actor": "Robert De Niro"}
# tranquil_fury	{"char": "Driver", "movie": "Drive", "id": "/m/0g4vml8", "actor": "Ryan Gosling"}
# trickster	{"char": "Han Solo", "movie": "Star Wars Episode V: The Empire Strikes Back", "id": "/m/01xpntj", "actor": "Harrison Ford"}
# trickster	{"char": "Captain Jack Sparrow", "movie": "Pirates of the Caribbean: Dead Man's Chest", "id": "/m/0k1xxm", "actor": "Johnny Depp"}
# trickster	{"char": "Tyler Durden", "movie": "Fight Club", "id": "/m/0jy5tj", "actor": "Brad Pitt"}
# trickster	{"char": "Mr. Nick", "movie": "The Imaginarium of Dr. Parnassus", "id": "/m/03kz4l5", "actor": "Tom Waits"}
# trickster	{"char": "Loki", "movie": "Thor", "id": "/m/0855mjk", "actor": "Tom Hiddleston"}
# valley_girl	{"char": "Julie Richman", "movie": "Valley Girl", "id": "/m/03jprhz", "actor": "Deborah Foreman"}
# valley_girl	{"char": "Cher Horowitz", "movie": "Clueless", "id": "/m/0jwjsy", "actor": "Alicia Silverstone"}
# valley_girl	{"char": "Romy White", "movie": "Romy and Michele's High School Reunion", "id": "/m/0k2p5c", "actor": "Mira Sorvino"}
# valley_girl	{"char": "Buffy Summers", "movie": "Buffy the Vampire Slayer", "id": "/m/0jvy0r", "actor": "Kristy Swanson"}
# valley_girl	{"char": "Elle Woods", "movie": "Legally Blonde", "id": "/m/0j_wm4", "actor": "Reese Witherspoon"}
# valley_girl	{"char": "Karen", "movie": "White Chicks", "id": "/m/045xr4n", "actor": "Busy Philipps"}
# warrior_poet	{"char": "Katsumoto", "movie": "The Last Samurai", "id": "/m/0k5n1r", "actor": "Ken Watanabe"}
# warrior_poet	{"char": "Arthur Burns", "movie": "The Proposition", "id": "/m/0k66rt", "actor": "Danny Huston"}
# warrior_poet	{"char": "Zohan", "movie": "You Don't Mess with the Zohan", "id": "/m/03hqx35", "actor": "Adam Sandler"}
# warrior_poet	{"char": "Broken Sword", "movie": "Hero", "id": "/m/0jzcrb", "actor": "Tony Leung Chiu Wai"}
# warrior_poet	{"char": "Colonel Walter E. Kurtz", "movie": "Apocalypse Now", "id": "/m/0jtp23", "actor": "Marlon Brando"}
# warrior_poet	{"char": "Master Li Mu Bai", "movie": "Crouching Tiger, Hidden Dragon", "id": "/m/0jwt__", "actor": "Chow Yun-Fat"}
# warrior_poet	{"char": "Tool", "movie": "The Expendables", "id": "/m/05tb1tv", "actor": "Mickey Rourke"}
# warrior_poet	{"char": "T. E. Lawrence", "movie": "Lawrence of Arabia", "id": "/m/0j_tdt", "actor": "Peter O'Toole"}
# warrior_poet	{"char": "Horton the Elephant", "movie": "Horton Hears a Who!", "id": "/m/05tgl99", "actor": "Jim Carrey"}
# young_gun	{"char": "Chico", "movie": "The Magnificent Seven", "id": "/m/0k5tn5", "actor": "Horst Buchholz"}
# young_gun	{"char": "Morgan Earp", "movie": "Tombstone", "id": "/m/0k776f", "actor": "Bill Paxton"}
# young_gun	{"char": "Colorado Ryan", "movie": "Rio Bravo", "id": "/m/0k2kqg", "actor": "Ricky Nelson"}
# young_gun	{"char": "Tom Sawyer", "movie": "The League of Extraordinary Gentlemen", "id": "/m/0k5nsh", "actor": "Shane West"}
# young_gun	{"char": "William H. 'Billy the Kid' Bonney", "movie": "Young Guns II", "id": "/m/03lrjk0", "actor": "Emilio Estevez"}
# young_gun	{"char": "Jake", "movie": "Silverado", "id": "/m/0k39jj", "actor": "Kevin Costner"}

# %% [markdown]
# name.clusters.txt
#
#
# 970 unique character names used in at least two different movies, along with 2,666 instances of those types.  The ID field indexes into the Freebase character/actor map ID in character.metadata.tsv.

# %%
with open('data/MovieSummaries/name.clusters.txt', encoding='utf8') as f:
    lines = f.read()
print(lines)
# Out:
# Stuart Little	/m/0k3w9c
# Stuart Little	/m/0k3wcx
# Stuart Little	/m/0k3wbn
# John Doe	/m/0jyg35
# John Doe	/m/0k2_zn
# Josh Framm	/m/0jt3p3
# Josh Framm	/m/0jt3t3
# Caspian X	/m/0646flc
# Caspian X	/m/02vd12n
# Apostle Peter	/m/02vd6_v
# Apostle Peter	/m/03lqtky
# Apostle Peter	/m/02vcr4g
# Van Wilder	/m/05t9vyx
# Van Wilder	/m/0k14rv
# Max Cady	/m/0jw22y
# Max Cady	/m/0jw24c
# The Emperor of China	/m/05yvrzt
# The Emperor of China	/m/03lk812
# Ludo Dekker	/m/075xnnb
# Ludo Dekker	/m/04lr9d9
# Veer Pratap Singh	/m/0dgb3pv
# Veer Pratap Singh	/m/05tb5t7
# Veer Pratap Singh	/m/0h82lw6
# John McClane	/m/0jx8f8
# John McClane	/m/0jx8dk
# Jack Cates	/m/0jskgc
# Jack Cates	/m/0jtmhj
# Shorty Meeks	/m/0k2yyr
# Shorty Meeks	/m/02vcwky
# Fievel Mousekewitz	/m/0jtgf0
# Fievel Mousekewitz	/m/0669ryp
# Fievel Mousekewitz	/m/0669ryh
# Fievel Mousekewitz	/m/0jtgh6
# Kazuya Mishima	/m/05sw_3g
# Kazuya Mishima	/m/0ggd_08
# Darth Vader	/m/02nwtmm
# Darth Vader	/m/02nwtmz
# Queen Victoria	/m/02vc38l
# Queen Victoria	/m/04dch0t
# Queen Victoria	/m/0gwdbnp
# Billy Fish	/m/0k3w17
# Billy Fish	/m/02vcrbg
# Ian Hawke	/m/06495l1
# Ian Hawke	/m/03kyztz
# Ginger Fitzgerald	/m/0jystc
# Ginger Fitzgerald	/m/02tbk0l
# Ginger Fitzgerald	/m/0jysxw
# Le Chiffre	/m/02hw7b6
# Le Chiffre	/m/02vd3mg
# The Professor	/m/0k4kdl
# The Professor	/m/02vd51h
# The Professor	/m/05kkbwl
# The Professor	/m/03jpnqx
# Jim Levenstein	/m/0jtf48
# Jim Levenstein	/m/0jtf77
# Jim Levenstein	/m/0jtfgq
# Dave Robicheaux	/m/03lfsn6
# Dave Robicheaux	/m/04dd_gs
# Jimmy 'The Tulip' Tudeski	/m/0k6x2j
# Jimmy 'The Tulip' Tudeski	/m/0k6x0x
# Pavel Chekov	/m/0cgcc2b
# Pavel Chekov	/m/04d4f1z
# Chow Mo-wan	/m/0jsh92
# Chow Mo-wan	/m/0jzwm8
# Foghorn Leghorn	/m/0dwf32d
# Foghorn Leghorn	/m/0gb0dpf
# Foghorn Leghorn	/m/0gb242_
# Foghorn Leghorn	/m/0g9hsq4
# Foghorn Leghorn	/m/0gx6wgh
# Foghorn Leghorn	/m/0gx639j
# Foghorn Leghorn	/m/0g9p_0_
# Foghorn Leghorn	/m/0gx6vmn
# Walter Hill	/m/0gw8h_9
# Walter Hill	/m/04lr8j7
# Dylan Sanders	/m/0jw863
# Dylan Sanders	/m/02vc2j3
# The Girl	/m/0k607q
# The Girl	/m/02vbt5f
# The Girl	/m/0k3xkn
# The Girl	/m/0bvbj8n
# The Girl	/m/040n_vv
# The Girl	/m/0jz7fw
# Sherlock Holmes	/m/04q3yhw
# Sherlock Holmes	/m/02vbxd8
# Sherlock Holmes	/m/05kfvdv
# Sherlock Holmes	/m/02vd3qk
# Sherlock Holmes	/m/09j2n_m
# Sherlock Holmes	/m/0k491m
# Sherlock Holmes	/m/0k6jgp
# Sherlock Holmes	/m/0k6cvp
# Sherlock Holmes	/m/0h0xk61
# Sherlock Holmes	/m/0k5dhq
# Sherlock Holmes	/m/0k84x9
# Sherlock Holmes	/m/02vcstt
# Sherlock Holmes	/m/02vbxrx
# Sherlock Holmes	/m/03kyn7g
# Sherlock Holmes	/m/02vbh0h
# Sherlock Holmes	/m/04htzyc
# Sherlock Holmes	/m/02vcwrr
# Sherlock Holmes	/m/02vcngl
# Emperor Nero	/m/0hyq70s
# Emperor Nero	/m/0hynbsm
# Sonia Saxena	/m/0j_bjl
# Sonia Saxena	/m/0j_clt
# David King	/m/0ly_kw6
# David King	/m/0m00hnx
# Mr. Big	/m/040kc7_
# Mr. Big	/m/07ylsnr
# The Drifter	/m/04z6j5n
# The Drifter	/m/03jt5m_
# Molly O	/m/04lrfc5
# Molly O	/m/04lr9cy
# Judas Iscariot	/m/0cg6znq
# Judas Iscariot	/m/02vd90_
# Gloria Sullivan	/m/0k8bwm
# Gloria Sullivan	/m/03jt5d8
# Jennifer Parker	/m/04m2m7m
# Jennifer Parker	/m/0cg9lrp
# Jennifer Parker	/m/0cf_swn
# Roger Murtaugh	/m/0j_zl4
# Roger Murtaugh	/m/0j_zh0
# Sharpay Evans	/m/0gl45p4
# Sharpay Evans	/m/02vc3dx
# Sharpay Evans	/m/03lyytc
# Sharpay Evans	/m/0jzdz2
# Charlie Dog	/m/0hyn_tz
# Charlie Dog	/m/0hynmp_
# Dr. Vijay	/m/08c_ry1
# Dr. Vijay	/m/045y8kf
# Aldous Snow	/m/02vbl0l
# Aldous Snow	/m/0648t1y
# Mr. Smith	/m/0crzdny
# Mr. Smith	/m/02vb_mp
# Mr. Smith	/m/0k0ws6
# Mr. Smith	/m/05tdsk5
# Mr. Smith	/m/0k568m
# Ricky Baker	/m/09hy110
# Ricky Baker	/m/09hyrhv
# Ricky Baker	/m/0jvr1n
# The Stranger	/m/0c05y0n
# The Stranger	/m/0gbwrm0
# The Stranger	/m/0jzdrz
# Michelle Flaherty	/m/0jtf7k
# Michelle Flaherty	/m/0jtfh0
# Michelle Flaherty	/m/03jqhlx
# Sidney Prescott	/m/0bc3xjq
# Sidney Prescott	/m/0k2_bc
# Sidney Prescott	/m/0k2_d8
# Sidney Prescott	/m/0k2_gh
# Kay Adams	/m/0k56j6
# Kay Adams	/m/02nxvzm
# Kay Adams	/m/0k56l9
# Ted Striker	/m/0jt4nj
# Ted Striker	/m/0jt4lr
# Prince Charming	/m/0ggfz50
# Prince Charming	/m/02tbdp_
# Prince Charming	/m/071mfr6
# Prince Charming	/m/0k382g
# Mr. Kesuke Miyagi	/m/0k5jxz
# Mr. Kesuke Miyagi	/m/0k5k0z
# Mr. Kesuke Miyagi	/m/0k5j_3
# Mr. Kesuke Miyagi	/m/0k5_rf
# Bill Holt	/m/02tbd42
# Bill Holt	/m/04ytg9m
# Josef Stalin	/m/0g4z8rm
# Josef Stalin	/m/0g4z853
# Jake Taylor	/m/08d8ttw
# Jake Taylor	/m/0jwwhd
# Jake Taylor	/m/0k0c7g
# Dorinda Durston	/m/03lmv58
# Dorinda Durston	/m/0jtc4l
# Robin Hood	/m/0k2m0f
# Robin Hood	/m/0k48xm
# Robin Hood	/m/09l3pqd
# Robin Hood	/m/0k2m4s
# Robin Hood	/m/0k2lw_
# Robin Hood	/m/0k2m26
# Jonathan Corliss	/m/03l6c0g
# Jonathan Corliss	/m/09lxy53
# Marie Antoinette	/m/03jq9ls
# Marie Antoinette	/m/0k0g5v
# Tin Man	/m/02vb_7z
# Tin Man	/m/02vd8g1
# Betty Boop	/m/0h1lxgm
# Betty Boop	/m/052cmzn
# Betty Boop	/m/052b3x8
# Charlie Chaplin	/m/02wt53c
# Charlie Chaplin	/m/02vcr6x
# Tom Baker	/m/0jw92q
# Tom Baker	/m/0jw94s
# Detective Eric Matthews	/m/03lt_jr
# Detective Eric Matthews	/m/02vd2y4
# Detective Eric Matthews	/m/03lf_gw
# Long John Silver	/m/03l4myy
# Long John Silver	/m/05cj7w_
# David Martin	/m/0h58rg6
# David Martin	/m/04ddnlm
# Nicholas Nickleby	/m/040m2kb
# Nicholas Nickleby	/m/040jwv4
# Prince Edward	/m/0jxvm9
# Prince Edward	/m/09l5byq
# Carrie Bradshaw	/m/05nxhmg
# Carrie Bradshaw	/m/040kc92
# Jack Foley	/m/04djr3v
# Jack Foley	/m/0k1nyn
# Vikram Kapoor	/m/02tbhcv
# Vikram Kapoor	/m/0gxdvbl
# Philip Marlowe	/m/0g5cs5b
# Philip Marlowe	/m/0k4gwm
# Philip Marlowe	/m/0k4l3j
# Philip Marlowe	/m/0j_r4h
# Philip Marlowe	/m/0k5rp6
# Philip Marlowe	/m/02vd1yn
# Philip Marlowe	/m/02vczqt
# Richard Mason	/m/0jwn2r
# Richard Mason	/m/0cg1_ww
# Richard Mason	/m/0crt1g7
# Harry Potter	/m/0jz6jt
# Harry Potter	/m/02tbbh6
# Harry Potter	/m/0jz6mq
# Harry Potter	/m/0jz6hs
# Harry Potter	/m/02tbf6n
# Harry Potter	/m/0jz6b0
# Harry Potter	/m/0jz6dz
# Harry Potter	/m/09lybcb
# Mia Toretto	/m/0g5dvbj
# Mia Toretto	/m/0k51p6
# Tom Logan	/m/03l919d
# Tom Logan	/m/0j_wl9
# Tom Logan	/m/03jpb31
# Prince Philip	/m/03jq06x
# Prince Philip	/m/02vc93_
# Sam Sheepdog	/m/052d6jq
# Sam Sheepdog	/m/0hynq6q
# Sam Sheepdog	/m/0hyqrrg
# Orson Welles	/m/03lm1h6
# Orson Welles	/m/04p6sj4
# Tony Toponi	/m/09hytcz
# Tony Toponi	/m/08npm48
# Tommy Pickles	/m/0k6bh4
# Tommy Pickles	/m/0fps3w2
# Mace Windu	/m/0jw2m_
# Mace Windu	/m/02s9v_w
# Uncle Elroy	/m/0ggd7n2
# Uncle Elroy	/m/0ggcd_z
# The Driver	/m/0gz7vtg
# The Driver	/m/0k4zg4
# Bilbo Baggins	/m/02vc8t6
# Bilbo Baggins	/m/0k5s6b
# Snow Queen	/m/09j3hpg
# Snow Queen	/m/02vcwbj
# Gen. Robert E. Lee	/m/02tb36_
# Gen. Robert E. Lee	/m/0jyqwm
# Arun Chatterjee	/m/0gw43_s
# Arun Chatterjee	/m/0cs9nlj
# Ricky Nash	/m/0jv0vh
# Ricky Nash	/m/03jtclx
# Captain Jack Sparrow	/m/07wwg_4
# Captain Jack Sparrow	/m/0k1xvb
# Captain Jack Sparrow	/m/0k1xxm
# Ricky 'Wild Thing' Vaughn	/m/0k0c7m
# Ricky 'Wild Thing' Vaughn	/m/0k0cbj
# Tony Blair	/m/0cc0mtb
# Tony Blair	/m/02vb3sp
# Sir Galahad	/m/0h571ky
# Sir Galahad	/m/0k0t3j
# Charlie Conway	/m/02tb8_3
# Charlie Conway	/m/02vcgl4
# Charlie Conway	/m/02tb0r3
# Uncle Fester	/m/0k484q
# Uncle Fester	/m/0jt0x3
# Wild Bill Hickok	/m/0jw0gn
# Wild Bill Hickok	/m/02vb57v
# Ko Chun	/m/03jprrw
# Ko Chun	/m/03jrb44
# Sherman Klump	/m/0k60hq
# Sherman Klump	/m/0k1dvd
# Apple Annie	/m/0k1zg9
# Apple Annie	/m/02vccxr
# Harrison Bergeron	/m/0jz62w
# Harrison Bergeron	/m/07fzr_s
# Sadie Thompson	/m/02t9_mp
# Sadie Thompson	/m/04hv9d1
# Jamie Lloyd	/m/0jz2zn
# Jamie Lloyd	/m/045y4j1
# Jamie Lloyd	/m/0jz2yp
# Damien Thorn	/m/03js195
# Damien Thorn	/m/02tb6br
# Damien Thorn	/m/05h9v78
# Damien Thorn	/m/02vbgkh
# Marian Paroo	/m/0k5zfs
# Marian Paroo	/m/04hv61q
# White Witch	/m/0k4qc5
# White Witch	/m/0cg03k8
# Carl Denham	/m/03l6ln_
# Carl Denham	/m/0j_h9p
# Cindy Campbell	/m/0k2z05
# Cindy Campbell	/m/02tbfd1
# Cindy Campbell	/m/0k2y_7
# Cindy Campbell	/m/0k2yyf
# Su Li-zhen - Mrs. Chan	/m/0jzwmf
# Su Li-zhen - Mrs. Chan	/m/0jshbh
# Lee Chan	/m/0cg2tp7
# Lee Chan	/m/0cs8vr7
# Lee Chan	/m/04htyc4
# Ajay Sharma	/m/04hvf6l
# Ajay Sharma	/m/0dgb2hv
# Fletcher Christian Master's Mate	/m/0k0znm
# Fletcher Christian Master's Mate	/m/0k0zm8
# Charlie Croker	/m/0k5hrm
# Charlie Croker	/m/0k5hq1
# The Tramp	/m/0j_qy7
# The Tramp	/m/09tbnf3
# Sheriff of Nottingham	/m/02vbkmn
# Sheriff of Nottingham	/m/04hvc5l
# Sheriff of Nottingham	/m/0k2m57
# Sophie Piper	/m/04djh67
# Sophie Piper	/m/0jz3d5
# Dark Witch	/m/02vd0z4
# Dark Witch	/m/02vcgfk
# Dark Witch	/m/02vcctr
# Clark Kent	/m/0h571jd
# Clark Kent	/m/0k3z25
# Clark Kent	/m/0hgcdxr
# Ben Marco	/m/0k5vyc
# Ben Marco	/m/0k5v_2
# James St. James	/m/02tb2sc
# James St. James	/m/0k0lkl
# Li Shang	/m/0bfm5z_
# Li Shang	/m/0bfm5_7
# Harry Osborn	/m/0k3nl_
# Harry Osborn	/m/0k3ngl
# Harry Osborn	/m/0k3nj5
# Harry Osborn	/m/0j8pt1w
# Henery Hawk	/m/0hyp1gd
# Henery Hawk	/m/0hyq5wy
# Conan Edogawa	/m/05cm5vm
# Conan Edogawa	/m/040gd_3
# Conan Edogawa	/m/0gcbn6g
# Conan Edogawa	/m/0hqg9x1
# Conan Edogawa	/m/040hvl7
# Conan Edogawa	/m/0gdlw5z
# Conan Edogawa	/m/0gchwht
# Conan Edogawa	/m/0gdnq0y
# Conan Edogawa	/m/040gbzd
# Conan Edogawa	/m/0hqg95k
# Conan Edogawa	/m/0hqgb8g
# André Matias	/m/04mnngf
# André Matias	/m/0g4nwkr
# Harry Morgan	/m/0k4l7n
# Harry Morgan	/m/09j292v
# Daniel Jackson	/m/04htrkj
# Daniel Jackson	/m/0k3rhh
# Mr. Moto	/m/04dhk8f
# Mr. Moto	/m/05ckg58
# Sheriff Buford T. Justice	/m/0k3g30
# Sheriff Buford T. Justice	/m/02vd7vy
# Pai Mei	/m/0bg79b7
# Pai Mei	/m/0gz3h92
# Sunder Srivastava	/m/045yrqp
# Sunder Srivastava	/m/0h885b8
# Rachel Keller	/m/0k69dw
# Rachel Keller	/m/0k69bb
# Emily Newton	/m/066b4fy
# Emily Newton	/m/0jv5v7
# Hildegarde Withers	/m/040nxmv
# Hildegarde Withers	/m/040nxls
# Harold Lee	/m/0jz5zr
# Harold Lee	/m/0dkc35z
# Harold Lee	/m/02tbk11
# Bhavani Shankar	/m/0dj2kk6
# Bhavani Shankar	/m/02vcvzq
# Sweeney Todd	/m/03gn21r
# Sweeney Todd	/m/0cc0ktf
# Barnyard Dawg	/m/0hyp1g3
# Barnyard Dawg	/m/0hyq5x5
# George Banks	/m/0k0gz2
# George Banks	/m/0jy3fs
# Dante Hicks	/m/09vvr68
# Dante Hicks	/m/0jwj13
# The Boss	/m/0h32dyn
# The Boss	/m/04xg2fg
# Ruth Wonderly	/m/0k5txv
# Ruth Wonderly	/m/0k5tww
# Master Wu	/m/0lf82z9
# Master Wu	/m/0gz2wtd
# Tommy Biggs	/m/02tb6rp
# Tommy Biggs	/m/02vcxbh
# Ebenezer Scrooge	/m/040j5kd
# Ebenezer Scrooge	/m/05b8lf3
# Ebenezer Scrooge	/m/02sfh5z
# Michael Corvin	/m/0k7ks3
# Michael Corvin	/m/0k7kv4
# Mitch Weaver	/m/0cv_ypb
# Mitch Weaver	/m/0gz56st
# Karan Malhotra	/m/02vbbk_
# Karan Malhotra	/m/040hgyq
# Karan Malhotra	/m/02tb5b0
# Ellen Griswold	/m/0k7qdl
# Ellen Griswold	/m/02vbk07
# Ellen Griswold	/m/0k14qp
# Ellen Griswold	/m/0b6tmng
# Brian O'Conner	/m/0k51p1
# Brian O'Conner	/m/04m645v
# Brian O'Conner	/m/0h9hfyb
# Brian O'Conner	/m/0bq6trk
# Brian O'Conner	/m/0jsj0x
# Doc McCoy	/m/0k55cn
# Doc McCoy	/m/01xpznj
# Frank Jones	/m/0jw_tc
# Frank Jones	/m/040nk5h
# Peter Pan	/m/051sqbq
# Peter Pan	/m/0h2wjxb
# Peter Pan	/m/0k1vpw
# John Seward	/m/05mclfd
# John Seward	/m/03jpd5b
# John Seward	/m/0jxjp0
# Son Goten	/m/0bgf7n6
# Son Goten	/m/0bgf7nz
# Son Goten	/m/0bgf7ng
# Mahendra Varma	/m/0g8qhdb
# Mahendra Varma	/m/0gl2k8f
# Kevin Myers	/m/0gw28fp
# Kevin Myers	/m/07y5r67
# T.J. Hicks	/m/0jx6qn
# T.J. Hicks	/m/02vcp8k
# Biff Tannen	/m/0jty7d
# Biff Tannen	/m/0jty60
# James Ubriacco	/m/0k04lv
# James Ubriacco	/m/02vchxt
# Ellen Ripley	/m/0jt7sz
# Ellen Ripley	/m/0jt8h6
# Ellen Ripley	/m/0jt8mf
# Ellen Ripley	/m/0jt8dc
# Perry Smith	/m/0jzvdm
# Perry Smith	/m/03jrs92
# Perry Smith	/m/0jw26b
# Lt. Frank Drebin	/m/0k5z_8
# Lt. Frank Drebin	/m/0k5zxl
# King Louis XI	/m/02vbg31
# King Louis XI	/m/02vd5d5
# Adolf Hitler	/m/03jql9d
# Adolf Hitler	/m/0k0h_l
# Adolf Hitler	/m/0jxht5
# Adolf Hitler	/m/0n637wj
# Edgar Allan Poe	/m/07pzhtg
# Edgar Allan Poe	/m/0gwb_jz
# Edgar Allan Poe	/m/04gd9vx
# Calvin Palmer	/m/0jv0tw
# Calvin Palmer	/m/02vc82x
# Prem Kumar	/m/0dj2mhp
# Prem Kumar	/m/0h7b2f_
# Carmen Cortez	/m/0g5ddb0
# Carmen Cortez	/m/02s9tsc
# Carmen Cortez	/m/02s9tx3
# Carmen Cortez	/m/02s9tz1
# Amy Fisher	/m/040n4dd
# Amy Fisher	/m/02vc8lg
# Nikhil Kapoor	/m/04httj9
# Nikhil Kapoor	/m/04z0twj
# Howard Hughes	/m/0k0l1x
# Howard Hughes	/m/0c1hd5z
# Howard Hughes	/m/0k4cj3
# Howard Hughes	/m/02vb61_
# Juliet Capulet	/m/0gch00c
# Juliet Capulet	/m/0k8368
# Juliet Capulet	/m/0k2p03
# Juliet Capulet	/m/07slpzc
# Clear Rivers	/m/0jy673
# Clear Rivers	/m/0jy647
# Doctor Moreau	/m/0j_02y
# Doctor Moreau	/m/02tbfz3
# Richard Rich	/m/03l4z90
# Richard Rich	/m/0jstg9
# Frank James	/m/0jtf0_
# Frank James	/m/0k5rtd
# George W. Bush	/m/0gvyw_w
# George W. Bush	/m/0gdk0v0
# Samwise Gamgee	/m/03llqhb
# Samwise Gamgee	/m/0k5sfd
# Kentaro Moto	/m/04dfy4m
# Kentaro Moto	/m/03jt7y9
# The Leprechaun	/m/03lmhfn
# The Leprechaun	/m/02tb6sq
# The Leprechaun	/m/02vb7fd
# The Leprechaun	/m/02vb3p9
# The Leprechaun	/m/02vcq9r
# Alex Tanner	/m/0bfm5gj
# Alex Tanner	/m/0k42gx
# Stone Alexander	/m/03kzpth
# Stone Alexander	/m/03jt91b
# Reuben Tishkoff	/m/03jtcll
# Reuben Tishkoff	/m/03l8zw0
# Ludwig van Beethoven	/m/02tbjh7
# Ludwig van Beethoven	/m/0jwpp5
# Han Solo	/m/0k6jzj
# Han Solo	/m/02nwvmx
# Han Solo	/m/0k3r1_
# Han Solo	/m/01xpntj
# Ash Williams	/m/0jxz7g
# Ash Williams	/m/0k503x
# Vikram Singh	/m/0csclt3
# Vikram Singh	/m/0jy5k4
# Vikram Singh	/m/03jpfl2
# Vikram Singh	/m/0cyb5j3
# Vikram Singh	/m/05npz42
# Vikram Singh	/m/03jsm3t
# John Hatcher	/m/03jq7xf
# John Hatcher	/m/03lrgzd
# Ethan Hunt	/m/0k0qpl
# Ethan Hunt	/m/0k0qsw
# Ethan Hunt	/m/0k0qr1
# Ethan Hunt	/m/0gx9sjv
# Sir Charles Litton	/m/0k6949
# Sir Charles Litton	/m/0jwwg3
# Mike Wazowski	/m/0k0nqh
# Mike Wazowski	/m/0k0t19
# Drake Parker	/m/03l00bt
# Drake Parker	/m/0gym45l
# Drake Parker	/m/04q48y6
# Mickey Goldmill	/m/0k2n0k
# Mickey Goldmill	/m/0k2n51
# Mickey Goldmill	/m/0k2n3v
# Mark Gor	/m/0jsnw3
# Mark Gor	/m/03js6pn
# Amelia Earhart	/m/04dh3l0
# Amelia Earhart	/m/04lrksq
# Paul Smecker	/m/0k4k5x
# Paul Smecker	/m/0cf_qxn
# Max Goldman	/m/02vbhnv
# Max Goldman	/m/02vcwz0
# The Pilot	/m/0ksx4js
# The Pilot	/m/0j_1t_k
# The Pilot	/m/0cf_qsw
# Leia Organa	/m/0k3r24
# Leia Organa	/m/0k3r3v
# Leia Organa	/m/01xpnt9
# Leia Organa	/m/0k6jzp
# Count Dooku	/m/04m6bt1
# Count Dooku	/m/04d4gf3
# Count Dooku	/m/0k3q_8
# Wally Walrus	/m/0665y9q
# Wally Walrus	/m/062wfnq
# Wally Walrus	/m/05nvdmb
# Helen Hudson	/m/0k0b84
# Helen Hudson	/m/0jwpmj
# Claude Cat	/m/0g9qb_n
# Claude Cat	/m/0fs8qzh
# Bernard the Arch-elf	/m/0k6cmt
# Bernard the Arch-elf	/m/0k6ckn
# Prithvi Singh	/m/02tbc95
# Prithvi Singh	/m/03jrwsl
# Ronald Niedermann	/m/0csfwpm
# Ronald Niedermann	/m/0c1w01w
# Edmund Pevensie	/m/0646fl1
# Edmund Pevensie	/m/0k4q8z
# Jai Kumar	/m/0gvylm7
# Jai Kumar	/m/0j_by2
# Samantha Jones	/m/040kc8m
# Samantha Jones	/m/05nxhms
# Priya Malhotra	/m/02vcd0h
# Priya Malhotra	/m/0k0nvn
# Mohandas Karamchand Gandhi	/m/040jcdy
# Mohandas Karamchand Gandhi	/m/0jzcxc
# Dominic Toretto	/m/0h27_ht
# Dominic Toretto	/m/0k51nx
# Dominic Toretto	/m/04m645j
# Dominic Toretto	/m/0gxrd8d
# Dominic Toretto	/m/0bq6trf
# Travis Coates	/m/03jqvlr
# Travis Coates	/m/03jt5wz
# Wendy Darling	/m/0k1vq0
# Wendy Darling	/m/0k1vn1
# Ice Princess	/m/0h2d6bs
# Ice Princess	/m/03jqz4d
# Jack Walsh	/m/0k22fn
# Jack Walsh	/m/0k0n9r
# Laurie Strode	/m/02vbjxs
# Laurie Strode	/m/0jz34_
# Laurie Strode	/m/0jz306
# Laurie Strode	/m/0jz2x0
# Laurie Strode	/m/0jz31z
# Debbie Strand	/m/03js013
# Debbie Strand	/m/02tbgxw
# Mrs. Deshmukh	/m/0h79rhb
# Mrs. Deshmukh	/m/0h8028j
# Princess Aura	/m/0jy8qr
# Princess Aura	/m/02vbs6s
# Tom Brookman	/m/05gsc55
# Tom Brookman	/m/05gsc55
# Agent Augustus Eugene Gibbons	/m/0k874n
# Agent Augustus Eugene Gibbons	/m/0k8761
# The Artful Dodger	/m/0k1gxh
# The Artful Dodger	/m/04d88r4
# Arun Choudhury	/m/02vcmgt
# Arun Choudhury	/m/02vbky0
# Fa Mulan	/m/0bfm1v9
# Fa Mulan	/m/0bflz0y
# King Triton	/m/0k5r0y
# King Triton	/m/0csk3sv
# King Triton	/m/0cg1qyd
# Nanny McPhee	/m/0k13m0
# Nanny McPhee	/m/06wlb65
# Prince Derek	/m/0hgc6sz
# Prince Derek	/m/0hgc6j3
# Prince Derek	/m/0hgc6s8
# Clark Griswold	/m/0k14qj
# Clark Griswold	/m/02vc36f
# Clark Griswold	/m/0k7qdf
# Norman Pitkin	/m/0bmyyyw
# Norman Pitkin	/m/0c5m6h2
# Henry Bergner	/m/040j739
# Henry Bergner	/m/0jv8xg
# Sheriff Hoyt	/m/0k6n8h
# Sheriff Hoyt	/m/02vc6n0
# Janet Weiss	/m/0k372l
# Janet Weiss	/m/0k69_6
# Susan Johnson	/m/0jtrf2
# Susan Johnson	/m/0ghdkxt
# Boris the Goose	/m/0jt_17
# Boris the Goose	/m/0h7g1p7
# Stu Price	/m/0gl2vlp
# Stu Price	/m/05srhg_
# Susan Walker	/m/0k0q32
# Susan Walker	/m/059t1qs
# Ellen Carlsson	/m/09lxy7h
# Ellen Carlsson	/m/03jt3bs
# Carol McCoy	/m/02vc73z
# Carol McCoy	/m/0k55ct
# Maria Elena	/m/03kxpxx
# Maria Elena	/m/02vcn7c
# James Roberts	/m/06wjsth
# James Roberts	/m/0h2x2p_
# Kristi Rey	/m/0djyb9b
# Kristi Rey	/m/0hf45qr
# Hans Zarkov	/m/0jy8q8
# Hans Zarkov	/m/02vbc6b
# Hans Zarkov	/m/02vcnj8
# Iron Man	/m/062_92n
# Iron Man	/m/02vb_x3
# Dan Erickson	/m/05tf_jm
# Dan Erickson	/m/0cg5gmy
# George Newton	/m/0jv5tm
# George Newton	/m/0jv5rw
# Ellen Wagstaff Arden	/m/0k0_xt
# Ellen Wagstaff Arden	/m/0k3jlj
# Agent Smith	/m/07ljr09
# Agent Smith	/m/0k5w_p
# Agent Smith	/m/0k5x24
# Agent Smith	/m/0k5wz1
# Eddie Johnson	/m/02vdf60
# Eddie Johnson	/m/03jskq6
# Charlie Calvin	/m/0k6ckh
# Charlie Calvin	/m/0k6cmz
# Pepper Potts	/m/02tb2fz
# Pepper Potts	/m/05tf_gs
# Indiana Jones	/m/0k294p
# Indiana Jones	/m/0jzx9b
# Indiana Jones	/m/0jzx78
# Peter Parker	/m/0gydht3
# Peter Parker	/m/0gydhrt
# Peter Parker	/m/0gydhr6
# Thunderbolt Ross	/m/03jq1g0
# Thunderbolt Ross	/m/02vc69m
# Paul Crewe	/m/0k5s2n
# Paul Crewe	/m/0k5s1k
# Jack Carter	/m/02vct8j
# Jack Carter	/m/0jyqb2
# Terry McKay	/m/0k06d_
# Terry McKay	/m/03lsdmb
# Terry McKay	/m/0jtg12
# Henry Frankenstein	/m/0jvstj
# Henry Frankenstein	/m/0jyf2t
# Marcellus Washburn	/m/0cg1g1t
# Marcellus Washburn	/m/0k5zg2
# Jack Shepard	/m/099cmc4
# Jack Shepard	/m/0k8cqs
# Master Shifu	/m/03ldqh1
# Master Shifu	/m/0h2kqd9
# Master Shifu	/m/059ss7b
# Meyer Lansky	/m/0jvy6w
# Meyer Lansky	/m/0k5sjv
# Roy Miller	/m/083g8cj
# Roy Miller	/m/040nlmc
# Riley Poole	/m/0k14vc
# Riley Poole	/m/02vcw4_
# Shaggy Rogers	/m/0k2zxb
# Shaggy Rogers	/m/0k2zvd
# Shaggy Rogers	/m/0gw47sn
# Shaggy Rogers	/m/0b6vb9r
# Shaggy Rogers	/m/05cj0r7
# Dale Arden	/m/02tbjvz
# Dale Arden	/m/0jy8q3
# Young Jenny	/m/0gch316
# Young Jenny	/m/0c0n9bj
# Mina Harker	/m/0jwq8d
# Mina Harker	/m/0k5ns0
# Mina Harker	/m/0dkcxxm
# Mina Harker	/m/0jxjxb
# Mina Harker	/m/0jvrhl
# Mina Harker	/m/02vbtqw
# Mina Harker	/m/0jxjqj
# Sgt. Tibbs	/m/0k1jzm
# Sgt. Tibbs	/m/040r9r9
# Nick Parker	/m/0k6263
# Nick Parker	/m/02vdf4j
# Vijay Verma	/m/03lzmtp
# Vijay Verma	/m/0dgb0_t
# Road Runner	/m/0hyq19j
# Road Runner	/m/0jsgkx9
# Road Runner	/m/0jsdhcc
# Road Runner	/m/0gb5xp2
# Road Runner	/m/052cftv
# Road Runner	/m/0hyn_cg
# John Kreese	/m/0k5jy8
# John Kreese	/m/0k5k18
# Misa Amane	/m/0bg66qy
# Misa Amane	/m/0bg66r7
# Sonia Mehra	/m/02vbd7x
# Sonia Mehra	/m/0j_lwb
# Nick Persons	/m/02tbc7h
# Nick Persons	/m/0jtq4g
# Kathy Lutz	/m/0k49zq
# Kathy Lutz	/m/0k49y0
# Kim Possible	/m/0j_gwj
# Kim Possible	/m/0j_gvb
# Eden Sinclair	/m/02vdcs8
# Eden Sinclair	/m/0gchg1g
# Amanda Young	/m/0k2y3y
# Amanda Young	/m/05tf_js
# Amanda Young	/m/02vd7w0
# Mary Jane	/m/03jpbbb
# Mary Jane	/m/0g4wl9q
# Emmett Richmond	/m/06wgw3f
# Emmett Richmond	/m/0j_wm9
# James Bond	/m/0220wtn
# James Bond	/m/02xg8xp
# James Bond	/m/02nqjkd
# James Bond	/m/03hqwg_
# James Bond	/m/02k8g9d
# James Bond	/m/02hw79s
# James Bond	/m/02xg8v_
# James Bond	/m/02vc6y6
# James Bond	/m/02vd4_b
# James Bond	/m/02xg8yj
# James Bond	/m/02xg8w8
# James Bond	/m/02xg8vf
# James Bond	/m/021ymvc
# Queen Clarisse Renaldi	/m/02tb17x
# Queen Clarisse Renaldi	/m/0k6619
# Tracy Lord	/m/0k63nh
# Tracy Lord	/m/0jzf0y
# Sister Sarah	/m/0g9qvsg
# Sister Sarah	/m/0k64rc
# Sally Brown	/m/0h1j6fr
# Sally Brown	/m/0k8dbth
# The Man	/m/0gc82f1
# The Man	/m/0k0m6z
# The Man	/m/02ws868
# Bastian Balthazar Bux	/m/0jx8q1
# Bastian Balthazar Bux	/m/02vbbl5
# Oscar Madison	/m/02vd1r8
# Oscar Madison	/m/0k60rx
# Elena Morales	/m/04m5fbv
# Elena Morales	/m/0k215t
# Mr. George Wilson	/m/02vbzpl
# Mr. George Wilson	/m/03l0r03
# Sara Crewe	/m/03lf13z
# Sara Crewe	/m/0jssz9
# Daisy Duke	/m/0k4zkn
# Daisy Duke	/m/0k4zp7
# Shuya Nanahara	/m/02vd69t
# Shuya Nanahara	/m/0jv37k
# Thomas Howard, 3rd Duke of Norfolk	/m/03q13pj
# Thomas Howard, 3rd Duke of Norfolk	/m/03lksv4
# Jack Frost	/m/02vd4sd
# Jack Frost	/m/0k6clm
# Monty Oberoi	/m/040mg7w
# Monty Oberoi	/m/0j_cw6
# Mr. Tinkles	/m/0bv4v54
# Mr. Tinkles	/m/0cg06wk
# Leo Bloom	/m/0k66b6
# Leo Bloom	/m/0k668x
# Reba McClane	/m/0k2dcs
# Reba McClane	/m/0k0f4g
# Liu Kang	/m/0k0tzk
# Liu Kang	/m/0k0tx0
# Tony Manero	/m/02vccs7
# Tony Manero	/m/0k2x4z
# Sheriff Woody	/m/0k78tv
# Sheriff Woody	/m/0k78xm
# Sheriff Woody	/m/0k78wk
# Bernie Focker	/m/0k0kj9
# Bernie Focker	/m/087gyq_
# Joe Collins	/m/0jsn08
# Joe Collins	/m/0jvx36
# Joe Collins	/m/0ch6z1y
# Arun Verma	/m/0dgb21_
# Arun Verma	/m/040rw20
# Kelsi Nielsen	/m/03js450
# Kelsi Nielsen	/m/09sczh7
# Speedy Gonzales	/m/0hhycjj
# Speedy Gonzales	/m/0hynyql
# Speedy Gonzales	/m/0hyq6y3
# Speedy Gonzales	/m/0hyq5w0
# Speedy Gonzales	/m/0gb0gqb
# Speedy Gonzales	/m/0hyp10y
# Speedy Gonzales	/m/0hyp1lc
# Joel Cairo	/m/05nyhzc
# Joel Cairo	/m/02vc6v3
# Hannibal Lecter	/m/0gcxyv0
# Hannibal Lecter	/m/0k2dc9
# Hannibal Lecter	/m/0jz4bm
# Hannibal Lecter	/m/0k6g86
# Aunt Bea	/m/0cg2nb2
# Aunt Bea	/m/0666mpn
# Kay Wilson	/m/02vb_g_
# Kay Wilson	/m/04j21c5
# Scott Evil	/m/0byk7wl
# Scott Evil	/m/0bylbmx
# Willy Wonka	/m/07lh8zd
# Willy Wonka	/m/0k838z
# Rahul Verma	/m/02tbjrw
# Rahul Verma	/m/0gw3f94
# Dr. Henry Clerval	/m/02vbrr3
# Dr. Henry Clerval	/m/03l14py
# Miss Clavel	/m/02vb2yp
# Miss Clavel	/m/0bhf319
# Mary Lane	/m/03lf4m3
# Mary Lane	/m/04lqzd7
# Homeless Man	/m/0h34zk5
# Homeless Man	/m/0cg12m1
# Anne Boleyn	/m/0hgt8_l
# Anne Boleyn	/m/03ljsv9
# Anne Boleyn	/m/0gydyj7
# Anne Boleyn	/m/03q142q
# Deuce Bigalow	/m/0jx6qh
# Deuce Bigalow	/m/02vdddt
# Fred Flintstone	/m/02vcmsv
# Fred Flintstone	/m/0krpc78
# Fred Flintstone	/m/0k531r
# Fred Flintstone	/m/0kr3lzq
# Julie James Bronson	/m/0jzqv2
# Julie James Bronson	/m/0jzq7f
# Rachel Dawes	/m/03jsd6r
# Rachel Dawes	/m/0cg83s3
# Mickey Mouse	/m/0gy6vn2
# Mickey Mouse	/m/04616r5
# Mickey Mouse	/m/0h1kd5y
# Mickey Mouse	/m/052c2jf
# Mickey Mouse	/m/0gb047j
# Mickey Mouse	/m/0gy6d6t
# Mickey Mouse	/m/0gfsr9y
# Mickey Mouse	/m/0gy6hdw
# Mickey Mouse	/m/052c2jv
# Mickey Mouse	/m/0gy6dd9
# Mickey Mouse	/m/052bynr
# Mickey Mouse	/m/0gy6jth
# Mickey Mouse	/m/0gy6hd1
# Mickey Mouse	/m/0gy6jqq
# Mickey Mouse	/m/0g8qddb
# Mickey Mouse	/m/05nn2dn
# Mickey Mouse	/m/0gy6jx3
# Mickey Mouse	/m/0gy6vlc
# Mickey Mouse	/m/0gy6c_3
# Mickey Mouse	/m/0gy6d6f
# Mickey Mouse	/m/0gy6vlc
# Mickey Mouse	/m/02vc_j6
# Mickey Mouse	/m/0gy6hdm
# Mickey Mouse	/m/0bykjd1
# Mr. D	/m/02wt532
# Mr. D	/m/0cgpgkh
# John Henry Brennick	/m/03llrrl
# John Henry Brennick	/m/0jyc_2
# Vilos Cohaagen	/m/0gwhnwl
# Vilos Cohaagen	/m/0k78f8
# The Thief	/m/0h5n8vc
# The Thief	/m/0bh5hdy
# The Thief	/m/02tc3sz
# Inspector Lestrade	/m/0chl6sv
# Inspector Lestrade	/m/0cgrxs9
# Jean Valjean	/m/02vcfhr
# Jean Valjean	/m/0j_y2s
# Richard Hannay	/m/0k47jd
# Richard Hannay	/m/059v2pk
# Richard Hannay	/m/0k47r3
# T. E. Lawrence	/m/0j_tdt
# T. E. Lawrence	/m/0jsqbs
# John Ryder	/m/02vcy1r
# John Ryder	/m/0k5cm3
# Lucy Westenra	/m/0jxjqp
# Lucy Westenra	/m/02vc785
# Lucy Westenra	/m/0jxjp5
# Lucy Westenra	/m/02vbg2d
# Lucy Westenra	/m/0jvrj6
# Lucy Westenra	/m/0jxjxn
# Lucy Westenra	/m/0jwq87
# Lucy Westenra	/m/040h618
# Flash Gordon	/m/02tbcr4
# Flash Gordon	/m/02vd9yp
# Flash Gordon	/m/03z8qs7
# Amanda Krueger	/m/03jqtvs
# Amanda Krueger	/m/0jsvnw
# Victor Frankenstein	/m/02vcv78
# Victor Frankenstein	/m/02vbycz
# Lestat de Lioncourt	/m/075jp3k
# Lestat de Lioncourt	/m/02tbgwy
# Ann Darrow	/m/0bmzl_2
# Ann Darrow	/m/0j_h9j
# Harry Lime	/m/0jzhmc
# Harry Lime	/m/0k6p2c
# Captain Haddock	/m/0j6_yzj
# Captain Haddock	/m/09hxz4g
# Captain Haddock	/m/04mhtln
# Princess Jasmine	/m/0jt5wf
# Princess Jasmine	/m/0jt5sk
# Barbara Gordon	/m/0jv29r
# Barbara Gordon	/m/041w0vy
# Barbara Gordon	/m/0460kqm
# Antoine Doinel	/m/0k47gt
# Antoine Doinel	/m/03qc0y5
# Antoine Doinel	/m/03qc0xm
# Antoine Doinel	/m/03qc0x_
# Camryn Barnes	/m/0k7ft9
# Camryn Barnes	/m/0gdjqwz
# Shamsher Singh	/m/0h70xb5
# Shamsher Singh	/m/040g0b0
# Billy the Kid	/m/0jwct3
# Billy the Kid	/m/03ky9ws
# Uncle Jack	/m/0gcybvk
# Uncle Jack	/m/0cg7cyl
# Joe Taylor	/m/059snl4
# Joe Taylor	/m/0k89bg
# Quincey Morris	/m/052b76n
# Quincey Morris	/m/04m4x58
# Quincey Morris	/m/05n5vsg
# Mark Hoffman	/m/02vc2sn
# Mark Hoffman	/m/05tf_jy
# Mark Hoffman	/m/09tc315
# Mark Hoffman	/m/040m41s
# Carlito Brigante	/m/0jw30w
# Carlito Brigante	/m/02vd6qg
# Hermione Granger	/m/0jz6f8
# Hermione Granger	/m/0jz6n0
# Hermione Granger	/m/09lybcg
# Hermione Granger	/m/0jz6j2
# Hermione Granger	/m/02vb8g9
# Hermione Granger	/m/0jz6bb
# Hermione Granger	/m/0jz6k3
# Mildred Rogers	/m/02tb47f
# Mildred Rogers	/m/04fsg7m
# Arjun Singh	/m/04dfk9k
# Arjun Singh	/m/03l74nd
# Arjun Singh	/m/04d8d0h
# Arjun Singh	/m/0j_cl5
# Arjun Singh	/m/03llrr6
# Matt Hunter	/m/02vb98g
# Matt Hunter	/m/0g5d0n9
# Ram Kumar	/m/02tbf9j
# Ram Kumar	/m/0gh9rtv
# Detective James Carter	/m/03l8vy5
# Detective James Carter	/m/0k2rb1
# Detective James Carter	/m/0k2rc0
# Ardeth Bay	/m/03jsl68
# Ardeth Bay	/m/03jsfhn
# Mitch Robbins	/m/0jwgq9
# Mitch Robbins	/m/0jwgnw
# Ernst Stavro Blofeld	/m/04r9h7s
# Ernst Stavro Blofeld	/m/04r9h8b
# Ernst Stavro Blofeld	/m/04r9h84
# Andy Hardy	/m/0mtgqvd
# Andy Hardy	/m/01z0l3t
# Seema Malhotra	/m/02vc15c
# Seema Malhotra	/m/0k2tcb
# William Stryker	/m/040qzwm
# William Stryker	/m/0k86xm
# Terry Benedict	/m/03lg80x
# Terry Benedict	/m/0k1fdq
# Heihachi Mishima	/m/04dhw8b
# Heihachi Mishima	/m/03l7tjr
# Anna Morgan	/m/0hnphsr
# Anna Morgan	/m/0j9ty9y
# Annie Porter	/m/0k3mmv
# Annie Porter	/m/0k3mlj
# Ward Abbott	/m/0k4kdf
# Ward Abbott	/m/0k4kg2
# Little John	/m/07ylmkb
# Little John	/m/0k2m0r
# Tanya Mousekewitz	/m/0669s3y
# Tanya Mousekewitz	/m/0jtghp
# Tanya Mousekewitz	/m/08npm3w
# Truman Capote	/m/0465n2v
# Truman Capote	/m/0jw260
# Tommy Jarvis	/m/0crt3gg
# Tommy Jarvis	/m/02vcmv_
# Pugsley Addams	/m/09hz5m7
# Pugsley Addams	/m/09hy33d
# Chief Inspector Lee	/m/03l8vy0
# Chief Inspector Lee	/m/0k2rbw
# Ned Morton	/m/0hyn_yt
# Ned Morton	/m/0647y5j
# Gilbert Blythe	/m/0d778sl
# Gilbert Blythe	/m/0jtm6n
# Chuck Sherman	/m/0cg0j_k
# Chuck Sherman	/m/03jsdb8
# Mrs. Potts	/m/0fw2j1c
# Mrs. Potts	/m/0fw2n55
# The Kid	/m/03jryhy
# The Kid	/m/02vcfyj
# Pooja Saxena	/m/0dbxmj9
# Pooja Saxena	/m/02vbkqg
# Abraham Lincoln	/m/0k059l1
# Abraham Lincoln	/m/0k89pf
# Abraham Lincoln	/m/02tbdlx
# Nobita Nobi	/m/0jyts8_
# Nobita Nobi	/m/0k27jd3
# Karan Singh	/m/0byknsp
# Karan Singh	/m/0dgb2s4
# Shere Khan	/m/06whpb9
# Shere Khan	/m/0glwpz6
# Shere Khan	/m/03lrrd_
# Tom Sawyer	/m/06wk65w
# Tom Sawyer	/m/02vc77b
# Tom Sawyer	/m/0k5nsh
# Wilma Flintstone	/m/0k5321
# Wilma Flintstone	/m/02vd788
# Wilma Flintstone	/m/0kr3lw3
# Sarah Baker	/m/0jw957
# Sarah Baker	/m/02vdb5r
# Cadet Carey Mahoney	/m/0k1_q0
# Cadet Carey Mahoney	/m/03lp6cz
# Cadet Carey Mahoney	/m/0k1_wk
# Minnie Mouse	/m/0ksh9nd
# Minnie Mouse	/m/0gy6vp1
# Minnie Mouse	/m/0g8qdhf
# Minnie Mouse	/m/0ksh9nd
# Minnie Mouse	/m/0gy6vm9
# Ellie Sattler	/m/02vd19d
# Ellie Sattler	/m/0j_8y9
# Cutler Beckett	/m/0k1xyw
# Cutler Beckett	/m/0k1xwx
# Dr. Samantha Hill	/m/0jsjpd
# Dr. Samantha Hill	/m/0jsncd
# Jill Tuck-Kramer	/m/04ddh1_
# Jill Tuck-Kramer	/m/09tc32f
# Jill Tuck-Kramer	/m/05tf_k7
# Charlie Bucket	/m/0jw83j
# Charlie Bucket	/m/0k8398
# Peter Parkette	/m/02sjzn6
# Peter Parkette	/m/02sjznp
# Anna Karenina	/m/02vcc_v
# Anna Karenina	/m/03kzlgr
# Anna Karenina	/m/02vcdbb
# Lawrence Stewart Talbot	/m/02nwsyx
# Lawrence Stewart Talbot	/m/03ldx5_
# Lawrence Stewart Talbot	/m/0jzlc2
# Lawrence Stewart Talbot	/m/0gb_cdk
# Lawrence Stewart Talbot	/m/0k6yf8
# Lawrence Stewart Talbot	/m/0jzl7t
# Dorothy Carlsson	/m/09lxy66
# Dorothy Carlsson	/m/09lxy6d
# John F. Kennedy	/m/0k256y
# John F. Kennedy	/m/0k67v3
# Tasmanian Devil	/m/0hynjk6
# Tasmanian Devil	/m/0hynl7d
# Lisbeth Salander	/m/0b3vyd7
# Lisbeth Salander	/m/0c1w01_
# Lisbeth Salander	/m/09l581w
# Bill Sikes	/m/0k1gz1
# Bill Sikes	/m/0k1gvd
# Bill Sikes	/m/05cdqnr
# Bill Sikes	/m/0k1gxb
# Regan MacNeil	/m/0k50cy
# Regan MacNeil	/m/0jx_1t
# Jonathan Carnahan	/m/0k5z01
# Jonathan Carnahan	/m/0k5yzj
# Jonathan Carnahan	/m/03lzd6_
# Stifler's Mom	/m/03jqbx1
# Stifler's Mom	/m/03jrk92
# Miss Finster	/m/0kxcszg
# Miss Finster	/m/0kx9w0_
# Lex Luthor	/m/02vbrr0
# Lex Luthor	/m/02vb45j
# Lex Luthor	/m/0k3z3h
# Lex Luthor	/m/0k3z0y
# Lex Luthor	/m/06wj_km
# Lex Luthor	/m/0k3zb8
# Lex Luthor	/m/0k3z7_
# Karsh WarBurton	/m/0gdjq8l
# Karsh WarBurton	/m/0gchf45
# Allan Quatermain	/m/0dkcff_
# Allan Quatermain	/m/0dkcffs
# Allan Quatermain	/m/0dkcfg6
# Allan Quatermain	/m/02vdb4q
# Nelson Potter	/m/0jy2_4
# Nelson Potter	/m/0jy2yb
# Edward Rochester	/m/04sz_8r
# Edward Rochester	/m/0j_37b
# Rahul Sharma	/m/0k12qb
# Rahul Sharma	/m/0gm0zrv
# Freddy Krueger	/m/0667gzp
# Freddy Krueger	/m/0jsvqk
# Freddy Krueger	/m/0jyg1b
# Freddy Krueger	/m/0jsvj_
# Freddy Krueger	/m/070nw_0
# Freddy Krueger	/m/0k7z4p
# Freddy Krueger	/m/0jsvp5
# Freddy Krueger	/m/0jsvmj
# Freddy Krueger	/m/0jsvhc
# Kristen Parker	/m/0jsvqd
# Kristen Parker	/m/0jsvjj
# Dorian Gray	/m/0dkcy1f
# Dorian Gray	/m/07m1wvf
# Oliver "Daddy" Warbucks	/m/040kqbc
# Oliver "Daddy" Warbucks	/m/03l220l
# Velma Dinkley	/m/03js164
# Velma Dinkley	/m/0k2zvw
# Velma Dinkley	/m/0h1hzbf
# Velma Dinkley	/m/05cj0rk
# Maid Marian	/m/0k48xs
# Maid Marian	/m/0h0_xzh
# Maid Marian	/m/0k2m52
# Cameron Mitchell	/m/0cg863c
# Cameron Mitchell	/m/0cg1702
# Alvin Seville	/m/0cgnj7t
# Alvin Seville	/m/06495l6
# Alvin Seville	/m/0k4q1s
# Raj Malhotra	/m/029p_h0
# Raj Malhotra	/m/0jt4xw
# Raj Malhotra	/m/0dgb2pv
# Raj Malhotra	/m/0hz_g5w
# Raj Malhotra	/m/0jtjxd
# Raj Malhotra	/m/03jsqyn
# Raj Malhotra	/m/0h8bc26
# Raj Malhotra	/m/0jsmb5
# Raj Malhotra	/m/04mjvg4
# Raj Malhotra	/m/0bmz7b4
# Carol Anne Freeling	/m/02vbddz
# Carol Anne Freeling	/m/02vcbh3
# Carol Anne Freeling	/m/02tbdfr
# Mr. Murray	/m/0jwzp5
# Mr. Murray	/m/03lj4l5
# Harry Houdini	/m/02vb6b_
# Harry Houdini	/m/02vd8nt
# Connie Corleone	/m/0k56lm
# Connie Corleone	/m/02nxvzx
# Anne Elliot	/m/0gw0n1w
# Anne Elliot	/m/0k1v9r
# Silent Bob	/m/0jwj05
# Silent Bob	/m/0jxdks
# Silent Bob	/m/09vvrgm
# Bellatrix Lestrange	/m/05pxc0x
# Bellatrix Lestrange	/m/0crxhn6
# Bellatrix Lestrange	/m/02_3gkk
# Dr. Zaius	/m/0jv7wm
# Dr. Zaius	/m/0k1yq1
# Miles Archer	/m/0cg2vj8
# Miles Archer	/m/05nyhzj
# Ace Ventura	/m/0jt03v
# Ace Ventura	/m/0jt05v
# Gabriel Van Helsing	/m/02vd4nv
# Gabriel Van Helsing	/m/0k7p7w
# The Wizard	/m/02vb92n
# The Wizard	/m/03lc0r7
# The Wizard	/m/04htzhl
# The Wizard	/m/0k6y77
# Eddie Felson	/m/0k4rkf
# Eddie Felson	/m/02vct3c
# The Collector	/m/0jx534
# The Collector	/m/09v1859
# Roger Rabbit	/m/0k81jv
# Roger Rabbit	/m/04616rn
# Herbert West	/m/0jv9hb
# Herbert West	/m/0jvsxx
# Herbert West	/m/0k2c86
# Jack Powell	/m/02vcr5s
# Jack Powell	/m/02tbgyx
# Lorna Cole	/m/0j_zjl
# Lorna Cole	/m/0j_zhb
# William Shakespeare	/m/0h5jrq2
# William Shakespeare	/m/0gl1mnw
# William Shakespeare	/m/02_571y
# William Shakespeare	/m/045xj51
# Childlike Empress	/m/02vbdkn
# Childlike Empress	/m/0jx8q6
# Davy Jones	/m/0k1xy2
# Davy Jones	/m/0k1xvh
# Dan Cain	/m/0jvsx3
# Dan Cain	/m/0k2c8c
# Mia Thermopolis	/m/02vbfh2
# Mia Thermopolis	/m/0k6614
# Pat Garrett	/m/0k1sb7
# Pat Garrett	/m/059whrd
# Pat Garrett	/m/03ky9wm
# Clarice Starling	/m/0jz4bs
# Clarice Starling	/m/0k6g81
# Betty Rubble	/m/02vc3s7
# Betty Rubble	/m/0k5326
# Betty Rubble	/m/0kr3ly5
# Jack Byrnes	/m/0k0kl5
# Jack Byrnes	/m/0k0kjg
# Jack Byrnes	/m/087gypx
# Nicky Parsons	/m/02t9dkw
# Nicky Parsons	/m/0k4kgd
# Ravi Varma	/m/040lkfg
# Ravi Varma	/m/040k38f
# Ravi Varma	/m/0h1kt2r
# Sir Walter Elliot	/m/0k1vb6
# Sir Walter Elliot	/m/0cgpdbl
# Miranda Hobbes	/m/040kc84
# Miranda Hobbes	/m/05nxhmm
# George Milton	/m/0k1g22
# George Milton	/m/0k1g11
# Sam Hall	/m/04zcgmh
# Sam Hall	/m/0k4v_9
# Celia Gray	/m/03jtbcv
# Celia Gray	/m/0ck7b8h
# Barney Ross	/m/0gwhcth
# Barney Ross	/m/059tvtw
# Charlie B. Barkin	/m/0jt948
# Charlie B. Barkin	/m/09l4g66
# Kevin McCallister	/m/0jzhl5
# Kevin McCallister	/m/0jzhm6
# Jack Crawford	/m/0k0f4s
# Jack Crawford	/m/0k2dcm
# Jack Crawford	/m/0k6g8c
# Prince Hamlet	/m/09nf2qs
# Prince Hamlet	/m/0jz3w4
# Prince Hamlet	/m/05ch59w
# Daniel Cleaver	/m/0c1r22g
# Daniel Cleaver	/m/0h5njph
# Albert Brooks	/m/0k2cmw
# Albert Brooks	/m/0k04t1
# The Sheriff	/m/0l4qfn7
# The Sheriff	/m/02vc4fm
# Prince Eric	/m/0k5r0s
# Prince Eric	/m/0cs6mk_
# Prince Eric	/m/03lk7hd
# Barney Rubble	/m/0krpc70
# Barney Rubble	/m/0k531x
# Barney Rubble	/m/02vcz7m
# Barney Rubble	/m/0k5v0p
# Barney Rubble	/m/0kr3lvh
# Barney Rubble	/m/04d74qc
# Prince Shamsher Singh	/m/02vbt57
# Prince Shamsher Singh	/m/02tb9bv
# Richard the Lionheart	/m/02wh79x
# Richard the Lionheart	/m/0cs1dgt
# Cardinal Richelieu	/m/0ggfs8n
# Cardinal Richelieu	/m/02vcspz
# Cardinal Richelieu	/m/02vbtwv
# Cardinal Richelieu	/m/0ccdq3d
# Cardinal Richelieu	/m/02tb5n7
# Ted "Theodore" Logan	/m/0jvcqg
# Ted "Theodore" Logan	/m/0jvcnw
# Dr. Anton Phibes	/m/0k47z8
# Dr. Anton Phibes	/m/0jxjhd
# Frodo Baggins	/m/0k5s97
# Frodo Baggins	/m/0k5scc
# Frodo Baggins	/m/0k5sf7
# Frodo Baggins	/m/0k5s5d
# Chris Hargensen	/m/0jw3ky
# Chris Hargensen	/m/03jr05_
# Jimmy Lee	/m/02vbz3d
# Jimmy Lee	/m/04dbrk2
# Security Guard	/m/0j1ffqf
# Security Guard	/m/0f_6z7f
# Genji Takiya	/m/0gw0445
# Genji Takiya	/m/0djcxdk
# Michael Jackson	/m/04q5vg1
# Michael Jackson	/m/040c1s4
# Charlie Brown	/m/07n9qvl
# Charlie Brown	/m/0n3l_49
# Daffy Duck	/m/0g9n24p
# Daffy Duck	/m/0hynk74
# Daffy Duck	/m/0gx8gyp
# Daffy Duck	/m/0gx6xc0
# Daffy Duck	/m/052ct6g
# Daffy Duck	/m/0hyn6rt
# Daffy Duck	/m/0gb1vhp
# Daffy Duck	/m/0hyq22t
# Daffy Duck	/m/0gx7dt6
# Daffy Duck	/m/0hynzx1
# Daffy Duck	/m/0hgvq1p
# Daffy Duck	/m/052b3z9
# Daffy Duck	/m/0gx874s
# Daffy Duck	/m/0hynjq9
# Daffy Duck	/m/0gx7smx
# Daffy Duck	/m/052cw1m
# Daffy Duck	/m/052bx3v
# Daffy Duck	/m/0gw3xvy
# Daffy Duck	/m/0gx867f
# Daffy Duck	/m/09l4_j7
# Daffy Duck	/m/0gb5xzr
# Daffy Duck	/m/0lmnyj7
# Daffy Duck	/m/052bzjn
# Daffy Duck	/m/0hyn5n6
# Daffy Duck	/m/0hyn2zm
# Daffy Duck	/m/0gx8dbm
# Daffy Duck	/m/052c2_5
# Daffy Duck	/m/0hyn6r7
# Daffy Duck	/m/0ggc7mp
# Daffy Duck	/m/0647dyw
# Daffy Duck	/m/0hynr1_
# Daffy Duck	/m/052bd46
# Daffy Duck	/m/0gx8ldv
# Daffy Duck	/m/0hyn2mj
# Daffy Duck	/m/09l556v
# Daffy Duck	/m/0g9qc1s
# Daffy Duck	/m/0gx49n4
# Daffy Duck	/m/052cwkx
# Daffy Duck	/m/0gx50y1
# Daffy Duck	/m/0hynl0w
# Daffy Duck	/m/052bzk0
# Daffy Duck	/m/0j2fvc3
# Helen Benson	/m/0k4w6g
# Helen Benson	/m/040mnw3
# Jackie Robinson	/m/0k5hzs
# Jackie Robinson	/m/04618bh
# Leo Getz	/m/0j_zh5
# Leo Getz	/m/0j_zjf
# Leo Getz	/m/0j_zl9
# Philip Carey	/m/04fsg7s
# Philip Carey	/m/02tb8_z
# Fox Mulder	/m/03gjth6
# Fox Mulder	/m/04f8_t5
# Rosemary Woodhouse	/m/02vcq0c
# Rosemary Woodhouse	/m/02vbdfj
# Bharat Bhushan	/m/0gw2k1k
# Bharat Bhushan	/m/09j018n
# Inspector Megure	/m/0hqgcjq
# Inspector Megure	/m/0ggdl1q
# Optimus Prime	/m/04m54zn
# Optimus Prime	/m/0k79kc
# Optimus Prime	/m/0c055xd
# Optimus Prime	/m/0646s6s
# Linus Larrabee	/m/01x3dtf
# Linus Larrabee	/m/0k2sdf
# Big Daddy	/m/03jrg3b
# Big Daddy	/m/0hdg77m
# Big Daddy	/m/0k25f2
# Big Daddy	/m/02tbj1c
# Don Diego de la Vega	/m/0gl0nr9
# Don Diego de la Vega	/m/0h36wq9
# Prince Barin	/m/0jy8qf
# Prince Barin	/m/03z8qmm
# Miss Bianca	/m/0k68mp
# Miss Bianca	/m/0k68q3
# Tommy Ross	/m/0jw3km
# Tommy Ross	/m/03lwrx1
# Ray Bronson	/m/0jzq7x
# Ray Bronson	/m/0jzqvk
# Captain January	/m/040f_t3
# Captain January	/m/02tb9wb
# Joe Carraclough	/m/0j_slj
# Joe Carraclough	/m/03jpbj5
# Snow White	/m/0gvzs8s
# Snow White	/m/03jr85w
# Snow White	/m/0gy4p8t
# Gang Member	/m/0bmkqvk
# Gang Member	/m/0gykrxp
# Luke Skywalker	/m/0k3r1v
# Luke Skywalker	/m/0k6jzc
# Luke Skywalker	/m/01xpntr
# Luke Skywalker	/m/0k3r3j
# Baron Frankenstein	/m/0jyf4h
# Baron Frankenstein	/m/04q4m6r
# Edgar Frog	/m/0crsc36
# Edgar Frog	/m/0gxbj2c
# Deepak Kumar	/m/0dj2lq0
# Deepak Kumar	/m/0gw0cdy
# Margaret White	/m/0jw3k9
# Margaret White	/m/02vbkk9
# Julius Caesar	/m/0jwhxq
# Julius Caesar	/m/0k3m5p
# Dan Jordan	/m/03jpdr2
# Dan Jordan	/m/03jptyx
# Mary Crawford	/m/09sddf6
# Mary Crawford	/m/0cg61m1
# Hercule Poirot	/m/02vb7yx
# Hercule Poirot	/m/03jqrpn
# Hercule Poirot	/m/02vbw1m
# Jim Hawkins	/m/02vbr8d
# Jim Hawkins	/m/05cj7x4
# Wyatt Earp	/m/02vbn72
# Wyatt Earp	/m/04d8gym
# Wyatt Earp	/m/0k775z
# Wyatt Earp	/m/0gy8rxk
# Lightning McQueen	/m/05t9l5j
# Lightning McQueen	/m/0jw4d3
# Samuel J. Loomis	/m/0jz2x5
# Samuel J. Loomis	/m/0jz2zh
# Samuel J. Loomis	/m/0jz2yj
# Samuel J. Loomis	/m/0jz323
# Samuel J. Loomis	/m/0jz36b
# Young Jake	/m/0hndzk9
# Young Jake	/m/0bwsx65
# Carl Kolchak	/m/04dctvq
# Carl Kolchak	/m/07ll4c0
# Lord Voldemort	/m/094wpns
# Lord Voldemort	/m/02t9_zv
# Lord Voldemort	/m/09lybcq
# Lord Voldemort	/m/075q0v4
# Lord Voldemort	/m/0jz6fl
# Lord Voldemort	/m/02vcdgy
# Martin Beck	/m/0dlfhds
# Martin Beck	/m/0k24b8
# Martin Beck	/m/0d1tth4
# Ryce Newton	/m/03jq3np
# Ryce Newton	/m/0jv5ty
# General Zod	/m/02vbg3t
# General Zod	/m/0k3z4r
# Arthur Bach	/m/0jtrgj
# Arthur Bach	/m/0ghdkxh
# Arthur Bach	/m/0jtrdg
# Buzz Lightyear	/m/05t77sd
# Buzz Lightyear	/m/02s9l6m
# Buzz Lightyear	/m/0k78wq
# Buzz Lightyear	/m/02s9l6z
# Randal Graves	/m/09vvrb_
# Randal Graves	/m/0jwj18
# Donald Duck	/m/0gfsqzl
# Donald Duck	/m/04616rb
# Donald Duck	/m/0lpxw_k
# Donald Duck	/m/0gb58qn
# Donald Duck	/m/0gfsr8_
# Donald Duck	/m/0h1k8f6
# Donald Duck	/m/0km7m2t
# Donald Duck	/m/0n4j11h
# Donald Duck	/m/0gg2d61
# Donald Duck	/m/0jr9xjf
# Donald Duck	/m/0mzmmb1
# Donald Duck	/m/0jrxlz7
# Princess Ilene	/m/04fgygk
# Princess Ilene	/m/0cf_qtm
# Young Jack	/m/03jq87t
# Young Jack	/m/03jppd0
# Anakin Skywalker	/m/02sg5s6
# Anakin Skywalker	/m/02sg5ry
# Anakin Skywalker	/m/02sg5rn
# Anakin Skywalker	/m/04m6bsf
# Franz Liszt	/m/04kp4mz
# Franz Liszt	/m/02vbv2p
# Carrie White	/m/07rzv7l
# Carrie White	/m/0jw3k4
# Pontius Pilate	/m/042h1f5
# Pontius Pilate	/m/03jt1k5
# Pontius Pilate	/m/09j2b4l
# Pontius Pilate	/m/042h1f0
# Billy Jack	/m/02vbcw7
# Billy Jack	/m/0jvc_9
# Billy Jack	/m/02t9_68
# Billy Jack	/m/02vbf57
# Sean Brody	/m/03js2z7
# Sean Brody	/m/0ch98pw
# Megan Parker	/m/0jxkps
# Megan Parker	/m/04q48xx
# Ursula Stanhope	/m/0jypxb
# Ursula Stanhope	/m/0jypz7
# Steve Stifler	/m/0jtf4f
# Steve Stifler	/m/0gvx2tj
# Steve Stifler	/m/0jtf7d
# Steve Stifler	/m/0jtfgw
# The Chief	/m/0cg54hp
# The Chief	/m/02vc6kh
# Nora Baker	/m/03jt5ff
# Nora Baker	/m/0jw935
# Felix Unger	/m/03l920n
# Felix Unger	/m/0k60rr
# Kate Baker	/m/0jw92w
# Kate Baker	/m/0jw94y
# Lt. Sean Topper Harley	/m/0jzkj3
# Lt. Sean Topper Harley	/m/0jzkgb
# Father Uffizi	/m/02tbjc3
# Father Uffizi	/m/02vbm27
# Marty McFly	/m/0jty5d
# Marty McFly	/m/0jty84
# Marty McFly	/m/0jty6y
# David Bowman	/m/0jsmd2
# David Bowman	/m/0jsjmg
# King Kong	/m/0h2vw8s
# King Kong	/m/0h34xh0
# John Hammond	/m/0j_8ym
# John Hammond	/m/0k5st6
# Saraswati Chandra's father	/m/0gcy23_
# Saraswati Chandra's father	/m/0gcy23_
# Brian Kelly	/m/02vc8l5
# Brian Kelly	/m/0k3jgk
# Taylor McKessie	/m/0jzdzk
# Taylor McKessie	/m/0gz0wnc
# Neil Patrick Harris	/m/03d_jzv
# Neil Patrick Harris	/m/03d_jz8
# Ben Cooper	/m/0k3fh2
# Ben Cooper	/m/0k633d
# Rohit Kumar	/m/0k1pz8
# Rohit Kumar	/m/02b9dzf
# Chad Danforth	/m/03lyytv
# Chad Danforth	/m/0jzdzd
# Chad Danforth	/m/0gz0ldm
# Tommy Doyle	/m/0jz36h
# Tommy Doyle	/m/02vb6tb
# Mycroft Holmes	/m/0gk8kt8
# Mycroft Holmes	/m/02vbty7
# Inspector Clouseau	/m/0k2j12
# Inspector Clouseau	/m/0k63xg
# Inspector Clouseau	/m/02_2hh6
# Inspector Clouseau	/m/0k797p
# Inspector Clouseau	/m/02_2hgr
# Inspector Clouseau	/m/03jqhfj
# Inspector Clouseau	/m/0k63zt
# Greg Heffley	/m/0h2wrwj
# Greg Heffley	/m/0gw2ydz
# Greg Heffley	/m/07ykgr9
# Princess Odette	/m/0gdmvqn
# Princess Odette	/m/02vc8n4
# Princess Odette	/m/02vcp11
# Princess Odette	/m/040n603
# Bugs Bunny	/m/052cqt0
# Bugs Bunny	/m/09vlfvh
# Bugs Bunny	/m/052bxvw
# Bugs Bunny	/m/052cx3d
# Bugs Bunny	/m/052bz1c
# Bugs Bunny	/m/052cqjx
# Bugs Bunny	/m/052cm4w
# Bugs Bunny	/m/052c6cm
# Bugs Bunny	/m/0gx62c3
# Bugs Bunny	/m/052cqk2
# Bugs Bunny	/m/0gx4mx5
# Bugs Bunny	/m/0hynkw7
# Bugs Bunny	/m/0gy5gvh
# Bugs Bunny	/m/0g99lbm
# Bugs Bunny	/m/052bz28
# Bugs Bunny	/m/0gx4qgw
# Bugs Bunny	/m/052cxgg
# Bugs Bunny	/m/052c63k
# Bugs Bunny	/m/0glw70k
# Bugs Bunny	/m/052d8ch
# Vicky Malhotra	/m/02vcch4
# Vicky Malhotra	/m/0h6f7nz
# Julie Hastings	/m/0h5nmtb
# Julie Hastings	/m/0jwzw9
# Witch Hazel	/m/0gx88_7
# Witch Hazel	/m/09vlfvn
# Witch Hazel	/m/0gx88y4
# Snake Plissken	/m/0jxxkh
# Snake Plissken	/m/0jxxhp
# Pamela Landy	/m/0k4kg7
# Pamela Landy	/m/02t9dn6
# Itchy Itchiford	/m/03jtdwv
# Itchy Itchiford	/m/0jt94f
# Eric Lassard	/m/0k1_sn
# Eric Lassard	/m/0k1_xh
# Eric Lassard	/m/0k1_qz
# Eric Lassard	/m/0k1_vl
# Davy Crockett	/m/03l35jl
# Davy Crockett	/m/02vb42j
# Davy Crockett	/m/04dfht2
# Davy Crockett	/m/0k49cv
# Uncle Arthur	/m/03l5_t9
# Uncle Arthur	/m/07r2jk5
# The Oracle	/m/03jt6fx
# The Oracle	/m/0jt5xc
# The Oracle	/m/03jpl0f
# Jane Spencer Drebin	/m/0k5zxr
# Jane Spencer Drebin	/m/0k5z_f
# Jane Spencer Drebin	/m/0k5zyx
# Mikael Blomkvist	/m/07lmck1
# Mikael Blomkvist	/m/07llrrx
# Mikael Blomkvist	/m/0b3vyd1
# Sean Anderson	/m/04f8xf_
# Sean Anderson	/m/0gm28gr
# Daniel Larusso	/m/0k5jxt
# Daniel Larusso	/m/0k5jzz
# Daniel Larusso	/m/0k5k0t
# Juan Rico	/m/0mz9qcb
# Juan Rico	/m/0k3rmk
# Adrian Pennino	/m/0k2n6q
# Adrian Pennino	/m/0k2n02
# Victor Prinzim	/m/02k9d4l
# Victor Prinzim	/m/0k4ndb
# Rahul Malhotra	/m/0hrn2f2
# Rahul Malhotra	/m/0ccf8k2
# Bo Duke	/m/04mgd77
# Bo Duke	/m/0k4zkh
# Bo Duke	/m/0k4zny
# Dr. John Dolittle	/m/0jxh_0
# Dr. John Dolittle	/m/0jxc_s
# Michael Gold	/m/0k4g9k
# Michael Gold	/m/02vd7tb
# ACP Jai Dixit	/m/0jx7ny
# ACP Jai Dixit	/m/0220_c2
# Lois Lane	/m/02tbg08
# Lois Lane	/m/0k3z89
# Lois Lane	/m/0k3z43
# Lois Lane	/m/0k3zb3
# Lois Lane	/m/02vd8wk
# Lois Lane	/m/02vbpng
# Lois Lane	/m/02tbk5n
# Lois Lane	/m/0k3z1q
# Lucy Stark	/m/0cg6c2y
# Lucy Stark	/m/09dxvd4
# Jean-Luc Picard	/m/01xpsgd
# Jean-Luc Picard	/m/040qs2n
# Jean-Luc Picard	/m/04hvd58
# Capt. Thaddeus Harris	/m/03jt8tb
# Capt. Thaddeus Harris	/m/0k1_vf
# Capt. Thaddeus Harris	/m/0k1_sh
# Gary Winston	/m/0jthc_
# Gary Winston	/m/02vbk_v
# Tom Chaney	/m/0g5dytp
# Tom Chaney	/m/0b796rz
# Ravi Verma	/m/0gc33jd
# Ravi Verma	/m/0dj2k38
# Ravi Verma	/m/0csbh3n
# Ravi Verma	/m/0gw3ybf
# Mrs. Santa	/m/0gw77f4
# Mrs. Santa	/m/0lm4r4y
# Judge Dredd	/m/03l9nyg
# Judge Dredd	/m/0g5cn55
# Dr. Laura Baker	/m/0k3mjr
# Dr. Laura Baker	/m/0k3mkt
# Fairy Godmother	/m/0jwffv
# Fairy Godmother	/m/04_bz55
# Fairy Godmother	/m/0hnpx1x
# Fairy Godmother	/m/0bhg15c
# Dr. Henry Jekyll	/m/0jxj5s
# Dr. Henry Jekyll	/m/0k5nsn
# Dr. Henry Jekyll	/m/0jxj9p
# Dr. Henry Jekyll	/m/0jxj7v
# Miss Prissy	/m/0hyp1tr
# Miss Prissy	/m/0gx76p2
# Colonel Sam Trautman	/m/0k2b0_
# Colonel Sam Trautman	/m/0jy7k8
# Esther Blodgett	/m/02nwsyj
# Esther Blodgett	/m/0jsxlp
# Wednesday Addams	/m/0jt0xf
# Wednesday Addams	/m/0k4850
# Ben Carson	/m/09k867c
# Ben Carson	/m/02vcfgj
# Mr. Evans	/m/0hgctl9
# Mr. Evans	/m/0bnprx7
# Jobe Smith	/m/0k5nnj
# Jobe Smith	/m/02sjzh8
# Frank Chambers	/m/0k654x
# Frank Chambers	/m/04m544k
# Princess Snow White	/m/0hgvg2x
# Princess Snow White	/m/0fprkj6
# Irene Adler	/m/04q3yhk
# Irene Adler	/m/0gwss4h
# Amy Sumner	/m/0gvzk5c
# Amy Sumner	/m/02vc216
# Santa Claus	/m/02vd79p
# Santa Claus	/m/0m0zqth
# Santa Claus	/m/0gx43bc
# Santa Claus	/m/0dwkcz7
# Santa Claus	/m/08s2h7w
# Santa Claus	/m/03jqvhx
# Santa Claus	/m/07xyf4y
# Santa Claus	/m/0lpshyn
# Santa Claus	/m/059t04_
# Santa Claus	/m/0g5k64r
# Santa Claus	/m/0gc0gd8
# Frederic Chopin	/m/0jwd7g
# Frederic Chopin	/m/0jzv3_
# Laura Black	/m/03jsvh2
# Laura Black	/m/04j20qg
# Cliff Brumby	/m/0hhhcvq
# Cliff Brumby	/m/02tb44b
# 'Baby' Louise	/m/0c0lv89
# 'Baby' Louise	/m/0h2cmv_
# Wile E. Coyote	/m/0hynb8v
# Wile E. Coyote	/m/0gggxqr
# Wile E. Coyote	/m/0hyq19r
# Captain Englehorn	/m/02vc_7l
# Captain Englehorn	/m/0k6ht5
# Larry Wilson	/m/03jrtgt
# Larry Wilson	/m/0k7yjg
# Nancy 'Sikes'	/m/0k1gvk
# Nancy 'Sikes'	/m/0k1gyx
# Virgil Tibbs	/m/0jzwf0
# Virgil Tibbs	/m/04ls6r2
# Jason Taylor	/m/052glk8
# Jason Taylor	/m/0dlfsx3
# Helen Sharp	/m/0csjgtz
# Helen Sharp	/m/0jx2_9
# Gale Weathers	/m/0k2_df
# Gale Weathers	/m/0bc3xk8
# Gale Weathers	/m/0k2_bp
# The Creeper	/m/0j_4g2
# The Creeper	/m/09j0y1x
# Charlie Frost	/m/03jt3rq
# Charlie Frost	/m/04lsjfp
# Pat Chambers	/m/04l4nbf
# Pat Chambers	/m/02vc39t
# Henry VIII of England	/m/03q141c
# Henry VIII of England	/m/03lkst_
# Aidan Keller	/m/0k69f0
# Aidan Keller	/m/0k69bn
# Jane Eyre	/m/0j_38_
# Jane Eyre	/m/02_y64k
# Jane Eyre	/m/0gfmvhh
# Jane Eyre	/m/02_y64b
# Lyle van de Groot	/m/03lfcfd
# Lyle van de Groot	/m/0jypxh
# Cora Jean Simmons Brown	/m/09j0kyw
# Cora Jean Simmons Brown	/m/0ghs8h8
# Jake "the Muss" Heke	/m/02vcmsg
# Jake "the Muss" Heke	/m/02tb0bv
# George Logan	/m/0k2z0h
# George Logan	/m/03jrksl
# John Connor	/m/0k45ck
# John Connor	/m/03n9_pb
# John Connor	/m/04m5b3q
# Raj Oberoi	/m/04z23yj
# Raj Oberoi	/m/05tf20m
# Marion Ravenwood	/m/0446hng
# Marion Ravenwood	/m/0k294v
# Old Man	/m/0k6n6y
# Old Man	/m/0gcq6bz
# Old Man	/m/09cwzp_
# Old Man	/m/0cgpbsj
# Old Man	/m/0gj41d5
# Old Man	/m/0cg3c1c
# Old Man	/m/0cv3vr0
# Earl of Essex	/m/02vcscc
# Earl of Essex	/m/0h6lsvd
# Karan Oberoi	/m/02tbb8y
# Karan Oberoi	/m/03jqyzh
# The Old Man	/m/0hg466c
# The Old Man	/m/03ljlk5
# Flynn Carsen	/m/02vbzmx
# Flynn Carsen	/m/0gy9lp_
# Eleanor 'Nell' Lance	/m/0k5b5c
# Eleanor 'Nell' Lance	/m/0k5b6f
# Clark Davis	/m/0h2t9mk
# Clark Davis	/m/05nv7ws
# Clark Davis	/m/0h2t9mr
# Ms. Darbus	/m/01z0ccy
# Ms. Darbus	/m/0h5shzf
# Captain Hook	/m/0bhq2ky
# Captain Hook	/m/0cgr3cb
# Captain Hook	/m/0jzjnr
# Daphne Blake	/m/0h1hzmj
# Daphne Blake	/m/0k2zx5
# Daphne Blake	/m/05cj0rq
# Daphne Blake	/m/0k2zvk
# Lara Croft	/m/0gczrqc
# Lara Croft	/m/0j_s88
# Monsieur Hulot	/m/0k1z2f
# Monsieur Hulot	/m/0k0ryt
# Frank Martin	/m/0k79lk
# Frank Martin	/m/0bpgfj1
# Frank Martin	/m/0k6r5t
# Lloyd Christmas	/m/0jxm_1
# Lloyd Christmas	/m/0jxmxj
# Alfred Pennyworth	/m/0497wl1
# Alfred Pennyworth	/m/0cls3tk
# Alfred Pennyworth	/m/0jv2cb
# Mary Magdalene	/m/04hvc11
# Mary Magdalene	/m/02tbcw8
# Tweety Bird	/m/0hyny7c
# Tweety Bird	/m/0hyq5z3
# Tweety Bird	/m/052bm2q
# Tweety Bird	/m/0hyq0zb
# Tweety Bird	/m/0g8qd1f
# Tweety Bird	/m/0hynhnl
# Tweety Bird	/m/0hyp1jd
# Tweety Bird	/m/0gd0xz3
# Tweety Bird	/m/0hyp2p_
# Tweety Bird	/m/0hynmd8
# Tweety Bird	/m/0hyq24w
# Tweety Bird	/m/0hyn7wl
# Tweety Bird	/m/0hyq2m9
# Harry Palmer	/m/04szzf4
# Harry Palmer	/m/04szz85
# Harry Palmer	/m/02tb8q6
# Harry Palmer	/m/04dj1dy
# Harry Palmer	/m/02tbb_4
# Hal Jordan	/m/05p07cy
# Hal Jordan	/m/0gx6y9d
# Martin Luther	/m/04hv63s
# Martin Luther	/m/03jt6gs
# Ron Stoppable	/m/0j_gvh
# Ron Stoppable	/m/0j_gwp
# Zack Martin	/m/0h292b9
# Zack Martin	/m/0gm2yjy
# Peter Vincent	/m/0dgl4s_
# Peter Vincent	/m/03l8rxq
# Peter Vincent	/m/03kyyh7
# Holly Hills	/m/0hcbkq5
# Holly Hills	/m/0gvwwkn
# Norman Bates	/m/0k255h
# Norman Bates	/m/0k2542
# Norman Bates	/m/02tb7h0
# Norman Bates	/m/02vc7cn
# Randolph Carter	/m/09sl8k1
# Randolph Carter	/m/09sl732
# Randolph Carter	/m/09sl8mh
# Isaac Chroner	/m/03lp955
# Isaac Chroner	/m/02vd8yt
# Rowley Jefferson	/m/0g4tkv_
# Rowley Jefferson	/m/0hcblbr
# Cyrano de Bergerac	/m/0jwwvs
# Cyrano de Bergerac	/m/02kpj10
# Merlin Jones	/m/03jrrrg
# Merlin Jones	/m/03jr5dn
# Boba Fett	/m/05n8b9z
# Boba Fett	/m/0bvd6p7
# Lucy Pevensie	/m/0646fl6
# Lucy Pevensie	/m/0k4q93
# Lucy Pevensie	/m/02vcr1y
# Jason Bourne	/m/0k4kfm
# Jason Bourne	/m/0k4kcz
# Jason Bourne	/m/02t9djx
# Hector Barbossa	/m/0k1x_2
# Hector Barbossa	/m/0k1xvt
# Hector Barbossa	/m/087vfh8
# Kyle Williams	/m/04ls5sp
# Kyle Williams	/m/0jwzpz
# Thantos DuBaer	/m/02vd0qv
# Thantos DuBaer	/m/03jrhyh
# Dana Barrett	/m/0jyrz9
# Dana Barrett	/m/0jyr_m
# Prince Humperdinck	/m/03jt4jc
# Prince Humperdinck	/m/0k65z0
# Kathryn Merteuil	/m/0jwv4w
# Kathryn Merteuil	/m/02vd6b2
# Dylan Piper	/m/0jz3d0
# Dylan Piper	/m/0jz3f5
# Dylan Piper	/m/04djh5y
# Sebastian Valmont	/m/02vbmsy
# Sebastian Valmont	/m/0jwv4q
# John Wayne Gacy	/m/04j36zl
# John Wayne Gacy	/m/0djb84t
# Jesse Huston	/m/02vczvc
# Jesse Huston	/m/02vbc94
# Rianne Murtaugh Butters	/m/0h5rzt9
# Rianne Murtaugh Butters	/m/0gcjb99
# Robert Martin	/m/07q9v9d
# Robert Martin	/m/05clkc2
# Romeo Montague	/m/0k8363
# Romeo Montague	/m/0gch254
# Mollie Ubriacco	/m/0k04l_
# Mollie Ubriacco	/m/02vd40p
# Mollie Ubriacco	/m/02tbhlh
# Scott Calvin	/m/0k6cmh
# Scott Calvin	/m/0k6ck0
# Scott Calvin	/m/0k6clg
# Jo March	/m/0k023x
# Jo March	/m/0k0270
# Father Brennan	/m/0mz9xy8
# Father Brennan	/m/03l79vn
# Father Brennan	/m/0k610v
# Captain Nascimento	/m/04mnnfy
# Captain Nascimento	/m/0g4nwkh
# Princess Ariel	/m/02vcqhn
# Princess Ariel	/m/040nkwf
# Princess Ariel	/m/0k5r09
# Lena Kaligaris	/m/0k6gwn
# Lena Kaligaris	/m/04g6vv4
# Han Lue	/m/0k51qm
# Han Lue	/m/0jv8sn
# Michael Myers	/m/0jz30_
# Michael Myers	/m/02vdf1t
# Michael Myers	/m/02vb34_
# Michael Myers	/m/02vc04n
# Michael Myers	/m/0jz328
# Michael Myers	/m/03jtc2g
# Mary Morstan	/m/0btn3kn
# Mary Morstan	/m/0gw6_80
# Nancy Thompson	/m/0jsvgr
# Nancy Thompson	/m/0jsvq2
# President Baxter Harris	/m/0k2z0n
# President Baxter Harris	/m/03jsm_n
# Becky Thatcher	/m/03lbz8w
# Becky Thatcher	/m/02tb69x
# Laxmi Devi	/m/0jznk7
# Laxmi Devi	/m/02vdc95
# Christopher Robin	/m/0gkcl82
# Christopher Robin	/m/062tzjk
# Marge Sherwood	/m/0k1z84
# Marge Sherwood	/m/0k6mhl
# Charlotte York	/m/05lmdtt
# Charlotte York	/m/05nxhmy
# George Lytton	/m/0k63z6
# George Lytton	/m/0cg4dgp
# Jack Ryan	/m/0cs5h5r
# Jack Ryan	/m/0k4g6_
# Jack Ryan	/m/0k6lpc
# Catherine Tramell	/m/0jv1wy
# Catherine Tramell	/m/0jv1vb
# Shane Gray	/m/09rjlbh
# Shane Gray	/m/064ylll
# Charlie Chan	/m/08nnpnn
# Charlie Chan	/m/04ddyzc
# John Rambo	/m/040lhs4
# John Rambo	/m/0k2b0v
# Alex West	/m/0j77mx3
# Alex West	/m/02tbd5z
# The Doctor	/m/0h2vrh_
# The Doctor	/m/0gc0jkz
# The Doctor	/m/03jrv05
# Apollo Creed	/m/02vcknw
# Apollo Creed	/m/0k2n3p
# Apollo Creed	/m/0k2n0d
# Big Bad Wolf	/m/0hyn5y0
# Big Bad Wolf	/m/0g99lch
# Big Bad Wolf	/m/0hyn9jv
# Big Bad Wolf	/m/0hynm04
# Big Bad Wolf	/m/0jzjmr
# Norman Maine	/m/0jsxlv
# Norman Maine	/m/0jsxhz
# Gabriel Martin	/m/04m716n
# Gabriel Martin	/m/045x5sk
# Dave the Dude	/m/0k1zg4
# Dave the Dude	/m/02vcl6z
# Porky Pig	/m/0hyp01z
# Porky Pig	/m/052bktd
# Porky Pig	/m/0647479
# Porky Pig	/m/0hyq22k
# Porky Pig	/m/052cgjh
# Porky Pig	/m/052c6v9
# Porky Pig	/m/0gx55_s
# Porky Pig	/m/0hyn7l2
# Porky Pig	/m/0ggfbmw
# Porky Pig	/m/0gx78br
# Porky Pig	/m/0hyq1wk
# Porky Pig	/m/052d7kb
# Porky Pig	/m/0hgvjvf
# Porky Pig	/m/052d0g7
# Porky Pig	/m/0glmltq
# Porky Pig	/m/0gcsp35
# Porky Pig	/m/0ggcxvh
# Porky Pig	/m/052d9kk
# Porky Pig	/m/052b3xt
# Porky Pig	/m/0665hpk
# Porky Pig	/m/0hyqd4s
# Porky Pig	/m/0gx84q8
# Porky Pig	/m/0h1k0g3
# Porky Pig	/m/0hynkqy
# Porky Pig	/m/0gx4401
# Porky Pig	/m/0hynnz8
# Porky Pig	/m/0gx86h0
# Porky Pig	/m/052ccqz
# Porky Pig	/m/0n4pmb0
# Porky Pig	/m/052bf45
# Porky Pig	/m/052bz2g
# Porky Pig	/m/052bl0d
# Porky Pig	/m/0hyq74r
# Porky Pig	/m/052cttw
# Porky Pig	/m/0hynpjw
# Porky Pig	/m/0b78pdk
# Porky Pig	/m/0gx5f1c
# Porky Pig	/m/0hynk3g
# Garth Algar	/m/0k7xz5
# Garth Algar	/m/0k7xxw
# Napoléon Bonaparte	/m/02vb2kl
# Napoléon Bonaparte	/m/0jwn5p
# Lisa Dolittle	/m/02vc_tl
# Lisa Dolittle	/m/0gcpd50
# Miss Marple	/m/02vbylm
# Miss Marple	/m/02tbctl
# Miss Marple	/m/02vc584
# Miss Marple	/m/02t9_pg
# Evan Baxter	/m/0jxy5m
# ...
# Leon Trotsky	/m/04htwl9
# Leon Trotsky	/m/0jyh0m
# Tony Stark	/m/0j1__hv
# Tony Stark	/m/0n4fx4_
# Babe Bennett	/m/0k0wws
# Babe Bennett	/m/0k0wyc
# Mr. White	/m/0k2gg9
# Mr. White	/m/0k46x1
# Aman Mehra	/m/0jszpk
# Aman Mehra	/m/0dj2l_x
# Max Rockatansky	/m/0k09dq
# Max Rockatansky	/m/05dc8yy
# Max Rockatansky	/m/0k09b2
# Mikaela Banes	/m/0k79jf
# Mikaela Banes	/m/04m54zb
# Ginny Weasley	/m/0fq96yv
# Ginny Weasley	/m/07z1scv
# Tom Ripley	/m/0k1z7v
# Tom Ripley	/m/0k6mh8
# Gabriella Montez	/m/02vd0zf
# Gabriella Montez	/m/0jzdyy
# Robert Thorn	/m/0k610c
# Robert Thorn	/m/02vdcbs
# Chili Palmer	/m/0jv3jj
# Chili Palmer	/m/02vc474
# Cobra Bubbles	/m/03l67r6
# Cobra Bubbles	/m/0cw00xy
# Joanna Eberhart	/m/0k6k6n
# Joanna Eberhart	/m/0k6k7q
# High Priest Imhotep	/m/0k5y_x
# High Priest Imhotep	/m/0k5yzp
# Bobby Ray	/m/03jqy4h
# Bobby Ray	/m/03jstvn
# King Harold	/m/04_bz4y
# King Harold	/m/0k3829
# Poison Ivy	/m/0jv29l
# Poison Ivy	/m/0k1zps
# Andy Warhol	/m/040rxs3
# Andy Warhol	/m/0jy0gs
# Anne Frank	/m/0k4cdz
# Anne Frank	/m/0k4yl2
# Ethan Dalloway	/m/0jz3fb
# Ethan Dalloway	/m/02tb3lm
# Aggie Cromwell	/m/04djh6d
# Aggie Cromwell	/m/0jz3b1
# Aggie Cromwell	/m/0jz3cd
# Jane Porter	/m/0k42w3
# Jane Porter	/m/0k42rp
# Jane Porter	/m/04hv7m_
# Jane Porter	/m/040lqg1
# Jessie Thekekuttu	/m/0hpqb9b
# Jessie Thekekuttu	/m/05nw02t
# Red Queen	/m/0k9xy6x
# Red Queen	/m/04q4dn9
# Mr. Tumnus	/m/03jq4gd
# Mr. Tumnus	/m/0k4qc0
# Lucy van Pelt	/m/07n9qvv
# Lucy van Pelt	/m/0h5hchw
# Professor Albus Dumbledore	/m/03bvlq0
# Professor Albus Dumbledore	/m/02vcbhh
# Professor Albus Dumbledore	/m/0jz6fr
# Professor Albus Dumbledore	/m/0jz6c8
# Professor Albus Dumbledore	/m/03lwx73
# Lankester Merrin	/m/0jx_43
# Lankester Merrin	/m/0jx_28
# Lankester Merrin	/m/0k50c9
# Vada Margaret Sultenfuss	/m/02vc46p
# Vada Margaret Sultenfuss	/m/02vb40v
# Danny Ocean	/m/02vc2g_
# Danny Ocean	/m/0k1fh0
# Conan the Barbarian	/m/0jwmfk
# Conan the Barbarian	/m/0gvc15s
# Conan the Barbarian	/m/040_lvv
# El Chivo	/m/03k_gpb
# El Chivo	/m/0gm5yvy
# Reggie Hammond	/m/0jskgj
# Reggie Hammond	/m/0jtmhp
# Cornelius Hackl	/m/02vdbv5
# Cornelius Hackl	/m/040jtmn
# Turanga Leela	/m/03l1gw9
# Turanga Leela	/m/02vbzkk
# Turanga Leela	/m/03l1gww
# Turanga Leela	/m/04mjqy7
# Dwight Stifler	/m/0jtf68
# Dwight Stifler	/m/02vczfq
# The Father	/m/03jt5kj
# The Father	/m/0jb9n97
# Alan Garner	/m/0gdk8lh
# Alan Garner	/m/05srhfs
# Ben Parker	/m/0g5tv13
# Ben Parker	/m/02vd9gl
# Dana Scully	/m/04f8_rv
# Dana Scully	/m/0k6zn6
# Elizabeth Frankenstein	/m/0jvstp
# Elizabeth Frankenstein	/m/02vcfm9
# Anne Shirley	/m/0d778r_
# Anne Shirley	/m/0jtm60
# Sethurama Iyer	/m/066738k
# Sethurama Iyer	/m/03jpgcp
# Dorothy Gale	/m/0k2hq0
# Dorothy Gale	/m/0g9lp9c
# Dorothy Gale	/m/09z66lh
# Dorothy Gale	/m/0k6y72
# Audrey Bennett	/m/07r2fpv
# Audrey Bennett	/m/052c8b4
# Mary Jane Watson	/m/0k3nj0
# Mary Jane Watson	/m/0k3ngf
# Mary Jane Watson	/m/0k3nlv
# Gabbar Singh	/m/0dj2k3z
# Gabbar Singh	/m/0gv_r38
# Dr. Anand	/m/03l0xj2
# Dr. Anand	/m/02vbnn0
# Dr. Anand	/m/02vbvwf
# Harold Hill	/m/0k5zfy
# Harold Hill	/m/04hv61w
# Inspector Oscar Piper	/m/040nxm_
# Inspector Oscar Piper	/m/040nxly
# Nora Charles	/m/02vc7jq
# Nora Charles	/m/02vblpp
# Richie Rich	/m/0h2yc35
# Richie Rich	/m/02tb048
# Doctor Doom	/m/0jy24c
# Doctor Doom	/m/0k51k2
# John Cutter	/m/0k1s6v
# John Cutter	/m/0k65kl
# Kamal Khan	/m/03jsjdg
# Kamal Khan	/m/04r9c2w
# Nancy Fowler Archer	/m/0jttmc
# Nancy Fowler Archer	/m/04j2xp_
# Jacob Black	/m/0b68zn5
# Jacob Black	/m/05tflhw
# Jacob Black	/m/075wxc2
# Police Inspector	/m/0h7187r
# Police Inspector	/m/04sc7zx
# Ajay Kapoor	/m/0cg00xq
# Ajay Kapoor	/m/02vd25j
# Freddy Lounds	/m/03js1wd
# Freddy Lounds	/m/0k2dcy
# Sher Khan	/m/0dj2jzx
# Sher Khan	/m/0dj2ldj
# Sam Spade	/m/04dmkpj
# Sam Spade	/m/04dmkpb
# Marvin the Martian	/m/0hyntkj
# Marvin the Martian	/m/0hynljn
# Robert Langdon	/m/0jtkml
# Robert Langdon	/m/0k4v8c
# Paul Vitti	/m/0jthkz
# Paul Vitti	/m/0jthm6
# El Mariachi	/m/0k1j0x
# El Mariachi	/m/0jx5_x
# Mr. Chow	/m/0djw3s5
# Mr. Chow	/m/05srhkd
# Michael Sobel	/m/0gdnnsr
# Michael Sobel	/m/0gdnyws
# Anastasia Tremaine	/m/0hp7r39
# Anastasia Tremaine	/m/03jrh_p
# Anastasia Tremaine	/m/02tb5zv
# Harry Callahan	/m/0k4wj4
# Harry Callahan	/m/0k4_r8
# Harry Callahan	/m/0k0bgf
# Harry Callahan	/m/0k3x23
# Jill McBain	/m/0gb_whk
# Jill McBain	/m/0k1j4c
# Tony Wilson	/m/0jsk5k
# Tony Wilson	/m/0cgbqr5
# Pooja Malhotra	/m/040jw9x
# Pooja Malhotra	/m/0dbxq5k
# Mike Hammer	/m/04j11p0
# Mike Hammer	/m/0k104s
# Mike Hammer	/m/0j_jh4
# Mike Hammer	/m/04l4rk7
# Mike Hammer	/m/04l4m_b
# Naruto Uzumaki	/m/05t6gq0
# Naruto Uzumaki	/m/05np9zg
# Jon Arbuckle	/m/0jyn_4
# Jon Arbuckle	/m/0jynyv
# Joseph Fernandez	/m/0k00qds
# Joseph Fernandez	/m/02vbmwr
# Dracula's Bride	/m/05mdr8g
# Dracula's Bride	/m/05n5vpt
# Gordon Bombay	/m/03ld2v8
# Gordon Bombay	/m/03l9ncd
# Gordon Bombay	/m/03lmq2q
# Elektra Natchios	/m/0jwz5d
# Elektra Natchios	/m/0hdvq4l
# Frank Towns	/m/0jy9k8
# Frank Towns	/m/052fkcc
# Billy Nolan	/m/07rzlcw
# Billy Nolan	/m/0jw3l2
# Obi-Wan Kenobi	/m/0k3qy3
# Obi-Wan Kenobi	/m/0k3r2g
# Obi-Wan Kenobi	/m/0k3r05
# Obi-Wan Kenobi	/m/0k3qzt
# Obi-Wan Kenobi	/m/04m6bsr
# Vicomte Sébastien de Valmont	/m/0jwyr9
# Vicomte Sébastien de Valmont	/m/05nvnnc
# Emily Rose	/m/0k6sh0
# Emily Rose	/m/0k508t
# Frankenstein's monster	/m/052b_kh
# Frankenstein's monster	/m/02vdb22
# Frankenstein's monster	/m/0jyfb3
# Frankenstein's monster	/m/0k55k6
# Frankenstein's monster	/m/0js_24
# Frankenstein's monster	/m/0jyf2z
# Frankenstein's monster	/m/0jvstc
# Frankenstein's monster	/m/0k3jrd
# Oliver Twist	/m/02tbcyj
# Oliver Twist	/m/0k1gww
# Oliver Twist	/m/04hv1vt
# Oliver Twist	/m/0glhjbx
# Oliver Twist	/m/0k1gvq
# Oliver Twist	/m/02tb4dl
# Oliver Twist	/m/03lfhp1
# Roy Earle	/m/0jzd_l
# Roy Earle	/m/02vb9q4
# Queen Elizabeth I	/m/0k6txj
# Queen Elizabeth I	/m/02vbw96
# Queen Elizabeth I	/m/0gl1r62
# Queen Elizabeth I	/m/04fmnkb
# Queen Elizabeth I	/m/02vd7j1
# Queen Elizabeth I	/m/04fmmv9
# Raj Singh	/m/0h887zn
# Raj Singh	/m/0c05wjz
# Raj Singh	/m/0j_by7
# Betty Ross Banner	/m/0k7hlh
# Betty Ross Banner	/m/02tbhmx
# Betty Ross Banner	/m/0jznld
# Sethu Madhavan	/m/0cmxf3l
# Sethu Madhavan	/m/0j_j9g
# Mary McKay	/m/03kzxx4
# Mary McKay	/m/0bwrrwp
# Jason Voorhees	/m/0j_3q0
# Jason Voorhees	/m/0jyg1h
# Jason Voorhees	/m/0290qyj
# Jason Voorhees	/m/08cvzs2
# Sabrina Spellman	/m/03jrrpr
# Sabrina Spellman	/m/02vcxt6
# Sabrina Spellman	/m/03jsvbb
# Chon Wang	/m/0k34yq
# Chon Wang	/m/02tbdtg
# Austin Powers	/m/0jtv5t
# Austin Powers	/m/0jtv84
# Austin Powers	/m/0jtvbb
# Jill Valentine	/m/0k2glq
# Jill Valentine	/m/0gvzqlt
# David Sumner	/m/0gvwy91
# David Sumner	/m/0k3v65
# Armand Duval	/m/0jw14x
# Armand Duval	/m/02vblld
# Rocky Balboa	/m/0k2n4f
# Rocky Balboa	/m/0k2n36
# Rocky Balboa	/m/01xxqty
# Rocky Balboa	/m/0k2m_y
# Rocky Balboa	/m/02tb42c
# Amy Peterson	/m/0dgl4jz
# Amy Peterson	/m/02vbx8f
# Charley Brewster	/m/02vc1xx
# Charley Brewster	/m/0dglblh
# Mrs. Danvers	/m/0k2cy0
# Mrs. Danvers	/m/02vbg94
# Ronnie Winslow	/m/09rnx26
# Ronnie Winslow	/m/0bqs4zr
# Douglas Quaid	/m/0k78dt
# Douglas Quaid	/m/0gw40y1
# Edward Cullen	/m/075wx7x
# Edward Cullen	/m/04m6lb4
# Edward Cullen	/m/05tflhq
# Edward Cullen	/m/075wx86
# Count Dracula	/m/0k3jq7
# Count Dracula	/m/0jxjvp
# Count Dracula	/m/0jxjq6
# Count Dracula	/m/05v78rd
# Count Dracula	/m/0k6cq0
# Count Dracula	/m/0jxjtg
# Count Dracula	/m/02vc323
# Count Dracula	/m/02vc6xy
# Count Dracula	/m/05n52b6
# Count Dracula	/m/02tbf19
# Count Dracula	/m/0jwq7s
# Count Dracula	/m/0jxjnq
# Count Dracula	/m/0h4y7ck
# Count Dracula	/m/0jxjrv
# Count Dracula	/m/0k1cp2
# Count Dracula	/m/02vd4nc
# Count Dracula	/m/0jzlc7
# John Preston	/m/0jxwq8
# John Preston	/m/02vd03b
# Louis Tully	/m/0jyr_y
# Louis Tully	/m/02tbfxb
# Lucius Fox	/m/045yrqg
# Lucius Fox	/m/0bpm7s8
# M. Bison	/m/0k3vfm
# M. Bison	/m/0460cp6
# Nancy Drew	/m/02vc47b
# Nancy Drew	/m/04ytjds
# Ming the Merciless	/m/02tbgpc
# Ming the Merciless	/m/0jy8ql
# Wilmer Cook	/m/05nyh_9
# Wilmer Cook	/m/05nyn2q
# Dexter Riley	/m/02vcc0n
# Dexter Riley	/m/02vd0y6
# Dexter Riley	/m/02vd76h
# George Taylor	/m/0k1ypl
# George Taylor	/m/0jv7ws
# Juni Cortez	/m/02s9tvb
# Juni Cortez	/m/02s9ttl
# Juni Cortez	/m/02s9trw
# Juni Cortez	/m/0g51m5_
# Rodrick Heffley	/m/0g4tkw4
# Rodrick Heffley	/m/0hcbktv
# Valentin Dmitrovich Zukovsky	/m/07vr46w
# Valentin Dmitrovich Zukovsky	/m/01z0qcz
# Katherine Thorn	/m/0k610j
# Katherine Thorn	/m/02vcw5c
# Dr. Jennings	/m/04zd_2y
# Dr. Jennings	/m/0bq3sl4
# George Lutz	/m/0k49zk
# George Lutz	/m/0k49xw
# Blanche Hudson	/m/0k7ztw
# Blanche Hudson	/m/0cs4g8g
# Lawrence Gordon	/m/0cf_bww
# Lawrence Gordon	/m/07p69b3
# Abraham Van Helsing	/m/0jwq7y
# Abraham Van Helsing	/m/02vc_c7
# Abraham Van Helsing	/m/0jxjq1
# Abraham Van Helsing	/m/0k4llv
# Abraham Van Helsing	/m/02vbt49
# Abraham Van Helsing	/m/0jvrhf
# Abraham Van Helsing	/m/0jxjvv
# Abraham Van Helsing	/m/0jxjnw
# Abraham Van Helsing	/m/0jxjsg
# Abraham Van Helsing	/m/0jxjxh
# Grandpa Joe	/m/0k8393
# Grandpa Joe	/m/02vbr83
# Joe Pendleton	/m/0jz8zl
# Joe Pendleton	/m/0jzcjj
# John Kane	/m/0259v60
# John Kane	/m/052j148
# Salim Mirza	/m/03jr7gw
# Salim Mirza	/m/040k6bd
# Martin Riggs	/m/0j_zj3
# Martin Riggs	/m/0j_zgw
# Martin Riggs	/m/0j_zfr
# Martin Riggs	/m/0j_zk_
# Lilo Pelekai	/m/0j_xhv
# Lilo Pelekai	/m/0k3t36
# Lilo Pelekai	/m/0k00dg
# Lilo Pelekai	/m/0k00bd
# White Rabbit	/m/0jt7jj
# White Rabbit	/m/02vb5n9
# George McFly	/m/0jty5w
# George McFly	/m/0crrc7t
# Ralph Wolf	/m/052d6k0
# Ralph Wolf	/m/0hynqdn
# Ralph Wolf	/m/052d6kj
# Joan Wilder	/m/02vd3wx
# Joan Wilder	/m/0k2nxl
# Angela Baker	/m/03js2bt
# Angela Baker	/m/0k3d0z
# Angela Baker	/m/0k3c_p
# Horatio Hornblower	/m/04d6b15
# Horatio Hornblower	/m/0jw295
# Horatio Hornblower	/m/0h34xtd
# King Louis XIV	/m/03lzc4h
# King Louis XIV	/m/02tb2dv
# Rahul Kapoor	/m/040kq9h
# Rahul Kapoor	/m/03jpqq4
# Mrs. Singh	/m/0h736vz
# Mrs. Singh	/m/09n83_h
# Mrs. Singh	/m/0h8ms5t
# Jesse James	/m/0jtf0j
# Jesse James	/m/0j_4xc
# Jesse James	/m/05t9r51
# Jesse James	/m/0k4c1k
# Vijay Kumar	/m/0dgb1c3
# Vijay Kumar	/m/03ll815
# Alice Johnson	/m/0jsvp0
# Alice Johnson	/m/0jsvjv
# Henry Roth	/m/0jsll5
# Henry Roth	/m/03jptjn
# Felix Leiter	/m/04y_fmd
# Felix Leiter	/m/07vr1bp
# Felix Leiter	/m/04yw0ft
# Felix Leiter	/m/04z072p
# Felix Leiter	/m/04y_n8v
# Felix Leiter	/m/03hqwdy
# Carol Brady	/m/02vccf6
# Carol Brady	/m/02vc_r7
# Wayne Szalinski	/m/0jzjdk
# Wayne Szalinski	/m/0jzj8h
# Wayne Szalinski	/m/0j7r877
# Will Turner	/m/0k1x_7
# Will Turner	/m/0k1xvn
# Will Turner	/m/0k1xxs
# Brad Majors	/m/0k372r
# Brad Majors	/m/0k69_c
# Captain America	/m/02vc0w_
# Captain America	/m/063kzx3
# Captain America	/m/05z09zw
# Captain America	/m/0k7hk2
# The Predator	/m/03lpp78
# The Predator	/m/0h34xg2
# Sara Moore	/m/0k31y4
# Sara Moore	/m/0k0p80
# Josh Nichols	/m/04q48y1
# Josh Nichols	/m/0jxkpm
# Mr. Brownlow	/m/0cd_1xj
# Mr. Brownlow	/m/05cdz58
# Mr. Brownlow	/m/0k1gxn
# The Colonel	/m/02tbg10
# The Colonel	/m/0bscj08
# The Colonel	/m/04z1v9n
# Bobby Ewing	/m/0h5jn1w
# Bobby Ewing	/m/0h5jn0k
# Savitri Devi	/m/02vbtr7
# Savitri Devi	/m/040kz59
# The Grinch	/m/0jzmfc
# The Grinch	/m/04ypjd7
# Son Goku	/m/0hh6mcy
# Son Goku	/m/0jx28n
# Son Goku	/m/040ly_g
# Abigail Chase	/m/02vcd9h
# Abigail Chase	/m/0k14v6
# The Monster	/m/04htszs
# The Monster	/m/0k89l0
# The Monster	/m/0jyf1r
# Kasper Gutman	/m/03lk0l8
# Kasper Gutman	/m/05nyfhg
# Dev Prakash Subramaniam	/m/09sd74q
# Dev Prakash Subramaniam	/m/0h765zp
# Bridget Jones	/m/0c1r226
# Bridget Jones	/m/0jvt4d
# Philo Beddoe	/m/0jxyl4
# Philo Beddoe	/m/03l9hym
# Jonathan Harker	/m/02vbxk4
# Jonathan Harker	/m/03js4jz
# Jonathan Harker	/m/05n52v0
# Jonathan Harker	/m/0h1kd_0
# Jonathan Harker	/m/05n5vp6
# Jonathan Harker	/m/0jwq8k
# Jonathan Harker	/m/0jvrh8
# Jonathan Harker	/m/0jxjs4
# François Pignon	/m/03jqj3s
# François Pignon	/m/0j_tsl
# Jonah Hex	/m/0gv_zjc
# Jonah Hex	/m/05tg21f
# Mark Hunter	/m/0k25p4
# Mark Hunter	/m/0cs1m0x
# Christine Daaé	/m/0k63gl
# Christine Daaé	/m/0k63hp
# Christine Daaé	/m/05nqr1x
# Charlie McGee	/m/02vcl4x
# Charlie McGee	/m/0460dxt
# King Leonidas	/m/02vbth5
# King Leonidas	/m/0jsg_l
# Jesse Stone	/m/0cs70w2
# Jesse Stone	/m/09j3tkx
# Jesse Stone	/m/0gvwwc8
# Jesse Stone	/m/0cr_z6g
# King Arthur	/m/0jw0_y
# King Arthur	/m/0jy7qw
# King Arthur	/m/0gx8_6b
# King Arthur	/m/0k0t2r
# King Arthur	/m/045xxd8
# Albert Wesker	/m/0h_h2h4
# Albert Wesker	/m/08nbk4b
# Dr. Jonas Carson	/m/040t9pt
# Dr. Jonas Carson	/m/04q44bh
# Bella Swan	/m/075xjx2
# Bella Swan	/m/075wxc7
# Bella Swan	/m/04m6l9_
# Carlos Olivera	/m/0k2gp4
# Carlos Olivera	/m/0k2glw
# The Woman	/m/0h25z1c
# The Woman	/m/0k0m6t
# Nils Bjurman	/m/0c1w01r
# Nils Bjurman	/m/0b3vyf5
# Doc Holliday	/m/02vbm3g
# Doc Holliday	/m/062wppj
# John Reed	/m/0gfmw95
# John Reed	/m/04lqzzg
# Peter Mitchell	/m/02vd8ts
# Peter Mitchell	/m/0k72_r
# Rizwan Khan	/m/04dfm3w
# Rizwan Khan	/m/09ryztp
# Deloris Van Cartier / Sister Mary Clarence	/m/0k3bk9
# Deloris Van Cartier / Sister Mary Clarence	/m/0k3bld
# Walter Burns	/m/02vcrj5
# Walter Burns	/m/0jzg14
# Taj Mahal Badalandabad	/m/0k14s4
# Taj Mahal Badalandabad	/m/02vd1tq
# Troy Bolton	/m/0jzdys
# Troy Bolton	/m/02vcjkf
# Troy Bolton	/m/03lyytj
# Henry II of England	/m/02vd422
# Henry II of England	/m/02vb6mj
# Michael Jennings	/m/0k1hd7
# Michael Jennings	/m/0k1t08
# Laura Reynolds	/m/02vcg2s
# Laura Reynolds	/m/02vcb4j
# Paul Finch	/m/03jqt1w
# Paul Finch	/m/03jq2tk
# Paul Finch	/m/03jqz14
# Michael Woods	/m/0jzk4x
# Michael Woods	/m/0j_8hl
# Captain Nemo	/m/0dkcf_k
# Captain Nemo	/m/0dkcfz_
# Captain Nemo	/m/0k5nrw
# Captain Nemo	/m/0dkcf_r
# Mark Darcy	/m/0c1r22b
# Mark Darcy	/m/0jvt4k
# John Smith	/m/0dglfvj
# John Smith	/m/04lrh46
# John Smith	/m/0k1zbj
# John Smith	/m/0k0wdw
# John Smith	/m/02vddfg
# The Shadow	/m/0hhj5tr
# The Shadow	/m/0k6fjx
# Prince Carlos	/m/0chc9nh
# Prince Carlos	/m/0cb3xvz
# Don Giovanni	/m/0cfztq8
# Don Giovanni	/m/02h7x3p
# Uncle Joe	/m/02vbjx9
# Uncle Joe	/m/02vcy4g
# Estella Havisham	/m/0jy_hr
# Estella Havisham	/m/02vb4kb
# Woody Woodpecker	/m/09j1yx2
# Woody Woodpecker	/m/0n5f97y
# Woody Woodpecker	/m/09j1yfz
# Woody Woodpecker	/m/09j1x5c
# Woody Woodpecker	/m/09j1x44
# Woody Woodpecker	/m/09j1xd3
# Woody Woodpecker	/m/09j1yxn
# Woody Woodpecker	/m/09j1y9j
# Woody Woodpecker	/m/09j1yp6
# Woody Woodpecker	/m/0n4jzq6
# Woody Woodpecker	/m/09j1yhk
# Woody Woodpecker	/m/09j1x3_
# Woody Woodpecker	/m/09j1xxw
# Woody Woodpecker	/m/0n55thh
# Woody Woodpecker	/m/0n5f97y
# James T. Kirk	/m/02h8ffv
# James T. Kirk	/m/05qpqhm
# James T. Kirk	/m/02h8g02
# James T. Kirk	/m/02ws9cw
# James T. Kirk	/m/02h8f_w
# James T. Kirk	/m/022qrv1
# Juan Gallardo	/m/02tb4b4
# Juan Gallardo	/m/0jvj7l
# Kiran Saxena	/m/04j2930
# Kiran Saxena	/m/06wksj4
# Elle Woods	/m/0j_wnh
# Elle Woods	/m/0j_wm4
# Grand Duke	/m/02vbq62
# Grand Duke	/m/03jskyr
# Crystal Allen	/m/02vbq1l
# Crystal Allen	/m/040klgs
# Commissioner Dreyfus	/m/0jsw_d
# Commissioner Dreyfus	/m/0k694m
# Commissioner Dreyfus	/m/0k2j17
# Commissioner Dreyfus	/m/0k797v
# Commissioner Dreyfus	/m/0jwwfz
# Yosemite Sam	/m/0hynrhr
# Yosemite Sam	/m/0hyn6wh
# Yosemite Sam	/m/0hynsvw
# Yosemite Sam	/m/0hynzfx
# Yosemite Sam	/m/0hyn9f2
# Yosemite Sam	/m/0hynjwc
# Yosemite Sam	/m/0hyn2s4
# Yosemite Sam	/m/0hyq5ss
# Yosemite Sam	/m/0hyn8h5
# Yosemite Sam	/m/0hyq2w6
# Yosemite Sam	/m/0hyq2kz
# Yosemite Sam	/m/0hynjl3
# Yosemite Sam	/m/0hyn2nt
# Yosemite Sam	/m/0hynrw2
# Yosemite Sam	/m/0hynbs8
# Yosemite Sam	/m/0hynl9x
# Yosemite Sam	/m/0hyq0db
# Mother Superior	/m/052bg_q
# Mother Superior	/m/0k3blk
# Mother Superior	/m/0b7941h
# Linus Caldwell	/m/0k1fdk
# Linus Caldwell	/m/02vc_19
# Jerry Robinson	/m/03jtbdp
# Jerry Robinson	/m/03vnwn8
# Ichigo Kurosaki	/m/0n6461r
# Ichigo Kurosaki	/m/04619mx
# Ichigo Kurosaki	/m/045yzf8
# Michael Corleone	/m/0k56hx
# Michael Corleone	/m/0k56l4
# John Clark	/m/0k6lp_
# John Clark	/m/0jwhnj
# John Clark	/m/0k34q4
# Eliza Thornberry	/m/040gx8v
# Eliza Thornberry	/m/04hv752
# Cruella de Vil	/m/0k1jy1
# Cruella de Vil	/m/05t1wrz
# Cruella de Vil	/m/0jsl15
# Cruella de Vil	/m/0jsm6h
# Otis B. Driftwood	/m/0jsv64
# Otis B. Driftwood	/m/0jzl1f
# Wonder Woman	/m/0j2ps5l
# Wonder Woman	/m/03ls8n6
# Princess Fiona	/m/03jpm9k
# Princess Fiona	/m/04_bz4k
# Princess Fiona	/m/0k381p
# Princess Fiona	/m/02vcz8g
# Princess Fiona	/m/0k37yg
# Queen of Hearts	/m/0jt7j6
# Queen of Hearts	/m/0jt7nm
# Elmer Fudd	/m/0ggcb2r
# Elmer Fudd	/m/0ggctmr
# Elmer Fudd	/m/0gb5xzc
# Elmer Fudd	/m/0ggd201
# Elmer Fudd	/m/0ggd0sl
# Elmer Fudd	/m/0ggd2mp
# Elmer Fudd	/m/0h7srfm
# Elmer Fudd	/m/0ggcl90
# Elmer Fudd	/m/0hyq1k2
# Elmer Fudd	/m/0gx8ld5
# Elmer Fudd	/m/0ggf6mf
# Elmer Fudd	/m/0ggcktw
# Joe Miller	/m/0k1wdx
# Joe Miller	/m/07zkn44
# Huckleberry Finn	/m/06wk65q
# Huckleberry Finn	/m/02vb62g
# Dean Richmond	/m/0k60j5
# Dean Richmond	/m/0k1dvq
# Big Momma	/m/0g5djnx
# Big Momma	/m/0jvbtm
# Alan Grant	/m/0j_8zj
# Alan Grant	/m/0j_8y4
# Connor MacLeod	/m/0jzfft
# Connor MacLeod	/m/0jzf9c
# Connor MacLeod	/m/0jzfjz
# Connor MacLeod	/m/0jzfbq
# John Rolfe	/m/0k5_ql
# John Rolfe	/m/02vd6vs
# Elizabeth Swann	/m/0k1xvz
# Elizabeth Swann	/m/0k1x_d
# Elizabeth Swann	/m/0k1xxy

# %% [markdown]
# ## Character metadata:

# %% [markdown]
# ### Data cleaning

# %%
character_md.info()
sns.heatmap(character_md.isnull(),cmap=['w','b'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450669 entries, 0 to 450668
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Wikipedia_movie_ID               450669 non-null  int64
#  1   Freebase_movie_ID                450669 non-null  object
#  2   Movie_release_date               440674 non-null  object
#  3   Character_name                   192794 non-null  object
#  4   Actor_date_of_birth              344524 non-null  object
#  5   Actor_gender                     405060 non-null  object
#  6   Actor_height                     154824 non-null  float64
#  7   Actor_ethnicity                  106058 non-null  object
#  8   Actor_name                       449441 non-null  object
#  9   Actor_age_at_movie_release       292556 non-null  float64
#  10  Freebase_character/actor_map_ID  450669 non-null  object
#  11  Freebase_character_ID            192804 non-null  object
#  12  Freebase_actor_ID                449854 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 44.7+ MB
# <AxesSubplot:>

# %%
print(f'There are {len(character_md)} rows')
for i in range(0,len(character_md.columns)):
    nans = character_md.iloc[:,i].isnull().sum()
    print(f'Column {character_md.columns[i]} has: \n\t {nans} NaNs \n \t {nans/len(character_md)*100}% of the rows with NaN')
# Out:
# There are 450669 rows
# Column Wikipedia_movie_ID has:
# 	 0 NaNs
#  	 0.0% of the rows with NaN
# Column Freebase_movie_ID has:
# 	 0 NaNs
#  	 0.0% of the rows with NaN
# Column Movie_release_date has:
# 	 9995 NaNs
#  	 2.217813961022391% of the rows with NaN
# Column Character_name has:
# 	 257875 NaNs
#  	 57.22048776374679% of the rows with NaN
# Column Actor_date_of_birth has:
# 	 106145 NaNs
#  	 23.552762670607475% of the rows with NaN
# Column Actor_gender has:
# 	 45609 NaNs
#  	 10.120287838746398% of the rows with NaN
# Column Actor_height has:
# 	 295845 NaNs
#  	 65.64573999986688% of the rows with NaN
# Column Actor_ethnicity has:
# 	 344611 NaNs
#  	 76.46654196317031% of the rows with NaN
# Column Actor_name has:
# 	 1228 NaNs
#  	 0.2724837963117055% of the rows with NaN
# Column Actor_age_at_movie_release has:
# 	 158113 NaNs
#  	 35.08406391387027% of the rows with NaN
# Column Freebase_character/actor_map_ID has:
# 	 0 NaNs
#  	 0.0% of the rows with NaN
# Column Freebase_character_ID has:
# 	 257865 NaNs
#  	 57.21826884032405% of the rows with NaN
# Column Freebase_actor_ID has:
# 	 815 NaNs
#  	 0.1808422589528013% of the rows with NaN

# %% [markdown]
# For the gender analysis, we create a dataset that discards rows containing NaN for 'Actor_gender'

# %%
character_md_gender = character_md[character_md['Actor_gender'].notna()]
print(f'{character_md.iloc[:,5].isnull().sum()} rows are discarded.\n This corresponds to {character_md.iloc[:,5].isnull().sum()/len(character_md)*100}% of the rows')
# Out:
# 45609 rows are discarded.
#  This corresponds to 10.120287838746398% of the rows

# %%
#take out "unnecessary" columns for the moment
character_gender = character_md_gender.copy()
character_gender = character_gender[['Wikipedia_movie_ID',
                                       'Movie_release_date','Character_name',
                                       'Actor_gender','Actor_name']]
character_gender.head(5)
# Out:
#    Wikipedia_movie_ID Movie_release_date              Character_name  \
# 0              975900         2001-08-24                    Akooshay
# 1              975900         2001-08-24  Lieutenant Melanie Ballard
# 2              975900         2001-08-24         Desolation Williams
# 3              975900         2001-08-24          Sgt Jericho Butler
# 4              975900         2001-08-24             Bashira Kincaid
#
#   Actor_gender          Actor_name
# 0            F      Wanda De Jesus
# 1            F  Natasha Henstridge
# 2            M            Ice Cube
# 3            M       Jason Statham
# 4            F         Clea DuVall

# %% [markdown]
# ### Some numbers and statistics

# %%
nb_women = character_gender[character_gender.Actor_gender == 'F'].shape[0]
nb_women
print(f'{nb_women/len(character_gender)*100}% of all the actors of the dataset are women')
# Out:
# 33.27976102305831% of all the actors of the dataset are women

# %%
#convert to datetime type
character_gender['Movie_release_date'] = pd.to_datetime(character_gender['Movie_release_date'], errors = 'coerce')

# %%
character_gender.dtypes
# Out:
# Wikipedia_movie_ID             int64
# Movie_release_date    datetime64[ns]
# Character_name                object
# Actor_gender                  object
# Actor_name                    object
# dtype: object

# %%
#create new column only with movie_release_year
character_gender['Movie_year'] = character_gender['Movie_release_date'].dt.year.fillna(0.0).astype(int)
character_gender = character_gender[character_gender.Movie_year != 0]
#df[list("ABCD")] = df[list("ABCD")].fillna(0.0).astype(int)
character_gender.head(5)
# Out:
#    Wikipedia_movie_ID Movie_release_date              Character_name  \
# 0              975900         2001-08-24                    Akooshay
# 1              975900         2001-08-24  Lieutenant Melanie Ballard
# 2              975900         2001-08-24         Desolation Williams
# 3              975900         2001-08-24          Sgt Jericho Butler
# 4              975900         2001-08-24             Bashira Kincaid
#
#   Actor_gender          Actor_name  Movie_year
# 0            F      Wanda De Jesus        2001
# 1            F  Natasha Henstridge        2001
# 2            M            Ice Cube        2001
# 3            M       Jason Statham        2001
# 4            F         Clea DuVall        2001

# %%
character_gender.pivot_table(index=['Movie_year'],columns='Actor_gender',aggfunc='size').plot(kind='bar')
ax = plt.gca()
ax.set_xticks(ax.get_xticks()[::3])
ax.xaxis.set_tick_params(labelsize=7)
